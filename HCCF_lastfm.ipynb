# %% [markdown]
# ## HCCF

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from torch.nn.init import xavier_normal_, xavier_uniform_
import argparse
import numpy as np
import time
import sys
from os.path import abspath

from base.graph_recommender import GraphRecommender
from util.sampler import next_batch_pairwise
from util.conf import OptionConf
import torch
import torch.nn as nn 
import torch.nn.functional as F
from scipy.sparse import coo_matrix
from util.loss_torch import bpr_loss, l2_reg_loss, EmbLoss, contrastLoss
from util.init import *
from base.torch_interface import TorchGraphInterface
import os
import numpy as np 
import time 
from torch.optim.lr_scheduler import ReduceLROnPlateau
from itertools import product

from data.loader import FileIO
from util.conf import ModelConf
from base.recommender import Recommender
from data.ui_graph import Interaction
# from data.knowledge import Knowledge
from util.algorithm import find_k_largest
from time import strftime, localtime
from data.loader import FileIO
from util.evaluation import ranking_evaluation

import pandas as pd
from datetime import datetime
import csv

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
class GraphRecommender(Recommender):
    def __init__(self, conf, training_set, test_set, knowledge_data, **kwargs):
        super(GraphRecommender, self).__init__(conf, training_set, test_set, knowledge_data, **kwargs)
        self.data = Interaction(conf, training_set, test_set)
        self.bestPerformance = []
        top = self.ranking.split(',')
        self.topN = [int(num) for num in top]
        self.max_N = max(self.topN)
        
        self.output_path = kwargs['output_path']
        if not os.path.exists(self.output_path):
            os.makedirs(self.output_path)

    def print_model_info(self):
        super(GraphRecommender, self).print_model_info()
        # # print dataset statistics
        print('Training Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.training_size()))
        print('Test Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.test_size()))
        print('=' * 80)

    def build(self):
        pass

    def train(self):
        pass

    def predict(self, u):
        pass

    def test(self, user_emb, item_emb):
        def process_bar(num, total):
            rate = float(num) / total
            ratenum = int(50 * rate)
            r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
            sys.stdout.write(r)
            sys.stdout.flush()

        # predict
        rec_list = {}
        user_count = len(self.data.test_set)
        for i, user in enumerate(self.data.test_set):
            # s_find_candidates = time.time()
            
            
            # candidates = predict(user)
            user_id  = self.data.get_user_id(user)
            score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
            candidates = score.cpu().numpy()
            
            # e_find_candidates = time.time()
            # print("Calculate candidates time: %f s" % (e_find_candidates - s_find_candidates))
            # predictedItems = denormalize(predictedItems, self.data.rScale[-1], self.data.rScale[0])
            rated_list, li = self.data.user_rated(user)
            for item in rated_list:
                candidates[self.data.item[item]] = -10e8
            
            # s_find_k_largest = time.time()
            ids, scores = find_k_largest(self.max_N, candidates)
            # e_find_k_largest = time.time()
            # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
            item_names = [self.data.id2item[iid] for iid in ids]
            rec_list[user] = list(zip(item_names, scores))
            if i % 1000 == 0:
                process_bar(i, user_count)
        process_bar(user_count, user_count)
        print('')
        return rec_list

    def evaluate(self, rec_list):
        self.recOutput.append('userId: recommendations in (itemId, ranking score) pairs, * means the item is hit.\n')
        for user in self.data.test_set:
            line = str(user) + ':'
            for item in rec_list[user]:
                line += ' (' + str(item[0]) + ',' + str(item[1]) + ')'
                if item[0] in self.data.test_set[user]:
                    line += '*'
            line += '\n'
            self.recOutput.append(line)
        current_time = strftime("%Y-%m-%d %H-%M-%S", localtime(time.time()))
        # output prediction result
        out_dir = self.output['-dir']
        file_name = self.config['model.name'] + '@' + current_time + '-top-' + str(self.max_N) + 'items' + '.txt'
        FileIO.write_file(out_dir, file_name, self.recOutput)
        print('The result has been output to ', abspath(out_dir), '.')
        file_name = self.config['model.name'] + '@' + current_time + '-performance' + '.txt'
        self.result = ranking_evaluation(self.data.test_set, rec_list, self.topN)
        self.model_log.add('###Evaluation Results###')
        self.model_log.add(self.result)
        FileIO.write_file(out_dir, file_name, self.result)
        print('The result of %s:\n%s' % (self.model_name, ''.join(self.result)))

    def fast_evaluation(self, model, epoch, user_embed, item_embed, kwargs=None):
        print('Evaluating the model...')
        s_test = time.time()
        rec_list = self.test(user_embed, item_embed)
        e_test = time.time() 
        print("Test time: %f s" % (e_test - s_test))
        
        s_measure = time.time()
        measure = ranking_evaluation(self.data.test_set, rec_list, [self.max_N])
        e_measure = time.time()
        print("Measure time: %f s" % (e_measure - s_measure))
        
        if len(self.bestPerformance) > 0:
            count = 0
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            for k in self.bestPerformance[1]:
                if self.bestPerformance[1][k] > performance[k]:
                    count += 1
                else:
                    count -= 1
            if count < 0:
                self.bestPerformance[1] = performance
                self.bestPerformance[0] = epoch + 1
                try:
                    self.save( model, kwargs)
                except:
                    self.save( model)
        else:
            self.bestPerformance.append(epoch + 1)
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            self.bestPerformance.append(performance)
            try:
                self.save( model, kwargs)
            except:
                self.save( model)
        print('-' * 120)
        print('Real-Time Ranking Performance ' + ' (Top-' + str(self.max_N) + ' Item Recommendation)')
        measure = [m.strip() for m in measure[1:]]
        print('*Current Performance*')
        print('Epoch:', str(epoch + 1) + ',', '  |  '.join(measure))
        bp = ''
        # for k in self.bestPerformance[1]:
        #     bp+=k+':'+str(self.bestPerformance[1][k])+' | '
        bp += 'Hit Ratio' + ':' + str(self.bestPerformance[1]['Hit Ratio']) + '  |  '
        bp += 'Precision' + ':' + str(self.bestPerformance[1]['Precision']) + '  |  '
        bp += 'Recall' + ':' + str(self.bestPerformance[1]['Recall']) + '  |  '
        # bp += 'F1' + ':' + str(self.bestPerformance[1]['F1']) + ' | '
        bp += 'NDCG' + ':' + str(self.bestPerformance[1]['NDCG'])
        print('*Best Performance* ')
        print('Epoch:fast_evaluation', str(self.bestPerformance[0]) + ',', bp)
        print('-' * 120)    
        
             
        performance_ep = {
            'Epoch': epoch,
            'Hit Ratio': str(self.bestPerformance[1]['Hit Ratio']),
            'Precision': str(self.bestPerformance[1]['Precision']),
            'Recall': str(self.bestPerformance[1]['Recall']),
            'NDCG': str(self.bestPerformance[1]['NDCG']),
            'Measure Time': e_measure - s_measure
        }
        
        return measure, performance_ep

    def save(self, model):
        self.save_model(model)
        
    def save_model(self, model):
        current_time = strftime("%Y-%m-%d", localtime(time.time()))
        out_dir = self.output_path
        file_name =  self.config['model.name'] + '@' + current_time + '-weight' + '.pth'
        weight_file = out_dir + '/' + file_name 
        torch.save(model.state_dict(), weight_file)

    def save_loss(self, train_losses, rec_losses, reg_losses, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
    
        df_train_loss = pd.DataFrame(train_losses, columns = ['ep', 'loss'])
        df_rec_loss = pd.DataFrame(rec_losses, columns = ['ep', 'loss'])
        df_reg_loss = pd.DataFrame(reg_losses, columns = ['ep', 'loss'])
        
        df_train_loss.to_csv(out_dir + '/train_loss.csv')
        df_rec_loss.to_csv(out_dir + '/rec_loss.csv')
        df_reg_loss.to_csv(out_dir + '/reg_loss.csv')

    def save_perfomance_training(self, log_train, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
        
        df_train_log = pd.DataFrame(log_train)
        df_train_log.to_csv(out_dir + '/train_performance.csv')
    
    def save_performance_test(self, log_test, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
        
        df_test_log = pd.DataFrame(log_test)
        df_test_log.to_csv(out_dir + '/test_performance.csv')

# %%
class HCCFEncoder(nn.Module):
    def __init__(self, data, emb_size, n_layers, hyperedge_num, leaky, drop_rate):
        super(HCCFEncoder, self).__init__()
        self.data = data
        self.leaky = leaky
        self.n_layers = n_layers
        self.drop_rate = drop_rate
        self.gcnlayer = GCNLayer(self.leaky)
        self.hgnnlayer = HGNNLayer(self.leaky)
        self.norm_adj = data.norm_adj
        self.latent_size = emb_size
        self.n_edges = hyperedge_num
        self.sparse_norm_adj = TorchGraphInterface.convert_sparse_mat_to_tensor(self.norm_adj).to(device)
        self.embedding_dict = self._init_model()
        self.drop_out = nn.Dropout(self.drop_rate)
        self.edgeDropper = SpAdjDropEdge()

    def _init_model(self):
        initializer = nn.init.xavier_uniform_
        embedding_dict = nn.ParameterDict({
            'user_emb': nn.Parameter(initializer(torch.empty(self.data.n_users, self.latent_size)).to(device)),
            'item_emb': nn.Parameter(initializer(torch.empty(self.data.n_items, self.latent_size)).to(device)),
            'user_w': nn.Parameter(initializer(torch.empty(self.latent_size, self.n_edges)).to(device)),
            'item_w': nn.Parameter(initializer(torch.empty(self.latent_size, self.n_edges)).to(device))
        })

#         embedding_dict = nn.ParameterDict({
#             'user_emb': nn.Parameter(torch.empty(self.data.n_users, self.latent_size).to(device)),
#             'item_emb': nn.Parameter(torch.empty(self.data.n_items, self.latent_size).to(device)),
#             'user_w': nn.Parameter(torch.empty(self.latent_size, self.n_edges).to(device)),
#             'item_w': nn.Parameter(torch.empty(self.latent_size, self.n_edges).to(device))
#         })
        
        return embedding_dict
        
    def forward(self):
        embeddings = torch.cat([self.embedding_dict['user_emb'], self.embedding_dict['item_emb']], 0)
        hidden = [embeddings]
        gcn_hidden = []
        hgnn_hidden = []
#         hyper_uu = torch.mm(self.embedding_dict['user_emb'], self.embedding_dict['user_w'])
#         hyper_ii = torch.mm(self.embedding_dict['item_emb'], self.embedding_dict['item_w'])
        
        hyper_uu = self.embedding_dict['user_emb'] @ self.embedding_dict['user_w']
        hyper_ii = self.embedding_dict['item_emb'] @self.embedding_dict['item_w']
        
        for i in range(self.n_layers):
            gcn_emb = self.gcnlayer(self.edgeDropper(self.sparse_norm_adj, 0.5), hidden[-1]) 
            hyper_uemb = self.hgnnlayer(self.drop_out(hyper_uu), hidden[-1][:self.data.n_users])
            hyper_iemb = self.hgnnlayer(self.drop_out(hyper_ii), hidden[-1][self.data.n_users:])
            gcn_hidden += [gcn_emb]
            hgnn_hidden += [torch.cat([hyper_uemb, hyper_iemb], 0)]
            hidden += [gcn_emb + hgnn_hidden[-1]]
            
        embeddings = sum(hidden)
        
        user_emb = embeddings[:self.data.n_users]
        item_emb = embeddings[self.data.n_users:]
        
        return user_emb, item_emb, gcn_hidden, hgnn_hidden
        
class GCNLayer(nn.Module):
    def __init__(self, leaky):
        super(GCNLayer, self).__init__()
        self.act = nn.LeakyReLU(negative_slope=leaky)
        
    def forward(self, adj, embeds):
        return (torch.sparse.mm(adj, embeds))
    
class HGNNLayer(nn.Module):
    def __init__(self, leaky):
        super(HGNNLayer, self).__init__()
        self.act = nn.LeakyReLU(negative_slope=leaky)
    
    def forward(self, adj, embeds):
        #edge_embeds = self.act(torch.mm(adj.T, embeds))
        #hyper_embeds = self.act(torch.mm(adj, edge_embeds))
        edge_embeds = torch.mm(adj.T, embeds)
        hyper_embeds = torch.mm(adj, edge_embeds)
        return hyper_embeds
    
class SpAdjDropEdge(nn.Module):
	def __init__(self):
		super(SpAdjDropEdge, self).__init__()

	def forward(self, adj, keepRate):
		if keepRate == 1.0:
			return adj
		vals = adj._values()
		idxs = adj._indices()
		edgeNum = vals.size()
		mask = ((torch.rand(edgeNum) + keepRate).floor()).type(torch.bool)
		newVals = vals[mask] / keepRate
		newIdxs = idxs[:, mask]
		return torch.sparse.FloatTensor(newIdxs, newVals, adj.shape)

# %%
def contrastLoss(embeds1, embeds2, nodes, temp):
	embeds1 = F.normalize(embeds1 + 1e-8, p=2)
	embeds2 = F.normalize(embeds2 + 1e-8, p=2)
	pckEmbeds1 = embeds1
	pckEmbeds2 = embeds2
	nume = torch.exp(torch.sum(pckEmbeds1 * pckEmbeds2, dim=-1) / temp)
	deno = torch.exp(pckEmbeds1 @ pckEmbeds2.T / temp).sum(-1) + 1e-8
	return -torch.log(nume / deno).mean()

# %%
def calcLosses(ancs, poss, negs, gcnEmbedsLst, hyperEmbedsLst):
    bprLoss = bpr_loss(ancs, poss, negs)

    sslLoss = 0
    for i in range(args['n_layers']):
        embeds1 = gcnEmbedsLst[i].detach()
        embeds2 = hyperEmbedsLst[i]
        sslLoss += contrastLoss(embeds1[:rec.data.n_users], embeds2[:rec.data.n_users], torch.unique(ancs.long()), 1) + contrastLoss(embeds1[rec.data.n_users:], embeds2[rec.data.n_users:], torch.unique(poss), 1)
        
    return bprLoss, sslLoss

# %%
def predict(u, rec, user_emb, item_emb):
    user_id  = rec.data.get_user_id(u)
    score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
    return score.cpu().numpy()

# %% [markdown]
# ## Train

# %%
def train(hyper_params):
    performance_dict = {'Epoch':[], 
                        'Hit Ratio': [], 
                        'Precision':[], 
                        'Recall': [],
                        'NDCG': [], 
                        'Measure Time': []}
    total_train_losses = []
    total_rec_losses = []
    total_reg_losses = []
    
    for ep in range(200):
        train_losses = []
        rec_losses = []
        reg_losses = []
        
        for n, batch in enumerate(next_batch_pairwise(rec.data, batchSize)):
            user_idx, pos_idx, neg_idx = batch
            train_model.train()
            user_emb, item_emb, gcnEmbedsLst, hyperEmbedsLst = train_model()

            anchor_emb = user_emb[user_idx]
            pos_emb = item_emb[pos_idx]
            neg_emb = item_emb[neg_idx]
            
            loss_rec, loss_reg = calcLosses(anchor_emb, pos_emb, neg_emb, gcnEmbedsLst, hyperEmbedsLst)
    #         print(f"Loss rec: {loss_rec}; Loss reg: {loss_reg}")
            
            batch_loss = loss_rec + loss_reg 
            #total_train_losses.append([loss_rec.item(), loss_reg.item(), batch_loss.item()])
            train_losses.append(batch_loss.item())
            rec_losses.append(loss_rec.item())
            reg_losses.append(loss_reg.item())
            
    #         print(f"Batch loss: {batch_loss}")
            optimizer.zero_grad()
            batch_loss.backward()

    #        torch.nn.utils.clip_grad_norm_(train_model.parameters(), 4)
            optimizer.step()
        
        batch_train_loss = np.mean(train_losses)
        batch_rec_loss = np.mean(rec_losses)
        batch_reg_loss = np.mean(reg_losses)
        
        total_train_losses.append([ep, batch_train_loss])
        total_rec_losses.append([ep, batch_rec_loss])
        total_reg_losses.append([ep, batch_reg_loss])
        scheduler.step(batch_train_loss)
        
        # Evaluation
        train_model.eval()
        with torch.no_grad():
            user_emb, item_emb, gcnEmbedsLst, hyperEmbedsLst = train_model()
            measure, performance_ep = rec.fast_evaluation(train_model, ep, user_emb, item_emb)
            for key, value in performance_ep.items():
                if key in performance_dict:
                    performance_dict[key].append(value)
                else:
                    continue
          
    rec.save_model(train_model, hyper_params)
    rec.save_loss(total_train_losses, total_rec_losses, total_reg_losses, hyper_params)
    rec.save_perfomance_training(performance_dict, hyper_params)
    
    
#         df_train = df_train.append(new_data, ignore_index=True)
#     current_time = datetime.now()
#     df_train.to_csv('results/'+ model + '/' + model+'@' + idx + '_train_['+ params + ']'+ str(current_time) +'.csv', index=False)
    
    return user_emb, item_emb

# %% [markdown]
# ## Test

# %%
def test(rec, user_emb, item_emb, hyper_params):
    
    def process_bar(num, total):
        rate = float(num) / total
        ratenum = int(50 * rate)
        r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
        sys.stdout.write(r)
        sys.stdout.flush()

    # predict
    rec_list = {}
    user_count = len(rec.data.test_set)
    for i, user in enumerate(rec.data.test_set):
        # s_find_candidates = time.time()
        candidates = predict(user, rec, user_emb, item_emb)
        # e_find_candidates = time.time()
        # print("Calculate candidates time: %f s" % (e_find_candidates - s_find_candidates))
        # predictedItems = denormalize(predictedItems, self.data.rScale[-1], self.data.rScale[0])
        rated_list, li = rec.data.user_rated(user)
        for item in rated_list:
            candidates[rec.data.item[item]] = -10e8

        # s_find_k_largest = time.time()
        ids, scores = find_k_largest(rec.max_N, candidates)
        # e_find_k_largest = time.time()
        # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
        item_names = [rec.data.id2item[iid] for iid in ids]
        rec_list[user] = list(zip(item_names, scores))
        if i % 1000 == 0:
            process_bar(i, user_count)
    process_bar(user_count, user_count)
    print('')
    result = ranking_evaluation(rec.data.test_set, rec_list, rec.topN)
    print(result)
    rec.save_performance_test(result, hyper_params)
    
#     df_test = pd.DataFrame(new_data, index=[0])
#     current_time = datetime.now()
#     path = 'results/' + model + '/' + model + ' ' + str(current_time)
#     file_path = path + '/' + model+'@' + str(idx) + '_test_'+ str(params) + ''+ str(current_time) +'.csv'
#     df_test.to_csv(file_path, index=False)

# %% [markdown]
# ## Main

# %%
model = 'HCCF'
if model not in ['HGNN', 'LightGCN', 'HCCF', 'DHCF']:
    print("No model found.")
config = ModelConf('./conf/' + model + '.conf')

dataset = 'alibaba-fashion'
batchSize = int(config['batch_size'])
maxEpoch = 500
lRates = [0.01]
lrDecays = [0.7]
regs = [ 0.0001]
hyperDims = [ 128]
inputDims = [32]
ps = [0.1]
dropRates = [0.1]
nLayers = [2]
hyperedge_num = [ 128]

if dataset == 'lastfm':
    training_set = "./dataset/lastfm/train.txt"
    test_set = './dataset/lastfm/test.txt'
elif dataset == 'ml-1m':
    training_set = './dataset/ml-1m/train.txt'
    test_set = './dataset/ml-1m/test.txt'
elif dataset == 'alibaba-fashion':
    training_set = "./dataset/alibaba-fashion/train.txt"
    test_set = './dataset/alibaba-fashion/test.txt'
hyperparameters = [lRates, lrDecays, regs, hyperDims, inputDims, ps, dropRates, nLayers, hyperedge_num, dataset]

# %%
reg = 0.01
args = {
    'p':  0.1,
    'drop_rate': 0.5,
    'n_layers': 2,
    'input_dim': 32,
    'hyper_dim': 128,
    'hyperedge_num': 128,
    'lr': 0.001,
    'reg': reg,
    'leaky': 0.5,
    'dataset': dataset,
    'item_ranking': "20,40",
    "batch_size": 2048,
}

default_dir = f"./dataset/{config['dataset']}/"
training_data = FileIO.load_data_set(training_set, config['model.type'])
test_data = FileIO.load_data_set(test_set, config['model.type'])
knowledge_data = FileIO.load_kg_data(default_dir + f"{config['dataset']}.kg")


args['output_path'] =  f"./results/HCCF/{dataset}/@HCCF-inp_emb:{args['input_dim']}-emb:{args['hyper_dim']}-bs:{args['batch_size']}-lr:{args['lr']}--n_layers:{args['n_layers']}/"
if not os.path.exists(args['output_path']):
    os.makedirs(args['output_path'])

rec = GraphRecommender(config, training_data, test_data, knowledge_data, **args)
if model == 'HGNN':
    train_model = Model(rec.config, rec.data, args).to(device)
elif model == 'LightGCN':
    train_model = LGCN_Encoder(rec.data, args['input_dim'], args['n_layers'])
elif model == 'HCCF':
    train_model = HCCFEncoder(rec.data, args['input_dim'], args['n_layers'], args['hyperedge_num'], args['leaky'], args['drop_rate'])

optimizer  = torch.optim.Adam(train_model.parameters(), lr=args['lr'], weight_decay=0.001)
scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5)
user_emb, item_emb = train(args)
test(rec, user_emb, item_emb, args)
# Out:
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.167515 s
# Measure time: 0.159076 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 1, Hit Ratio:0.00668  |  Precision:0.00066  |  Recall:0.00621  |  NDCG:0.00296
# *Best Performance*
# Epoch:fast_evaluation 1, Hit Ratio:0.00668  |  Precision:0.00066  |  Recall:0.00621  |  NDCG:0.00296
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.030564 s
# Measure time: 0.161262 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 2, Hit Ratio:0.01998  |  Precision:0.00198  |  Recall:0.01963  |  NDCG:0.00902
# *Best Performance*
# Epoch:fast_evaluation 2, Hit Ratio:0.01998  |  Precision:0.00198  |  Recall:0.01963  |  NDCG:0.00902
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.072669 s
# Measure time: 0.174130 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 3, Hit Ratio:0.0281  |  Precision:0.00279  |  Recall:0.02854  |  NDCG:0.01331
# *Best Performance*
# Epoch:fast_evaluation 3, Hit Ratio:0.0281  |  Precision:0.00279  |  Recall:0.02854  |  NDCG:0.01331
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.075545 s
# Measure time: 0.157866 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 4, Hit Ratio:0.0324  |  Precision:0.00322  |  Recall:0.03227  |  NDCG:0.01619
# *Best Performance*
# Epoch:fast_evaluation 4, Hit Ratio:0.0324  |  Precision:0.00322  |  Recall:0.03227  |  NDCG:0.01619
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.864937 s
# Measure time: 0.153162 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 5, Hit Ratio:0.03747  |  Precision:0.00372  |  Recall:0.03793  |  NDCG:0.01907
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.03747  |  Precision:0.00372  |  Recall:0.03793  |  NDCG:0.01907
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.003936 s
# Measure time: 0.155847 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 6, Hit Ratio:0.04361  |  Precision:0.00433  |  Recall:0.04488  |  NDCG:0.02197
# *Best Performance*
# Epoch:fast_evaluation 6, Hit Ratio:0.04361  |  Precision:0.00433  |  Recall:0.04488  |  NDCG:0.02197
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.942407 s
# Measure time: 0.156347 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 7, Hit Ratio:0.04855  |  Precision:0.00482  |  Recall:0.05  |  NDCG:0.02476
# *Best Performance*
# Epoch:fast_evaluation 7, Hit Ratio:0.04855  |  Precision:0.00482  |  Recall:0.05  |  NDCG:0.02476
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.038625 s
# Measure time: 0.155776 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 8, Hit Ratio:0.04971  |  Precision:0.00494  |  Recall:0.05051  |  NDCG:0.0253
# *Best Performance*
# Epoch:fast_evaluation 8, Hit Ratio:0.04971  |  Precision:0.00494  |  Recall:0.05051  |  NDCG:0.0253
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.999284 s
# Measure time: 0.162164 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 9, Hit Ratio:0.05473  |  Precision:0.00543  |  Recall:0.05601  |  NDCG:0.02806
# *Best Performance*
# Epoch:fast_evaluation 9, Hit Ratio:0.05473  |  Precision:0.00543  |  Recall:0.05601  |  NDCG:0.02806
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.058405 s
# Measure time: 0.153058 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 10, Hit Ratio:0.05592  |  Precision:0.00555  |  Recall:0.05878  |  NDCG:0.02882
# *Best Performance*
# Epoch:fast_evaluation 10, Hit Ratio:0.05592  |  Precision:0.00555  |  Recall:0.05878  |  NDCG:0.02882
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.042418 s
# Measure time: 0.156127 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 11, Hit Ratio:0.06074  |  Precision:0.00603  |  Recall:0.0633  |  NDCG:0.03131
# *Best Performance*
# Epoch:fast_evaluation 11, Hit Ratio:0.06074  |  Precision:0.00603  |  Recall:0.0633  |  NDCG:0.03131
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.352106 s
# Measure time: 0.155545 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 12, Hit Ratio:0.06247  |  Precision:0.0062  |  Recall:0.0649  |  NDCG:0.03193
# *Best Performance*
# Epoch:fast_evaluation 12, Hit Ratio:0.06247  |  Precision:0.0062  |  Recall:0.0649  |  NDCG:0.03193
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.144525 s
# Measure time: 0.164138 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 13, Hit Ratio:0.06361  |  Precision:0.00631  |  Recall:0.06517  |  NDCG:0.03229
# *Best Performance*
# Epoch:fast_evaluation 13, Hit Ratio:0.06361  |  Precision:0.00631  |  Recall:0.06517  |  NDCG:0.03229
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.038208 s
# Measure time: 0.155114 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 14, Hit Ratio:0.06602  |  Precision:0.00655  |  Recall:0.06902  |  NDCG:0.0341
# *Best Performance*
# Epoch:fast_evaluation 14, Hit Ratio:0.06602  |  Precision:0.00655  |  Recall:0.06902  |  NDCG:0.0341
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.063808 s
# Measure time: 0.156291 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 15, Hit Ratio:0.0663  |  Precision:0.00658  |  Recall:0.06921  |  NDCG:0.03421
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.0663  |  Precision:0.00658  |  Recall:0.06921  |  NDCG:0.03421
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.923985 s
# Measure time: 0.152951 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 16, Hit Ratio:0.06796  |  Precision:0.00675  |  Recall:0.07014  |  NDCG:0.03475
# *Best Performance*
# Epoch:fast_evaluation 16, Hit Ratio:0.06796  |  Precision:0.00675  |  Recall:0.07014  |  NDCG:0.03475
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.085567 s
# Measure time: 0.161427 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 17, Hit Ratio:0.07005  |  Precision:0.00695  |  Recall:0.07291  |  NDCG:0.03721
# *Best Performance*
# Epoch:fast_evaluation 17, Hit Ratio:0.07005  |  Precision:0.00695  |  Recall:0.07291  |  NDCG:0.03721
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.090189 s
# Measure time: 0.163672 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 18, Hit Ratio:0.07042  |  Precision:0.00699  |  Recall:0.07281  |  NDCG:0.03751
# *Best Performance*
# Epoch:fast_evaluation 18, Hit Ratio:0.07042  |  Precision:0.00699  |  Recall:0.07281  |  NDCG:0.03751
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.019550 s
# Measure time: 0.156202 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 19, Hit Ratio:0.07067  |  Precision:0.00702  |  Recall:0.07353  |  NDCG:0.03738
# *Best Performance*
# Epoch:fast_evaluation 19, Hit Ratio:0.07067  |  Precision:0.00702  |  Recall:0.07353  |  NDCG:0.03738
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.030516 s
# Measure time: 0.154333 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 20, Hit Ratio:0.07073  |  Precision:0.00702  |  Recall:0.07545  |  NDCG:0.03768
# *Best Performance*
# Epoch:fast_evaluation 20, Hit Ratio:0.07073  |  Precision:0.00702  |  Recall:0.07545  |  NDCG:0.03768
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.048369 s
# Measure time: 0.154864 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 21, Hit Ratio:0.07295  |  Precision:0.00724  |  Recall:0.07685  |  NDCG:0.03898
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.07295  |  Precision:0.00724  |  Recall:0.07685  |  NDCG:0.03898
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.337239 s
# Measure time: 0.150703 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 22, Hit Ratio:0.07174  |  Precision:0.00712  |  Recall:0.07527  |  NDCG:0.03804
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.07295  |  Precision:0.00724  |  Recall:0.07685  |  NDCG:0.03898
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.968926 s
# Measure time: 0.165132 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 23, Hit Ratio:0.07456  |  Precision:0.0074  |  Recall:0.07839  |  NDCG:0.03926
# *Best Performance*
# Epoch:fast_evaluation 23, Hit Ratio:0.07456  |  Precision:0.0074  |  Recall:0.07839  |  NDCG:0.03926
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.087683 s
# Measure time: 0.161172 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 24, Hit Ratio:0.0722  |  Precision:0.00717  |  Recall:0.07556  |  NDCG:0.03864
# *Best Performance*
# Epoch:fast_evaluation 23, Hit Ratio:0.07456  |  Precision:0.0074  |  Recall:0.07839  |  NDCG:0.03926
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.996664 s
# Measure time: 0.153991 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 25, Hit Ratio:0.07458  |  Precision:0.0074  |  Recall:0.0782  |  NDCG:0.03891
# *Best Performance*
# Epoch:fast_evaluation 23, Hit Ratio:0.07456  |  Precision:0.0074  |  Recall:0.07839  |  NDCG:0.03926
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.987850 s
# Measure time: 0.153071 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 26, Hit Ratio:0.07606  |  Precision:0.00755  |  Recall:0.07933  |  NDCG:0.04032
# *Best Performance*
# Epoch:fast_evaluation 26, Hit Ratio:0.07606  |  Precision:0.00755  |  Recall:0.07933  |  NDCG:0.04032
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.035373 s
# Measure time: 0.153670 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 27, Hit Ratio:0.07696  |  Precision:0.00764  |  Recall:0.08014  |  NDCG:0.04071
# *Best Performance*
# Epoch:fast_evaluation 27, Hit Ratio:0.07696  |  Precision:0.00764  |  Recall:0.08014  |  NDCG:0.04071
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.846095 s
# Measure time: 0.153466 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 28, Hit Ratio:0.07709  |  Precision:0.00765  |  Recall:0.07944  |  NDCG:0.04052
# *Best Performance*
# Epoch:fast_evaluation 27, Hit Ratio:0.07696  |  Precision:0.00764  |  Recall:0.08014  |  NDCG:0.04071
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.019946 s
# Measure time: 0.153322 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 29, Hit Ratio:0.07849  |  Precision:0.00779  |  Recall:0.08252  |  NDCG:0.04188
# *Best Performance*
# Epoch:fast_evaluation 29, Hit Ratio:0.07849  |  Precision:0.00779  |  Recall:0.08252  |  NDCG:0.04188
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.932969 s
# Measure time: 0.152551 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 30, Hit Ratio:0.0772  |  Precision:0.00766  |  Recall:0.08063  |  NDCG:0.04067
# *Best Performance*
# Epoch:fast_evaluation 29, Hit Ratio:0.07849  |  Precision:0.00779  |  Recall:0.08252  |  NDCG:0.04188
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.032476 s
# Measure time: 0.159215 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 31, Hit Ratio:0.07676  |  Precision:0.00762  |  Recall:0.08079  |  NDCG:0.04102
# *Best Performance*
# Epoch:fast_evaluation 29, Hit Ratio:0.07849  |  Precision:0.00779  |  Recall:0.08252  |  NDCG:0.04188
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.981968 s
# Measure time: 0.157501 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.229856 s
# Measure time: 0.152337 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 33, Hit Ratio:0.07797  |  Precision:0.00774  |  Recall:0.08129  |  NDCG:0.04114
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.919398 s
# Measure time: 0.154955 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 34, Hit Ratio:0.07971  |  Precision:0.00791  |  Recall:0.08323  |  NDCG:0.04213
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.075207 s
# Measure time: 0.153365 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 35, Hit Ratio:0.07833  |  Precision:0.00778  |  Recall:0.08285  |  NDCG:0.04207
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.044357 s
# Measure time: 0.162019 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 36, Hit Ratio:0.07751  |  Precision:0.00769  |  Recall:0.08094  |  NDCG:0.04123
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.854333 s
# Measure time: 0.150338 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 37, Hit Ratio:0.07784  |  Precision:0.00773  |  Recall:0.08227  |  NDCG:0.04157
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.077024 s
# Measure time: 0.155793 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 38, Hit Ratio:0.07789  |  Precision:0.00773  |  Recall:0.08218  |  NDCG:0.04148
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.923574 s
# Measure time: 0.152421 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 39, Hit Ratio:0.07802  |  Precision:0.00775  |  Recall:0.08259  |  NDCG:0.04163
# *Best Performance*
# Epoch:fast_evaluation 32, Hit Ratio:0.08048  |  Precision:0.00799  |  Recall:0.08387  |  NDCG:0.04198
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.050142 s
# Measure time: 0.154222 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 40, Hit Ratio:0.08059  |  Precision:0.008  |  Recall:0.08555  |  NDCG:0.04279
# *Best Performance*
# Epoch:fast_evaluation 40, Hit Ratio:0.08059  |  Precision:0.008  |  Recall:0.08555  |  NDCG:0.04279
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.928327 s
# Measure time: 0.148147 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 41, Hit Ratio:0.07864  |  Precision:0.00781  |  Recall:0.08249  |  NDCG:0.0424
# *Best Performance*
# Epoch:fast_evaluation 40, Hit Ratio:0.08059  |  Precision:0.008  |  Recall:0.08555  |  NDCG:0.04279
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.867504 s
# Measure time: 0.146662 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 42, Hit Ratio:0.07981  |  Precision:0.00792  |  Recall:0.08373  |  NDCG:0.04186
# *Best Performance*
# Epoch:fast_evaluation 40, Hit Ratio:0.08059  |  Precision:0.008  |  Recall:0.08555  |  NDCG:0.04279
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.345723 s
# Measure time: 0.142878 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# *Best Performance*
# Epoch:fast_evaluation 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.863112 s
# Measure time: 0.145970 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 44, Hit Ratio:0.08064  |  Precision:0.00801  |  Recall:0.08381  |  NDCG:0.04237
# *Best Performance*
# Epoch:fast_evaluation 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.987715 s
# Measure time: 0.150259 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 45, Hit Ratio:0.0809  |  Precision:0.00803  |  Recall:0.08444  |  NDCG:0.04275
# *Best Performance*
# Epoch:fast_evaluation 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.871222 s
# Measure time: 0.146371 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 46, Hit Ratio:0.08077  |  Precision:0.00802  |  Recall:0.08502  |  NDCG:0.0425
# *Best Performance*
# Epoch:fast_evaluation 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.003640 s
# Measure time: 0.150662 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 47, Hit Ratio:0.0809  |  Precision:0.00803  |  Recall:0.08461  |  NDCG:0.04261
# *Best Performance*
# Epoch:fast_evaluation 43, Hit Ratio:0.08069  |  Precision:0.00801  |  Recall:0.0854  |  NDCG:0.04355
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.965564 s
# Measure time: 0.147200 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 48, Hit Ratio:0.08121  |  Precision:0.00806  |  Recall:0.08599  |  NDCG:0.04375
# *Best Performance*
# Epoch:fast_evaluation 48, Hit Ratio:0.08121  |  Precision:0.00806  |  Recall:0.08599  |  NDCG:0.04375
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.000252 s
# Measure time: 0.148839 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 49, Hit Ratio:0.08297  |  Precision:0.00824  |  Recall:0.08759  |  NDCG:0.04415
# *Best Performance*
# Epoch:fast_evaluation 49, Hit Ratio:0.08297  |  Precision:0.00824  |  Recall:0.08759  |  NDCG:0.04415
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.084875 s
# Measure time: 0.157572 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 50, Hit Ratio:0.08439  |  Precision:0.00838  |  Recall:0.08872  |  NDCG:0.04492
# *Best Performance*
# Epoch:fast_evaluation 50, Hit Ratio:0.08439  |  Precision:0.00838  |  Recall:0.08872  |  NDCG:0.04492
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.906084 s
# Measure time: 0.148532 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 51, Hit Ratio:0.08488  |  Precision:0.00843  |  Recall:0.08954  |  NDCG:0.045
# *Best Performance*
# Epoch:fast_evaluation 51, Hit Ratio:0.08488  |  Precision:0.00843  |  Recall:0.08954  |  NDCG:0.045
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.865209 s
# Measure time: 0.153260 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.885454 s
# Measure time: 0.145896 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 53, Hit Ratio:0.0847  |  Precision:0.00841  |  Recall:0.08959  |  NDCG:0.04546
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.975969 s
# Measure time: 0.147302 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 54, Hit Ratio:0.08289  |  Precision:0.00823  |  Recall:0.08775  |  NDCG:0.04446
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.265475 s
# Measure time: 0.145954 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 55, Hit Ratio:0.08473  |  Precision:0.00841  |  Recall:0.08943  |  NDCG:0.04638
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.850539 s
# Measure time: 0.153239 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 56, Hit Ratio:0.0861  |  Precision:0.00855  |  Recall:0.09074  |  NDCG:0.04675
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.982469 s
# Measure time: 0.150710 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 57, Hit Ratio:0.08615  |  Precision:0.00855  |  Recall:0.09148  |  NDCG:0.04662
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.866963 s
# Measure time: 0.145670 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 58, Hit Ratio:0.08615  |  Precision:0.00855  |  Recall:0.09037  |  NDCG:0.0466
# *Best Performance*
# Epoch:fast_evaluation 52, Hit Ratio:0.08677  |  Precision:0.00861  |  Recall:0.09122  |  NDCG:0.04524
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.850602 s
# Measure time: 0.143771 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.988904 s
# Measure time: 0.147519 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 60, Hit Ratio:0.08687  |  Precision:0.00862  |  Recall:0.09319  |  NDCG:0.04751
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.772909 s
# Measure time: 0.142582 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 61, Hit Ratio:0.08654  |  Precision:0.00859  |  Recall:0.09073  |  NDCG:0.04613
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.935614 s
# Measure time: 0.154113 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 62, Hit Ratio:0.08625  |  Precision:0.00856  |  Recall:0.09027  |  NDCG:0.04639
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.962706 s
# Measure time: 0.147647 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 63, Hit Ratio:0.08674  |  Precision:0.00861  |  Recall:0.09109  |  NDCG:0.04602
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.795429 s
# Measure time: 0.149778 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 64, Hit Ratio:0.08592  |  Precision:0.00853  |  Recall:0.08993  |  NDCG:0.04614
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.150744 s
# Measure time: 0.166640 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 65, Hit Ratio:0.08654  |  Precision:0.00859  |  Recall:0.0909  |  NDCG:0.04771
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.319856 s
# Measure time: 0.157730 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 66, Hit Ratio:0.08651  |  Precision:0.00859  |  Recall:0.09137  |  NDCG:0.04737
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.995379 s
# Measure time: 0.155392 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 67, Hit Ratio:0.08631  |  Precision:0.00857  |  Recall:0.09074  |  NDCG:0.04651
# *Best Performance*
# Epoch:fast_evaluation 59, Hit Ratio:0.08765  |  Precision:0.0087  |  Recall:0.09261  |  NDCG:0.04719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.010100 s
# Measure time: 0.159457 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 68, Hit Ratio:0.08887  |  Precision:0.00882  |  Recall:0.09381  |  NDCG:0.04821
# *Best Performance*
# Epoch:fast_evaluation 68, Hit Ratio:0.08887  |  Precision:0.00882  |  Recall:0.09381  |  NDCG:0.04821
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.019009 s
# Measure time: 0.152079 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 69, Hit Ratio:0.08853  |  Precision:0.00879  |  Recall:0.09301  |  NDCG:0.0471
# *Best Performance*
# Epoch:fast_evaluation 68, Hit Ratio:0.08887  |  Precision:0.00882  |  Recall:0.09381  |  NDCG:0.04821
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.021483 s
# Measure time: 0.151983 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 70, Hit Ratio:0.08946  |  Precision:0.00888  |  Recall:0.09403  |  NDCG:0.04729
# *Best Performance*
# Epoch:fast_evaluation 70, Hit Ratio:0.08946  |  Precision:0.00888  |  Recall:0.09403  |  NDCG:0.04729
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.953560 s
# Measure time: 0.152893 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 71, Hit Ratio:0.08938  |  Precision:0.00887  |  Recall:0.094  |  NDCG:0.04763
# *Best Performance*
# Epoch:fast_evaluation 70, Hit Ratio:0.08946  |  Precision:0.00888  |  Recall:0.09403  |  NDCG:0.04729
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.235405 s
# Measure time: 0.150194 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 72, Hit Ratio:0.08812  |  Precision:0.00875  |  Recall:0.09158  |  NDCG:0.04664
# ...
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.792260 s
# Measure time: 0.149945 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.992785 s
# Measure time: 0.162679 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 182, Hit Ratio:0.10414  |  Precision:0.01034  |  Recall:0.10903  |  NDCG:0.0563
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.916596 s
# Measure time: 0.154947 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 183, Hit Ratio:0.10468  |  Precision:0.01039  |  Recall:0.10932  |  NDCG:0.0566
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.848139 s
# Measure time: 0.152522 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 184, Hit Ratio:0.10414  |  Precision:0.01034  |  Recall:0.10951  |  NDCG:0.05661
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.109097 s
# Measure time: 0.156751 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 185, Hit Ratio:0.10393  |  Precision:0.01032  |  Recall:0.10866  |  NDCG:0.05666
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.078524 s
# Measure time: 0.153890 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 186, Hit Ratio:0.10439  |  Precision:0.01036  |  Recall:0.10992  |  NDCG:0.05736
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.885864 s
# Measure time: 0.153220 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 187, Hit Ratio:0.10478  |  Precision:0.0104  |  Recall:0.10935  |  NDCG:0.05637
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.920846 s
# Measure time: 0.150631 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 188, Hit Ratio:0.10494  |  Precision:0.01042  |  Recall:0.10975  |  NDCG:0.05637
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.968746 s
# Measure time: 0.152296 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 189, Hit Ratio:0.10336  |  Precision:0.01026  |  Recall:0.10913  |  NDCG:0.05629
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.836752 s
# Measure time: 0.150449 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 190, Hit Ratio:0.10452  |  Precision:0.01038  |  Recall:0.11025  |  NDCG:0.057
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.967851 s
# Measure time: 0.454069 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 191, Hit Ratio:0.10527  |  Precision:0.01045  |  Recall:0.11126  |  NDCG:0.05731
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.930751 s
# Measure time: 0.155148 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 192, Hit Ratio:0.10507  |  Precision:0.01043  |  Recall:0.11078  |  NDCG:0.05683
# *Best Performance*
# Epoch:fast_evaluation 181, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11077  |  NDCG:0.05664
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.924052 s
# Measure time: 0.154591 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 193, Hit Ratio:0.1059  |  Precision:0.01051  |  Recall:0.11102  |  NDCG:0.05713
# *Best Performance*
# Epoch:fast_evaluation 193, Hit Ratio:0.1059  |  Precision:0.01051  |  Recall:0.11102  |  NDCG:0.05713
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.869400 s
# Measure time: 0.161887 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 194, Hit Ratio:0.10527  |  Precision:0.01045  |  Recall:0.11105  |  NDCG:0.05709
# *Best Performance*
# Epoch:fast_evaluation 193, Hit Ratio:0.1059  |  Precision:0.01051  |  Recall:0.11102  |  NDCG:0.05713
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.822318 s
# Measure time: 0.152907 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 195, Hit Ratio:0.10468  |  Precision:0.01039  |  Recall:0.11088  |  NDCG:0.05704
# *Best Performance*
# Epoch:fast_evaluation 193, Hit Ratio:0.1059  |  Precision:0.01051  |  Recall:0.11102  |  NDCG:0.05713
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.965152 s
# Measure time: 0.158494 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 196, Hit Ratio:0.10509  |  Precision:0.01043  |  Recall:0.11136  |  NDCG:0.05711
# *Best Performance*
# Epoch:fast_evaluation 193, Hit Ratio:0.1059  |  Precision:0.01051  |  Recall:0.11102  |  NDCG:0.05713
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.915398 s
# Measure time: 0.159171 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 197, Hit Ratio:0.10654  |  Precision:0.01058  |  Recall:0.11164  |  NDCG:0.05781
# *Best Performance*
# Epoch:fast_evaluation 197, Hit Ratio:0.10654  |  Precision:0.01058  |  Recall:0.11164  |  NDCG:0.05781
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.023592 s
# Measure time: 0.154787 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 198, Hit Ratio:0.10546  |  Precision:0.01047  |  Recall:0.11152  |  NDCG:0.05734
# *Best Performance*
# Epoch:fast_evaluation 197, Hit Ratio:0.10654  |  Precision:0.01058  |  Recall:0.11164  |  NDCG:0.05781
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 1.954955 s
# Measure time: 0.153879 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 199, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11073  |  NDCG:0.0579
# *Best Performance*
# Epoch:fast_evaluation 197, Hit Ratio:0.10654  |  Precision:0.01058  |  Recall:0.11164  |  NDCG:0.05781
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 2.060265 s
# Measure time: 0.150690 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-40 Item Recommendation)
# *Current Performance*
# Epoch: 200, Hit Ratio:0.10538  |  Precision:0.01046  |  Recall:0.11111  |  NDCG:0.05759
# *Best Performance*
# Epoch:fast_evaluation 197, Hit Ratio:0.10654  |  Precision:0.01058  |  Recall:0.11164  |  NDCG:0.05781
# ------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb Cell 16 line 3
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a> optimizer  = torch.optim.Adam(train_model.parameters(), lr=args['lr'], weight_decay=0.001)
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a> scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> user_emb, item_emb = train(args)
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> test(rec, user_emb, item_emb, args)
#
# /mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb Cell 16 line 6
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=58'>59</a>             else:
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a>                 continue
# ---> <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a> rec.save_model(train_model, hyper_params)
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=62'>63</a> rec.save_loss(total_train_losses, total_rec_losses, total_reg_losses, hyper_params)
#      <a href='vscode-notebook-cell://ssh-remote%2B%28aiotlabws%29/mnt/disk1/hungvv/hungvv1/recommend/SELFRec/HCCF_lastfm.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a> rec.save_perfomance_training(performance_dict, hyper_params)
#
# TypeError: save_model() takes 2 positional arguments but 3 were given
