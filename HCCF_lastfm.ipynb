# %% [markdown]
# ## HCCF

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from torch.nn.init import xavier_normal_, xavier_uniform_
import argparse
import numpy as np
import time
import sys
from os.path import abspath

from base.graph_recommender import GraphRecommender
from util.sampler import next_batch_pairwise
from util.conf import OptionConf
import torch
import torch.nn as nn 
import torch.nn.functional as F
from scipy.sparse import coo_matrix
from util.loss_torch import bpr_loss, l2_reg_loss, EmbLoss, contrastLoss
from util.init import *
from base.torch_interface import TorchGraphInterface
import os
import numpy as np 
import time 
from torch.optim.lr_scheduler import ReduceLROnPlateau
from itertools import product

from data.loader import FileIO
from util.conf import ModelConf
from base.recommender import Recommender
from data.ui_graph import Interaction
# from data.knowledge import Knowledge
from util.algorithm import find_k_largest
from time import strftime, localtime
from data.loader import FileIO
from util.evaluation import ranking_evaluation

import pandas as pd
from datetime import datetime
import csv

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
class GraphRecommender(Recommender):
    def __init__(self, conf, training_set, test_set, knowledge_data, **kwargs):
        super(GraphRecommender, self).__init__(conf, training_set, test_set, knowledge_data, **kwargs)
        self.data = Interaction(conf, training_set, test_set)
        self.bestPerformance = []
        top = self.ranking['-topN'].split(',')
        self.topN = [int(num) for num in top]
        self.max_N = max(self.topN)

    def print_model_info(self):
        super(GraphRecommender, self).print_model_info()
        # # print dataset statistics
        print('Training Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.training_size()))
        print('Test Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.test_size()))
        print('=' * 80)

    def build(self):
        pass

    def train(self):
        pass

    def predict(self, u):
        pass

    def test(self, user_emb, item_emb):
        def process_bar(num, total):
            rate = float(num) / total
            ratenum = int(50 * rate)
            r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
            sys.stdout.write(r)
            sys.stdout.flush()

        # predict
        rec_list = {}
        user_count = len(self.data.test_set)
        for i, user in enumerate(self.data.test_set):
            # s_find_candidates = time.time()
            
            
            # candidates = predict(user)
            user_id  = self.data.get_user_id(user)
            score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
            candidates = score.cpu().numpy()
            
            # e_find_candidates = time.time()
            # print("Calculate candidates time: %f s" % (e_find_candidates - s_find_candidates))
            # predictedItems = denormalize(predictedItems, self.data.rScale[-1], self.data.rScale[0])
            rated_list, li = self.data.user_rated(user)
            for item in rated_list:
                candidates[self.data.item[item]] = -10e8
            
            # s_find_k_largest = time.time()
            ids, scores = find_k_largest(self.max_N, candidates)
            # e_find_k_largest = time.time()
            # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
            item_names = [self.data.id2item[iid] for iid in ids]
            rec_list[user] = list(zip(item_names, scores))
            if i % 1000 == 0:
                process_bar(i, user_count)
        process_bar(user_count, user_count)
        print('')
        return rec_list

    def evaluate(self, rec_list):
        self.recOutput.append('userId: recommendations in (itemId, ranking score) pairs, * means the item is hit.\n')
        for user in self.data.test_set:
            line = str(user) + ':'
            for item in rec_list[user]:
                line += ' (' + str(item[0]) + ',' + str(item[1]) + ')'
                if item[0] in self.data.test_set[user]:
                    line += '*'
            line += '\n'
            self.recOutput.append(line)
        current_time = strftime("%Y-%m-%d %H-%M-%S", localtime(time.time()))
        # output prediction result
        out_dir = self.output['-dir']
        file_name = self.config['model.name'] + '@' + current_time + '-top-' + str(self.max_N) + 'items' + '.txt'
        FileIO.write_file(out_dir, file_name, self.recOutput)
        print('The result has been output to ', abspath(out_dir), '.')
        file_name = self.config['model.name'] + '@' + current_time + '-performance' + '.txt'
        self.result = ranking_evaluation(self.data.test_set, rec_list, self.topN)
        self.model_log.add('###Evaluation Results###')
        self.model_log.add(self.result)
        FileIO.write_file(out_dir, file_name, self.result)
        print('The result of %s:\n%s' % (self.model_name, ''.join(self.result)))

    def fast_evaluation(self, epoch, user_embed, item_embed, kwargs=None):
        print('Evaluating the model...')
        s_test = time.time()
        rec_list = self.test(user_embed, item_embed)
        e_test = time.time() 
        print("Test time: %f s" % (e_test - s_test))
        
        s_measure = time.time()
        measure = ranking_evaluation(self.data.test_set, rec_list, [self.max_N])
        e_measure = time.time()
        print("Measure time: %f s" % (e_measure - s_measure))
        
        if len(self.bestPerformance) > 0:
            count = 0
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            for k in self.bestPerformance[1]:
                if self.bestPerformance[1][k] > performance[k]:
                    count += 1
                else:
                    count -= 1
            if count < 0:
                self.bestPerformance[1] = performance
                self.bestPerformance[0] = epoch + 1
                try:
                    self.save(kwargs)
                except:
                    self.save()
        else:
            self.bestPerformance.append(epoch + 1)
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            self.bestPerformance.append(performance)
            try:
                self.save(kwargs)
            except:
                self.save()
        print('-' * 120)
        print('Real-Time Ranking Performance ' + ' (Top-' + str(self.max_N) + ' Item Recommendation)')
        measure = [m.strip() for m in measure[1:]]
        print('*Current Performance*')
        print('Epoch:', str(epoch + 1) + ',', '  |  '.join(measure))
        bp = ''
        # for k in self.bestPerformance[1]:
        #     bp+=k+':'+str(self.bestPerformance[1][k])+' | '
        bp += 'Hit Ratio' + ':' + str(self.bestPerformance[1]['Hit Ratio']) + '  |  '
        bp += 'Precision' + ':' + str(self.bestPerformance[1]['Precision']) + '  |  '
        bp += 'Recall' + ':' + str(self.bestPerformance[1]['Recall']) + '  |  '
        # bp += 'F1' + ':' + str(self.bestPerformance[1]['F1']) + ' | '
        bp += 'NDCG' + ':' + str(self.bestPerformance[1]['NDCG'])
        print('*Best Performance* ')
        print('Epoch:fast_evaluation', str(self.bestPerformance[0]) + ',', bp)
        print('-' * 120)    
        
             
        performance_ep = {
            'Epoch': epoch,
            'Hit Ratio': str(self.bestPerformance[1]['Hit Ratio']),
            'Precision': str(self.bestPerformance[1]['Precision']),
            'Recall': str(self.bestPerformance[1]['Recall']),
            'NDCG': str(self.bestPerformance[1]['NDCG']),
            'Measure Time': e_measure - s_measure
        }
        
        return measure, performance_ep
        
    def save_model(self, model, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        # save model 
        current_time = strftime("%Y-%m-%d", localtime(time.time()))
        out_dir = 'results/'+ str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)
        file_name =  self.config['model.name'] + '@' + current_time + '-weight' + '.pth'
        weight_file = out_dir + '/' + file_name 
        torch.save(model.state_dict(), weight_file)

    def save_loss(self, train_losses, rec_losses, reg_losses, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
    
        df_train_loss = pd.DataFrame(train_losses, columns = ['ep', 'loss'])
        df_rec_loss = pd.DataFrame(rec_losses, columns = ['ep', 'loss'])
        df_reg_loss = pd.DataFrame(reg_losses, columns = ['ep', 'loss'])
        
        df_train_loss.to_csv(out_dir + '/train_loss.csv')
        df_rec_loss.to_csv(out_dir + '/rec_loss.csv')
        df_reg_loss.to_csv(out_dir + '/reg_loss.csv')

    def save_perfomance_training(self, log_train, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
        
        df_train_log = pd.DataFrame(log_train)
        df_train_log.to_csv(out_dir + '/train_performance.csv')
    
    def save_performance_test(self, log_test, hyper_params):
        hp = list(hyper_params.values())
        hyper_params = '-p:' + str(hp[0]) + '-drop:' + str(hp[1]) + '-layers:' + str(hp[2]) + '-input_dim:' + str(hp[3]) + '-hyper_dim:' + str(hp[4]) + '-hyperedge_num:' + str(hp[5]) + 'lr:' + str(hp[6]) + 'reg:' + str(hp[7])
        out_dir = 'results/' + str(hp[9]) + '/' + self.config['model.name'] + '/' +self.config['model.name'] + hyper_params
        
        df_test_log = pd.DataFrame(log_test)
        df_test_log.to_csv(out_dir + '/test_performance.csv')

# %%
class HCCFEncoder(nn.Module):
    def __init__(self, data, emb_size, n_layers, hyperedge_num, leaky, drop_rate):
        super(HCCFEncoder, self).__init__()
        self.data = data
        self.leaky = leaky
        self.n_layers = n_layers
        self.drop_rate = drop_rate
        self.gcnlayer = GCNLayer(self.leaky)
        self.hgnnlayer = HGNNLayer(self.leaky)
        self.norm_adj = data.norm_adj
        self.latent_size = emb_size
        self.n_edges = hyperedge_num
        self.sparse_norm_adj = TorchGraphInterface.convert_sparse_mat_to_tensor(self.norm_adj).to(device)
        self.embedding_dict = self._init_model()
        self.drop_out = nn.Dropout(self.drop_rate)
        self.edgeDropper = SpAdjDropEdge()

    def _init_model(self):
        initializer = nn.init.xavier_uniform_
        embedding_dict = nn.ParameterDict({
            'user_emb': nn.Parameter(initializer(torch.empty(self.data.n_users, self.latent_size)).to(device)),
            'item_emb': nn.Parameter(initializer(torch.empty(self.data.n_items, self.latent_size)).to(device)),
            'user_w': nn.Parameter(initializer(torch.empty(self.latent_size, self.n_edges)).to(device)),
            'item_w': nn.Parameter(initializer(torch.empty(self.latent_size, self.n_edges)).to(device))
        })

#         embedding_dict = nn.ParameterDict({
#             'user_emb': nn.Parameter(torch.empty(self.data.n_users, self.latent_size).to(device)),
#             'item_emb': nn.Parameter(torch.empty(self.data.n_items, self.latent_size).to(device)),
#             'user_w': nn.Parameter(torch.empty(self.latent_size, self.n_edges).to(device)),
#             'item_w': nn.Parameter(torch.empty(self.latent_size, self.n_edges).to(device))
#         })
        
        return embedding_dict
        
    def forward(self):
        embeddings = torch.cat([self.embedding_dict['user_emb'], self.embedding_dict['item_emb']], 0)
        hidden = [embeddings]
        gcn_hidden = []
        hgnn_hidden = []
#         hyper_uu = torch.mm(self.embedding_dict['user_emb'], self.embedding_dict['user_w'])
#         hyper_ii = torch.mm(self.embedding_dict['item_emb'], self.embedding_dict['item_w'])
        
        hyper_uu = self.embedding_dict['user_emb'] @ self.embedding_dict['user_w']
        hyper_ii = self.embedding_dict['item_emb'] @self.embedding_dict['item_w']
        
        for i in range(self.n_layers):
            gcn_emb = self.gcnlayer(self.edgeDropper(self.sparse_norm_adj, 0.5), hidden[-1]) 
            hyper_uemb = self.hgnnlayer(self.drop_out(hyper_uu), hidden[-1][:self.data.n_users])
            hyper_iemb = self.hgnnlayer(self.drop_out(hyper_ii), hidden[-1][self.data.n_users:])
            gcn_hidden += [gcn_emb]
            hgnn_hidden += [torch.cat([hyper_uemb, hyper_iemb], 0)]
            hidden += [gcn_emb + hgnn_hidden[-1]]
            
        embeddings = sum(hidden)
        
        user_emb = embeddings[:self.data.n_users]
        item_emb = embeddings[self.data.n_users:]
        
        return user_emb, item_emb, gcn_hidden, hgnn_hidden
        
class GCNLayer(nn.Module):
    def __init__(self, leaky):
        super(GCNLayer, self).__init__()
        self.act = nn.LeakyReLU(negative_slope=leaky)
        
    def forward(self, adj, embeds):
        return (torch.sparse.mm(adj, embeds))
    
class HGNNLayer(nn.Module):
    def __init__(self, leaky):
        super(HGNNLayer, self).__init__()
        self.act = nn.LeakyReLU(negative_slope=leaky)
    
    def forward(self, adj, embeds):
        #edge_embeds = self.act(torch.mm(adj.T, embeds))
        #hyper_embeds = self.act(torch.mm(adj, edge_embeds))
        edge_embeds = torch.mm(adj.T, embeds)
        hyper_embeds = torch.mm(adj, edge_embeds)
        return hyper_embeds
    
class SpAdjDropEdge(nn.Module):
	def __init__(self):
		super(SpAdjDropEdge, self).__init__()

	def forward(self, adj, keepRate):
		if keepRate == 1.0:
			return adj
		vals = adj._values()
		idxs = adj._indices()
		edgeNum = vals.size()
		mask = ((torch.rand(edgeNum) + keepRate).floor()).type(torch.bool)
		newVals = vals[mask] / keepRate
		newIdxs = idxs[:, mask]
		return torch.sparse.FloatTensor(newIdxs, newVals, adj.shape)

# %%
def contrastLoss(embeds1, embeds2, nodes, temp):
	embeds1 = F.normalize(embeds1 + 1e-8, p=2)
	embeds2 = F.normalize(embeds2 + 1e-8, p=2)
	pckEmbeds1 = embeds1
	pckEmbeds2 = embeds2
	nume = torch.exp(torch.sum(pckEmbeds1 * pckEmbeds2, dim=-1) / temp)
	deno = torch.exp(pckEmbeds1 @ pckEmbeds2.T / temp).sum(-1) + 1e-8
	return -torch.log(nume / deno).mean()

# %%
def calcLosses(ancs, poss, negs, gcnEmbedsLst, hyperEmbedsLst):
    bprLoss = bpr_loss(ancs, poss, negs)

    sslLoss = 0
    for i in range(args['n_layers']):
        embeds1 = gcnEmbedsLst[i].detach()
        embeds2 = hyperEmbedsLst[i]
        sslLoss += contrastLoss(embeds1[:rec.data.n_users], embeds2[:rec.data.n_users], torch.unique(ancs.long()), 1) + contrastLoss(embeds1[rec.data.n_users:], embeds2[rec.data.n_users:], torch.unique(poss), 1)
        
    return bprLoss, sslLoss

# %%
def predict(u, rec, user_emb, item_emb):
    user_id  = rec.data.get_user_id(u)
    score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
    return score.cpu().numpy()

# %% [markdown]
# ## Train

# %%
def train(hyper_params):
    performance_dict = {'Epoch':[], 
                        'Hit Ratio': [], 
                        'Precision':[], 
                        'Recall': [],
                        'NDCG': [], 
                        'Measure Time': []}
    total_train_losses = []
    total_rec_losses = []
    total_reg_losses = []
    
    for ep in range(maxEpoch):
        train_losses = []
        rec_losses = []
        reg_losses = []
        
        for n, batch in enumerate(next_batch_pairwise(rec.data, batchSize)):
            user_idx, pos_idx, neg_idx = batch
            train_model.train()
            user_emb, item_emb, gcnEmbedsLst, hyperEmbedsLst = train_model()

            anchor_emb = user_emb[user_idx]
            pos_emb = item_emb[pos_idx]
            neg_emb = item_emb[neg_idx]
            
            loss_rec, loss_reg = calcLosses(anchor_emb, pos_emb, neg_emb, gcnEmbedsLst, hyperEmbedsLst)
    #         print(f"Loss rec: {loss_rec}; Loss reg: {loss_reg}")
            
            batch_loss = loss_rec + loss_reg 
            #total_train_losses.append([loss_rec.item(), loss_reg.item(), batch_loss.item()])
            train_losses.append(batch_loss.item())
            rec_losses.append(loss_rec.item())
            reg_losses.append(loss_reg.item())
            
    #         print(f"Batch loss: {batch_loss}")
            optimizer.zero_grad()
            batch_loss.backward()

    #        torch.nn.utils.clip_grad_norm_(train_model.parameters(), 4)
            optimizer.step()
        
        batch_train_loss = np.mean(train_losses)
        batch_rec_loss = np.mean(rec_losses)
        batch_reg_loss = np.mean(reg_losses)
        
        total_train_losses.append([ep, batch_train_loss])
        total_rec_losses.append([ep, batch_rec_loss])
        total_reg_losses.append([ep, batch_reg_loss])
        scheduler.step(batch_train_loss)
        
        # Evaluation
        train_model.eval()
        with torch.no_grad():
            user_emb, item_emb, gcnEmbedsLst, hyperEmbedsLst = train_model()
            measure, performance_ep = rec.fast_evaluation(ep, user_emb, item_emb)
            for key, value in performance_ep.items():
                if key in performance_dict:
                    performance_dict[key].append(value)
                else:
                    continue
          
    rec.save_model(train_model, hyper_params)
    rec.save_loss(total_train_losses, total_rec_losses, total_reg_losses, hyper_params)
    rec.save_perfomance_training(performance_dict, hyper_params)
    
    
#         df_train = df_train.append(new_data, ignore_index=True)
#     current_time = datetime.now()
#     df_train.to_csv('results/'+ model + '/' + model+'@' + idx + '_train_['+ params + ']'+ str(current_time) +'.csv', index=False)
    
    return user_emb, item_emb

# %% [markdown]
# ## Test

# %%
def test(rec, user_emb, item_emb, hyper_params):
    
    def process_bar(num, total):
        rate = float(num) / total
        ratenum = int(50 * rate)
        r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
        sys.stdout.write(r)
        sys.stdout.flush()

    # predict
    rec_list = {}
    user_count = len(rec.data.test_set)
    for i, user in enumerate(rec.data.test_set):
        # s_find_candidates = time.time()
        candidates = predict(user, rec, user_emb, item_emb)
        # e_find_candidates = time.time()
        # print("Calculate candidates time: %f s" % (e_find_candidates - s_find_candidates))
        # predictedItems = denormalize(predictedItems, self.data.rScale[-1], self.data.rScale[0])
        rated_list, li = rec.data.user_rated(user)
        for item in rated_list:
            candidates[rec.data.item[item]] = -10e8

        # s_find_k_largest = time.time()
        ids, scores = find_k_largest(rec.max_N, candidates)
        # e_find_k_largest = time.time()
        # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
        item_names = [rec.data.id2item[iid] for iid in ids]
        rec_list[user] = list(zip(item_names, scores))
        if i % 1000 == 0:
            process_bar(i, user_count)
    process_bar(user_count, user_count)
    print('')
    result = ranking_evaluation(rec.data.test_set, rec_list, rec.topN)
    print(result)
    rec.save_performance_test(result, hyper_params)
    
#     df_test = pd.DataFrame(new_data, index=[0])
#     current_time = datetime.now()
#     path = 'results/' + model + '/' + model + ' ' + str(current_time)
#     file_path = path + '/' + model+'@' + str(idx) + '_test_'+ str(params) + ''+ str(current_time) +'.csv'
#     df_test.to_csv(file_path, index=False)

# %% [markdown]
# ## Main

# %%
model = 'HCCF'
if model not in ['HGNN', 'LightGCN', 'HCCF', 'DHCF']:
    print("No model found.")
config = ModelConf('./conf/' + model + '.conf')

dataset = 'lastfm'
batchSize = int(config['batch_size'])
# lRate = float(config['learnRate'])
# maxEpoch = int(config['num.max.epoch'])
# reg = float(config['reg.lambda'])
maxEpoch = 500
lRates = [0.01, 0.001, 0.0001]
lrDecays = [0.9]
regs = [0.01, 0.001, 0.0001]
hyperDims = [32, 64, 128]
inputDims = [8, 16, 32]
ps = [0.1, 0.4, 0.6]
dropRates = [0.1, 0.3, 0.5]
nLayers = [1, 2, 3]
hyperedge_num = [32, 64, 128]

if dataset == 'lastfm':
    training_set = "./dataset/lastfm/train.txt"
    test_set = './dataset/lastfm/test.txt'
elif dataset == 'ml-1m':
    training_set = './dataset/ml-1m/train.txt'
    test_set = './dataset/ml-1m/test.txt'
    
hyperparameters = [lRates, lrDecays, regs, hyperDims, inputDims, ps, dropRates, nLayers, hyperedge_num, dataset]

# %%
reg = 0.01
args = {
    'p':  0.1,
    'drop_rate': 0.5,
    'n_layers': 2,
    'input_dim': 32,
    'hyper_dim': 128,
    'hyperedge_num': 128,
    'lr': 0.001,
    'reg': reg,
    'leaky': 0.5,
    'dataset': dataset
}

default_dir = f"./dataset/{config['dataset']}/"
training_data = FileIO.load_data_set(training_set, config['model.type'])
test_data = FileIO.load_data_set(test_set, config['model.type'])
knowledge_data = FileIO.load_kg_data(default_dir + f"{config['dataset']}.kg")


rec = GraphRecommender(config, training_data, test_data, knowledge_data, **args)
if model == 'HGNN':
    train_model = Model(rec.config, rec.data, args).to(device)
elif model == 'LightGCN':
    train_model = LGCN_Encoder(rec.data, args['input_dim'], args['n_layers'])
elif model == 'HCCF':
    train_model = HCCFEncoder(rec.data, args['input_dim'], args['n_layers'], args['hyperedge_num'], args['leaky'], args['drop_rate'])

optimizer  = torch.optim.Adam(train_model.parameters(), lr=args['lr'], weight_decay=0.001)
scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.9, patience=5)
user_emb, item_emb = train(args)
test(rec, user_emb, item_emb, args)
# Out:
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 4.065315 s
# Measure time: 0.017795 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 1, Hit Ratio:0.08386  |  Precision:0.05165  |  Recall:0.08338  |  NDCG:0.07836
# *Best Performance*
# Epoch:fast_evaluation 1, Hit Ratio:0.08386  |  Precision:0.05165  |  Recall:0.08338  |  NDCG:0.07836
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.543778 s
# Measure time: 0.021478 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 2, Hit Ratio:0.11946  |  Precision:0.07357  |  Recall:0.12018  |  NDCG:0.12483
# *Best Performance*
# Epoch:fast_evaluation 2, Hit Ratio:0.11946  |  Precision:0.07357  |  Recall:0.12018  |  NDCG:0.12483
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.544969 s
# Measure time: 0.017423 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 3, Hit Ratio:0.12821  |  Precision:0.07895  |  Recall:0.12903  |  NDCG:0.13813
# *Best Performance*
# Epoch:fast_evaluation 3, Hit Ratio:0.12821  |  Precision:0.07895  |  Recall:0.12903  |  NDCG:0.13813
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.541639 s
# Measure time: 0.020754 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 4, Hit Ratio:0.13488  |  Precision:0.08307  |  Recall:0.13552  |  NDCG:0.14566
# *Best Performance*
# Epoch:fast_evaluation 4, Hit Ratio:0.13488  |  Precision:0.08307  |  Recall:0.13552  |  NDCG:0.14566
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.691702 s
# Measure time: 0.021132 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.587830 s
# Measure time: 0.025960 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 6, Hit Ratio:0.12424  |  Precision:0.07651  |  Recall:0.12527  |  NDCG:0.12008
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.700122 s
# Measure time: 0.021827 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 7, Hit Ratio:0.12101  |  Precision:0.07452  |  Recall:0.12185  |  NDCG:0.13244
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.612372 s
# Measure time: 0.033575 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 8, Hit Ratio:0.12769  |  Precision:0.07864  |  Recall:0.12862  |  NDCG:0.13185
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.729963 s
# Measure time: 0.022010 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 9, Hit Ratio:0.1351  |  Precision:0.0832  |  Recall:0.13587  |  NDCG:0.1348
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.522344 s
# Measure time: 0.022703 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 10, Hit Ratio:0.13738  |  Precision:0.08461  |  Recall:0.13886  |  NDCG:0.14245
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.597819 s
# Measure time: 0.017451 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 11, Hit Ratio:0.12178  |  Precision:0.075  |  Recall:0.12407  |  NDCG:0.12976
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.531033 s
# Measure time: 0.024306 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 12, Hit Ratio:0.1292  |  Precision:0.07956  |  Recall:0.12934  |  NDCG:0.13093
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.14109  |  Precision:0.08689  |  Recall:0.14298  |  NDCG:0.14719
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.690074 s
# Measure time: 0.022985 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 13, Hit Ratio:0.14247  |  Precision:0.08774  |  Recall:0.14406  |  NDCG:0.14979
# *Best Performance*
# Epoch:fast_evaluation 13, Hit Ratio:0.14247  |  Precision:0.08774  |  Recall:0.14406  |  NDCG:0.14979
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.640355 s
# Measure time: 0.019538 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 14, Hit Ratio:0.13734  |  Precision:0.08458  |  Recall:0.13912  |  NDCG:0.14949
# *Best Performance*
# Epoch:fast_evaluation 13, Hit Ratio:0.14247  |  Precision:0.08774  |  Recall:0.14406  |  NDCG:0.14979
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.621063 s
# Measure time: 0.021056 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.609001 s
# Measure time: 0.018790 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 16, Hit Ratio:0.1267  |  Precision:0.07803  |  Recall:0.12687  |  NDCG:0.13513
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.440310 s
# Measure time: 0.019660 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 17, Hit Ratio:0.13122  |  Precision:0.08081  |  Recall:0.13182  |  NDCG:0.13134
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.606092 s
# Measure time: 0.017090 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 18, Hit Ratio:0.12976  |  Precision:0.07991  |  Recall:0.13098  |  NDCG:0.13644
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.645207 s
# Measure time: 0.022883 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 19, Hit Ratio:0.14208  |  Precision:0.0875  |  Recall:0.14213  |  NDCG:0.15388
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.624330 s
# Measure time: 0.018235 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 20, Hit Ratio:0.12338  |  Precision:0.07598  |  Recall:0.12386  |  NDCG:0.12727
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14684  |  NDCG:0.15825
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.508866 s
# Measure time: 0.017495 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 21, Hit Ratio:0.14842  |  Precision:0.0914  |  Recall:0.149  |  NDCG:0.15397
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.14842  |  Precision:0.0914  |  Recall:0.149  |  NDCG:0.15397
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.593189 s
# Measure time: 0.026859 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 22, Hit Ratio:0.14187  |  Precision:0.08737  |  Recall:0.14201  |  NDCG:0.14926
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.14842  |  Precision:0.0914  |  Recall:0.149  |  NDCG:0.15397
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.677229 s
# Measure time: 0.022202 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 23, Hit Ratio:0.13898  |  Precision:0.08559  |  Recall:0.13917  |  NDCG:0.14982
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.14842  |  Precision:0.0914  |  Recall:0.149  |  NDCG:0.15397
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.572644 s
# Measure time: 0.021685 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 24, Hit Ratio:0.13088  |  Precision:0.0806  |  Recall:0.13061  |  NDCG:0.13679
# *Best Performance*
# Epoch:fast_evaluation 21, Hit Ratio:0.14842  |  Precision:0.0914  |  Recall:0.149  |  NDCG:0.15397
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.447828 s
# Measure time: 0.016767 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.568181 s
# Measure time: 0.022758 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 26, Hit Ratio:0.1451  |  Precision:0.08936  |  Recall:0.14561  |  NDCG:0.16132
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.568931 s
# Measure time: 0.024610 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 27, Hit Ratio:0.14359  |  Precision:0.08843  |  Recall:0.14564  |  NDCG:0.16114
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.663379 s
# Measure time: 0.020052 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 28, Hit Ratio:0.13601  |  Precision:0.08376  |  Recall:0.13712  |  NDCG:0.14359
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.474252 s
# Measure time: 0.017159 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 29, Hit Ratio:0.14139  |  Precision:0.08708  |  Recall:0.14218  |  NDCG:0.15145
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.794054 s
# Measure time: 0.022799 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 30, Hit Ratio:0.146  |  Precision:0.08992  |  Recall:0.14727  |  NDCG:0.15988
# *Best Performance*
# Epoch:fast_evaluation 25, Hit Ratio:0.14898  |  Precision:0.09175  |  Recall:0.14885  |  NDCG:0.16376
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.590177 s
# Measure time: 0.022145 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 31, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15934  |  NDCG:0.17003
# *Best Performance*
# Epoch:fast_evaluation 31, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15934  |  NDCG:0.17003
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.605951 s
# Measure time: 0.028346 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 32, Hit Ratio:0.14695  |  Precision:0.0905  |  Recall:0.14774  |  NDCG:0.15426
# *Best Performance*
# Epoch:fast_evaluation 31, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15934  |  NDCG:0.17003
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.449090 s
# Measure time: 0.020869 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 33, Hit Ratio:0.142  |  Precision:0.08745  |  Recall:0.14288  |  NDCG:0.1491
# *Best Performance*
# Epoch:fast_evaluation 31, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15934  |  NDCG:0.17003
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.489134 s
# Measure time: 0.023307 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 34, Hit Ratio:0.14204  |  Precision:0.08747  |  Recall:0.14247  |  NDCG:0.14937
# *Best Performance*
# Epoch:fast_evaluation 31, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15934  |  NDCG:0.17003
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.705541 s
# Measure time: 0.026312 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 35, Hit Ratio:0.16078  |  Precision:0.09902  |  Recall:0.16118  |  NDCG:0.17461
# *Best Performance*
# Epoch:fast_evaluation 35, Hit Ratio:0.16078  |  Precision:0.09902  |  Recall:0.16118  |  NDCG:0.17461
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.310055 s
# Measure time: 0.018911 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.320485 s
# Measure time: 0.017259 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 37, Hit Ratio:0.15479  |  Precision:0.09533  |  Recall:0.15548  |  NDCG:0.16258
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.324525 s
# Measure time: 0.017642 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 38, Hit Ratio:0.14549  |  Precision:0.0896  |  Recall:0.14591  |  NDCG:0.15273
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.312218 s
# Measure time: 0.017700 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 39, Hit Ratio:0.15398  |  Precision:0.09482  |  Recall:0.15524  |  NDCG:0.15866
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.298631 s
# Measure time: 0.016379 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 40, Hit Ratio:0.15329  |  Precision:0.0944  |  Recall:0.15455  |  NDCG:0.16703
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.301323 s
# Measure time: 0.018376 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 41, Hit Ratio:0.15673  |  Precision:0.09652  |  Recall:0.1582  |  NDCG:0.1684
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.311352 s
# Measure time: 0.019359 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 42, Hit Ratio:0.14859  |  Precision:0.09151  |  Recall:0.14975  |  NDCG:0.15532
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.290523 s
# Measure time: 0.017588 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 43, Hit Ratio:0.14915  |  Precision:0.09185  |  Recall:0.15024  |  NDCG:0.15645
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.314115 s
# Measure time: 0.019703 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 44, Hit Ratio:0.15018  |  Precision:0.09249  |  Recall:0.15096  |  NDCG:0.16233
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.307216 s
# Measure time: 0.017233 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 45, Hit Ratio:0.15372  |  Precision:0.09467  |  Recall:0.15496  |  NDCG:0.16261
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.313058 s
# Measure time: 0.017245 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 46, Hit Ratio:0.16104  |  Precision:0.09918  |  Recall:0.16295  |  NDCG:0.17916
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.290718 s
# Measure time: 0.016942 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 47, Hit Ratio:0.14928  |  Precision:0.09193  |  Recall:0.15123  |  NDCG:0.15951
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.303145 s
# Measure time: 0.018482 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 48, Hit Ratio:0.15729  |  Precision:0.09687  |  Recall:0.15802  |  NDCG:0.16751
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.368584 s
# Measure time: 0.017880 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 49, Hit Ratio:0.15587  |  Precision:0.09599  |  Recall:0.15605  |  NDCG:0.17199
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.491688 s
# Measure time: 0.021417 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 50, Hit Ratio:0.16402  |  Precision:0.10101  |  Recall:0.16455  |  NDCG:0.17377
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.298298 s
# Measure time: 0.016282 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 51, Hit Ratio:0.1585  |  Precision:0.09761  |  Recall:0.15943  |  NDCG:0.17297
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.389408 s
# Measure time: 0.023091 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 52, Hit Ratio:0.16122  |  Precision:0.09928  |  Recall:0.16181  |  NDCG:0.17753
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.306142 s
# Measure time: 0.019014 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 53, Hit Ratio:0.15333  |  Precision:0.09443  |  Recall:0.15458  |  NDCG:0.15987
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.311409 s
# Measure time: 0.018240 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 54, Hit Ratio:0.1576  |  Precision:0.09705  |  Recall:0.15811  |  NDCG:0.17293
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.354118 s
# Measure time: 0.018588 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 55, Hit Ratio:0.15971  |  Precision:0.09835  |  Recall:0.16123  |  NDCG:0.17283
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.309194 s
# Measure time: 0.017177 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 56, Hit Ratio:0.15863  |  Precision:0.09769  |  Recall:0.16046  |  NDCG:0.17718
# *Best Performance*
# Epoch:fast_evaluation 36, Hit Ratio:0.16552  |  Precision:0.10194  |  Recall:0.16595  |  NDCG:0.18007
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.308871 s
# Measure time: 0.018440 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.345330 s
# Measure time: 0.021047 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 58, Hit Ratio:0.16902  |  Precision:0.10409  |  Recall:0.16987  |  NDCG:0.18065
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.308794 s
# Measure time: 0.020860 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 59, Hit Ratio:0.16919  |  Precision:0.10419  |  Recall:0.17096  |  NDCG:0.17952
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.341296 s
# Measure time: 0.020079 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 60, Hit Ratio:0.16522  |  Precision:0.10175  |  Recall:0.16488  |  NDCG:0.17561
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.327472 s
# Measure time: 0.017316 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 61, Hit Ratio:0.16113  |  Precision:0.09923  |  Recall:0.16151  |  NDCG:0.1732
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.160805 s
# Measure time: 0.016609 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 62, Hit Ratio:0.16781  |  Precision:0.10334  |  Recall:0.1687  |  NDCG:0.18478
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.332195 s
# Measure time: 0.019141 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 63, Hit Ratio:0.16294  |  Precision:0.10035  |  Recall:0.16413  |  NDCG:0.16338
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.352750 s
# Measure time: 0.022396 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 64, Hit Ratio:0.15492  |  Precision:0.09541  |  Recall:0.15612  |  NDCG:0.16777
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.373994 s
# Measure time: 0.023728 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 65, Hit Ratio:0.16932  |  Precision:0.10427  |  Recall:0.17061  |  NDCG:0.1837
# *Best Performance*
# Epoch:fast_evaluation 57, Hit Ratio:0.1707  |  Precision:0.10512  |  Recall:0.17154  |  NDCG:0.18255
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.365760 s
# Measure time: 0.023687 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.364177 s
# Measure time: 0.023365 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 67, Hit Ratio:0.17501  |  Precision:0.10778  |  Recall:0.17615  |  NDCG:0.18559
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.309308 s
# Measure time: 0.017224 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 68, Hit Ratio:0.16833  |  Precision:0.10366  |  Recall:0.16948  |  NDCG:0.18228
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.389022 s
# Measure time: 0.025564 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 69, Hit Ratio:0.16333  |  Precision:0.10058  |  Recall:0.16505  |  NDCG:0.17968
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.351961 s
# Measure time: 0.026290 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 70, Hit Ratio:0.16544  |  Precision:0.10188  |  Recall:0.16657  |  NDCG:0.18208
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.351943 s
# Measure time: 0.023267 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 71, Hit Ratio:0.16608  |  Precision:0.10228  |  Recall:0.16659  |  NDCG:0.18059
# *Best Performance*
# Epoch:fast_evaluation 66, Hit Ratio:0.17677  |  Precision:0.10886  |  Recall:0.17693  |  NDCG:0.1944
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.301655 s
# Measure time: 0.016698 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 72, Hit Ratio:0.1691  |  Precision:0.10414  |  Recall:0.17034  |  NDCG:0.18707
# *Best Performance*
# ...
# *Best Performance*
# Epoch:fast_evaluation 466, Hit Ratio:0.24633  |  Precision:0.1517  |  Recall:0.24765  |  NDCG:0.27116
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.288996 s
# Measure time: 0.024604 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 478, Hit Ratio:0.24512  |  Precision:0.15096  |  Recall:0.2461  |  NDCG:0.269
# *Best Performance*
# Epoch:fast_evaluation 466, Hit Ratio:0.24633  |  Precision:0.1517  |  Recall:0.24765  |  NDCG:0.27116
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.348197 s
# Measure time: 0.019579 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 479, Hit Ratio:0.24546  |  Precision:0.15117  |  Recall:0.24711  |  NDCG:0.27036
# *Best Performance*
# Epoch:fast_evaluation 466, Hit Ratio:0.24633  |  Precision:0.1517  |  Recall:0.24765  |  NDCG:0.27116
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.335505 s
# Measure time: 0.022674 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 480, Hit Ratio:0.2468  |  Precision:0.15199  |  Recall:0.24824  |  NDCG:0.27045
# *Best Performance*
# Epoch:fast_evaluation 480, Hit Ratio:0.2468  |  Precision:0.15199  |  Recall:0.24824  |  NDCG:0.27045
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.378111 s
# Measure time: 0.024253 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.408412 s
# Measure time: 0.024088 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 482, Hit Ratio:0.24529  |  Precision:0.15106  |  Recall:0.24594  |  NDCG:0.27041
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.402650 s
# Measure time: 0.025227 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 483, Hit Ratio:0.24546  |  Precision:0.15117  |  Recall:0.24647  |  NDCG:0.27166
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.321833 s
# Measure time: 0.019653 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 484, Hit Ratio:0.24637  |  Precision:0.15173  |  Recall:0.2478  |  NDCG:0.27173
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.361259 s
# Measure time: 0.021091 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 485, Hit Ratio:0.24602  |  Precision:0.15151  |  Recall:0.24719  |  NDCG:0.27148
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.324029 s
# Measure time: 0.023853 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 486, Hit Ratio:0.24611  |  Precision:0.15157  |  Recall:0.2474  |  NDCG:0.27158
# *Best Performance*
# Epoch:fast_evaluation 481, Hit Ratio:0.24719  |  Precision:0.15223  |  Recall:0.24813  |  NDCG:0.27187
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.409317 s
# Measure time: 0.024725 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.297689 s
# Measure time: 0.017650 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 488, Hit Ratio:0.24564  |  Precision:0.15127  |  Recall:0.24661  |  NDCG:0.27079
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.362142 s
# Measure time: 0.020350 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 489, Hit Ratio:0.2459  |  Precision:0.15143  |  Recall:0.24642  |  NDCG:0.2705
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.404310 s
# Measure time: 0.023634 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 490, Hit Ratio:0.24624  |  Precision:0.15165  |  Recall:0.24729  |  NDCG:0.27145
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.321968 s
# Measure time: 0.019907 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 491, Hit Ratio:0.2437  |  Precision:0.15008  |  Recall:0.24421  |  NDCG:0.27028
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.390707 s
# Measure time: 0.022624 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 492, Hit Ratio:0.24529  |  Precision:0.15106  |  Recall:0.24606  |  NDCG:0.27095
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.329010 s
# Measure time: 0.021974 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 493, Hit Ratio:0.24676  |  Precision:0.15196  |  Recall:0.24672  |  NDCG:0.27263
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.335511 s
# Measure time: 0.017873 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 494, Hit Ratio:0.24456  |  Precision:0.15061  |  Recall:0.24525  |  NDCG:0.27089
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.381322 s
# Measure time: 0.021884 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 495, Hit Ratio:0.24602  |  Precision:0.15151  |  Recall:0.24793  |  NDCG:0.27124
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.377880 s
# Measure time: 0.024317 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 496, Hit Ratio:0.24421  |  Precision:0.1504  |  Recall:0.24571  |  NDCG:0.2692
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.366852 s
# Measure time: 0.024065 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 497, Hit Ratio:0.24564  |  Precision:0.15127  |  Recall:0.24688  |  NDCG:0.27186
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.303463 s
# Measure time: 0.016994 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 498, Hit Ratio:0.2449  |  Precision:0.15082  |  Recall:0.24673  |  NDCG:0.26959
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.401612 s
# Measure time: 0.023356 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 499, Hit Ratio:0.2471  |  Precision:0.15218  |  Recall:0.2483  |  NDCG:0.27339
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.388126 s
# Measure time: 0.018172 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 500, Hit Ratio:0.24534  |  Precision:0.15109  |  Recall:0.2471  |  NDCG:0.27113
# *Best Performance*
# Epoch:fast_evaluation 487, Hit Ratio:0.2474  |  Precision:0.15236  |  Recall:0.24937  |  NDCG:0.27189
# ------------------------------------------------------------------------------------------------------------------------
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# ['Top 10\n', 'Hit Ratio:0.1657\n', 'Precision:0.20409\n', 'Recall:0.1669\n', 'NDCG:0.25944\n', 'Top 20\n', 'Hit Ratio:0.24534\n', 'Precision:0.15109\n', 'Recall:0.2471\n', 'NDCG:0.27113\n']

# %%
# for idx, params in enumerate(product(*hyperparameters)):
#     lr, lr_decay, reg, hyper_dim, input_dim, prob, drop_rate, n_layers, hyperedge_num = params
#     print("hyperparameters:{}".format(params))
#     args = {
#         'p': prob,
#         'drop_rate': drop_rate,
#         'n_layers': n_layers,
#         'input_dim': input_dim,
#         'hyper_dim': hyper_dim,
#         'hyperedge_num': hyperedge_num,
#         'lr': lr,
#         'reg': reg,
#         'leaky': 0.5,
#         'dataset': dataset
#     }

#     training_data = FileIO.load_data_set(training_set, config['model.type'])
#     test_data = FileIO.load_data_set(test_set, config['model.type'])

#     rec = GraphRecommender(config, training_data, test_data, **args)
#     if model == 'HGNN':
#         train_model = Model(rec.config, rec.data, args).to(device)
#     elif model == 'LightGCN':
#         train_model = LGCN_Encoder(rec.data, input_dim, args['n_layers'])
#     elif model == 'HCCF':
#         train_model = HCCFEncoder(rec.data, input_dim, args['n_layers'], args['hyperedge_num'], args['leaky'], args['drop_rate'])

#     optimizer  = torch.optim.Adam(train_model.parameters(), lr=lr)
#     scheduler = ReduceLROnPlateau(optimizer, 'min', factor=lr_decay, patience=5)
#     user_emb, item_emb = train(args)
#     test(rec, user_emb, item_emb, args)
