# %%
import math
import torch
import torch.nn as nn 
import torch.nn.functional as F
from torch.nn.parameter import Parameter
import torch.nn.init as init
# from torch.nn.init import xavier_normal_, xavier_uniform_
import argparse
import numpy as np
import time
import sys
from os.path import abspath
import random
import pandas as pd
from util.sampler import  next_batch_pairwise
from util.conf import OptionConf
import torch
import torch.nn as nn 
import torch.nn.functional as F
from scipy.sparse import coo_matrix
from util.loss_torch import bpr_loss, l2_reg_loss, EmbLoss, contrastLoss, InfoNCE
from util.init import *
from base.torch_interface import TorchGraphInterface
import os
import numpy as np 
import time 
from torch.optim.lr_scheduler import ReduceLROnPlateau
from itertools import product
import collections  
from collections import defaultdict
import scipy.sparse as sp
from itertools import product
from random import shuffle,randint,choice,sample
import torch.nn.init as init 
import csv 

from util.conf import ModelConf
from base.recommender import Recommender
from util.algorithm import find_k_largest
from time import strftime, localtime
from data.loader import FileIO
from util.evaluation import ranking_evaluation

from data.ui_graph import Interaction
from data.augmentor import GraphAugmentor

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Base Recommender

# %%
class GraphRecommender(Recommender):
    def __init__(self, conf, data, data_kg,knowledge_set, **kwargs):
        super(GraphRecommender, self).__init__(conf, data, data_kg, knowledge_set,**kwargs)
        self.data = data
        self.data_kg = data_kg 
        self.bestPerformance = []
        top = self.ranking['-topN'].split(',')
        self.topN = [int(num) for num in top]
        self.max_N = max(self.topN)
        
        self.dataset = kwargs['dataset']
        
        # self.output = f"./results/{self.model_name}/{self.dataset}/@{self.model_name}-inp_emb:{kwargs['input_dim']}-hyper_emb:{kwargs['hyper_dim']}-bs:{self.batch_size}-lr:{kwargs['lr']}-lrd:{kwargs['lr_decay']}-reg:{kwargs['reg']}-leaky:{kwargs['p']}-dropout:{kwargs['drop_rate']}-n_layers:{kwargs['n_layers']}-n_heads:{kwargs['n_heads']}-n_self_att:{kwargs['n_self_att']}/"
        self.output = f"./results/HGNN_KG_SSL/{self.dataset}/@{self.model_name}-inp_emb:{kwargs['input_dim']}-hyper_emb:{kwargs['hyper_dim']}-bs:{self.batch_size}-lr:{kwargs['lr']}-lrd:{kwargs['lr_decay']}-reg:{kwargs['reg']}-leaky:{kwargs['p']}-dropout:{kwargs['drop_rate']}-n_layers:{kwargs['n_layers']}-cl_rate:{kwargs['cl_rate']}-aug_type:{kwargs['aug_type']}-temp:{kwargs['temp']}/"
        if not os.path.exists(self.output):
            os.makedirs(self.output)

    def print_model_info(self):
        super(GraphRecommender, self).print_model_info()
        # # print dataset statistics
        print('Training Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.training_size()))
        print('Test Set Size: (user number: %d, item number %d, interaction number: %d)' % (self.data.test_size()))
        print('=' * 80)

    def build(self):
        pass

    def train(self):
        pass

    def predict(self, u):
        pass

    def test(self, user_emb, item_emb):
        def process_bar(num, total):
            rate = float(num) / total
            ratenum = int(50 * rate)
            r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
            sys.stdout.write(r)
            sys.stdout.flush()

        # predict
        rec_list = {}
        user_count = len(self.data.test_set)
        for i, user in enumerate(self.data.test_set):
            # s_find_candidates = time.time()
            
            
            # candidates = predict(user)
            user_id  = self.data.get_user_id(user)
            score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
            candidates = score.cpu().numpy()
            
            # e_find_candidates = time.time()
            # print("Calculate candidates time: %f s" % (e_find_candidates - s_find_candidates))
            # predictedItems = denormalize(predictedItems, self.data.rScale[-1], self.data.rScale[0])
            rated_list, li = self.data.user_rated(user)
            for item in rated_list:
                candidates[self.data.item[item]] = -10e8
            
            # s_find_k_largest = time.time()
            ids, scores = find_k_largest(self.max_N, candidates)
            # e_find_k_largest = time.time()
            # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
            item_names = [self.data.id2item[iid] for iid in ids]
            rec_list[user] = list(zip(item_names, scores))
            if i % 1000 == 0:
                process_bar(i, user_count)
        process_bar(user_count, user_count)
        print('')
        return rec_list

    def evaluate(self, rec_list):
        self.recOutput.append('userId: recommendations in (itemId, ranking score) pairs, * means the item is hit.\n')
        for user in self.data.test_set:
            line = str(user) + ':'
            for item in rec_list[user]:
                line += ' (' + str(item[0]) + ',' + str(item[1]) + ')'
                if item[0] in self.data.test_set[user]:
                    line += '*'
            line += '\n'
            self.recOutput.append(line)
        current_time = strftime("%Y-%m-%d %H-%M-%S", localtime(time.time()))
        # output prediction result
        out_dir = self.output
        file_name = self.config['model.name'] + '@' + current_time + '-top-' + str(self.max_N) + 'items' + '.txt'
        FileIO.write_file(out_dir, file_name, self.recOutput)
        print('The result has been output to ', abspath(out_dir), '.')
        file_name = self.config['model.name'] + '@' + current_time + '-performance' + '.txt'
        self.result = ranking_evaluation(self.data.test_set, rec_list, self.topN)
        self.model_log.add('###Evaluation Results###')
        self.model_log.add(self.result)
        FileIO.write_file(out_dir, file_name, self.result)
        print('The result of %s:\n%s' % (self.model_name, ''.join(self.result)))

    def fast_evaluation(self, model, epoch, user_embed, item_embed, kwargs=None):
        print('Evaluating the model...')
        s_test = time.time()
        rec_list = self.test(user_embed, item_embed)
        e_test = time.time() 
        print("Test time: %f s" % (e_test - s_test))
        
        s_measure = time.time()
        measure = ranking_evaluation(self.data.test_set, rec_list, [self.max_N])
        e_measure = time.time()
        print("Measure time: %f s" % (e_measure - s_measure))
        
        if len(self.bestPerformance) > 0:
            count = 0
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            for k in self.bestPerformance[1]:
                if self.bestPerformance[1][k] > performance[k]:
                    count += 1
                else:
                    count -= 1
            if count < 0:
                self.bestPerformance[1] = performance
                self.bestPerformance[0] = epoch + 1
                # try:
                #     self.save(kwargs)
                # except:
                self.save(model)
        else:
            self.bestPerformance.append(epoch + 1)
            performance = {}
            for m in measure[1:]:
                k, v = m.strip().split(':')
                performance[k] = float(v)
            self.bestPerformance.append(performance)
            # try:
            #     self.save(kwargs)
            # except:
            self.save(model)
        print('-' * 120)
        print('Real-Time Ranking Performance ' + ' (Top-' + str(self.max_N) + ' Item Recommendation)')
        measure = [m.strip() for m in measure[1:]]
        print('*Current Performance*')
        print('Epoch:', str(epoch + 1) + ',', '  |  '.join(measure))
        bp = ''
        # for k in self.bestPerformance[1]:
        #     bp+=k+':'+str(self.bestPerformance[1][k])+' | '
        bp += 'Hit Ratio' + ':' + str(self.bestPerformance[1]['Hit Ratio']) + '  |  '
        bp += 'Precision' + ':' + str(self.bestPerformance[1]['Precision']) + '  |  '
        bp += 'Recall' + ':' + str(self.bestPerformance[1]['Recall']) + '  |  '
        # bp += 'F1' + ':' + str(self.bestPerformance[1]['F1']) + ' | '
        bp += 'NDCG' + ':' + str(self.bestPerformance[1]['NDCG'])
        print('*Best Performance* ')
        print('Epoch:fast_evaluation', str(self.bestPerformance[0]) + ',', bp)
        print('-' * 120)
        return measure
    
    def save(self, model):
        with torch.no_grad():
            self.best_user_emb, self.best_item_emb = model(mode='cf')
        self.save_model(model)
    
    def save_model(self, model):
        # save model 
        current_time = strftime("%Y-%m-%d", localtime(time.time()))
        out_dir = self.output
        file_name =  self.config['model.name'] + '@' + current_time + '-weight' + '.pth'
        weight_file = out_dir + '/' + file_name 
        torch.save(model.state_dict(), weight_file)

    def save_loss(self, train_losses, cf_losses, kg_losses):
        df_train_loss = pd.DataFrame(train_losses, columns = ['ep', 'loss'])
        df_cf_loss = pd.DataFrame(cf_losses, columns = ['ep', 'loss'])
        df_kg_loss = pd.DataFrame(kg_losses, columns = ['ep', 'loss'])
        df_train_loss.to_csv(self.output + '/train_loss.csv')
        df_cf_loss.to_csv(self.output + '/cf_loss.csv')
        df_kg_loss.to_csv(self.output + '/kg_loss.csv')

    def save_perfomance_training(self, log_train):
        df_train_log = pd.DataFrame(log_train)
        df_train_log.to_csv(self.output + '/train_performance.csv')

# %% [markdown]
# ## Knowledge

# %%
class Knowledge(Interaction):
    def __init__(self, conf, training, test, knowledge):
        super().__init__(conf, training, test)
        self.conf = conf 
        self.kg_data = knowledge

        self.entity = {}
        self.id2ent = {}

        self.userent = {}
        self.itement = {}
        
        self.u2id = {}
        self.id2u = {}
        
        self.i2id = {}
        self.id2i = {}
        
        self.relation = {}
        self.id2rel = {}

        self.cf_train_data = np.array(training)
        self.training_set_e = defaultdict(dict)

        self.construct_data()
        
        self.laplacian_type = 'random-walk'
        self.create_adjacency_dict()
        self.create_laplacian_dict()
        
        self.kg_interaction_mat = self.__create_sparse_knowledge_interaction_matrix()
        self.interaction_mat = self.__create_sparse_interaction_matrix()
        
        
    def construct_data(self):
        kg_data = self.kg_data
        n_relations = max(kg_data['r']) + 1
        inverse_kg_data = kg_data.copy()
        inverse_kg_data = inverse_kg_data.rename({'h': 't', 't': 'h'}, axis='columns')
        inverse_kg_data['r'] += n_relations

        kg_data = pd.concat([kg_data, inverse_kg_data], axis=0, ignore_index=True, sort=False)

        # remap user_id 
        kg_data['r'] += 2
        
        kg_train_data = pd.concat([kg_data, inverse_kg_data], axis=0, ignore_index=True, sort=False)
        self.n_entities = max(max(kg_train_data['h']), max(kg_train_data['t'])) + 1
        self.n_relations = max(kg_train_data['r']) + 1

        # add interactions to kg data
        cf2kg_train_data = pd.DataFrame(np.zeros((self.n_cf_train, 3), dtype=np.int32), columns=['h', 'r', 't'])
        cf2kg_train_data['h'] = self.cf_train_data[:,0]
        cf2kg_train_data['t'] = self.cf_train_data[:,1]

        inverse_cf2kg_train_data = pd.DataFrame(np.ones((self.n_cf_train, 3), dtype=np.int32), columns=['h', 'r', 't'])
        inverse_cf2kg_train_data['h'] = self.cf_train_data[:,1]
        inverse_cf2kg_train_data['t'] = self.cf_train_data[:,0]

        self.kg_train_data = pd.concat([kg_train_data, cf2kg_train_data, inverse_cf2kg_train_data], ignore_index=True)
        self.n_kg_train = len(self.kg_train_data)

        self.n_users_entities = int(max(max(self.kg_train_data['h']), max(self.kg_train_data['t'])) + 1)

        # construct kg dict
        h_list = []
        t_list = []
        r_list = []

        self.train_kg_dict = collections.defaultdict(list)
        self.train_relation_dict = collections.defaultdict(list)

        for idx, row in self.kg_train_data.iterrows():
            h, r, t = int(row['h']), int(row['r']), int(row['t'])
            h_list.append(h)
            t_list.append(t)
            r_list.append(r)

            if h not in self.entity:
                self.entity[h] = len(self.entity)
                self.id2ent[self.entity[h]] = h
                # check h co phai user hay item k
                if h in self.user:
                    self.userent[h] = len(self.userent)
                #     # self.id2userent[self.userent[h]] = h
                if h in self.item:
                    self.itement[h] = len(self.itement)
                #     # self.id2itement[self.itement[h]] = h

            if t not in self.entity:
                self.entity[t] = len(self.entity)
                self.id2ent[self.entity[t]] = t 
                # check h co phai user hay item k 
                if t in self.user:
                    self.userent[t] = len(self.userent)
                #     # self.id2userent[self.userent[t]] = t
                if t in self.item:
                    self.itement[t] = len(self.itement)
                #     # self.id2itement[self.itement[t]] = t
            if r not in self.relation:
                self.relation[r] = len(self.relation)
                self.id2rel[self.relation[r]] = r 
            
            self.training_set_e[t][h] = r
            self.train_kg_dict[h].append((t, r))
            self.train_relation_dict[r].append((h, t))
        
        self.h_list = torch.LongTensor(h_list).to(device)
        self.t_list = torch.LongTensor(t_list).to(device)
        self.r_list = torch.LongTensor(r_list).to(device)
        
        lst_user_entities = list(self.userent.keys())
        lst_item_entities = list(self.itement.keys())

        for idx, u in enumerate(lst_user_entities):
            self.u2id[u] = idx
            self.id2u[idx] = u
        for idx, i in enumerate(lst_item_entities):
            self.i2id[i] = idx
            self.id2i[idx] = i
        
    def get_entity_id(self, e):
        if e in self.entity:
            return self.entity[e]
    
    def __create_sparse_knowledge_interaction_matrix(self):
        """
            return a sparse adjacency matrix with the shape (entity number, entity number)
        """
        row, col, entries = [], [], []
        for idx, pair in self.kg_train_data.iterrows():
            head, tail = int(pair['h']), int(pair['t'])
            row += [head]
            col += [tail]
            entries += [1.0]
        interaction_mat = sp.csr_matrix((entries, (row, col)), shape=(self.n_users_entities, self.n_users_entities),dtype=np.float32)
        return interaction_mat
    
    def __create_sparse_interaction_matrix(self):
        row, col, entries = [], [], []
        for pair in self.training_data:
            head, tail  = int(pair[0]), int(pair[1])
            row += [head]
            col += [tail]
            entries += [1.0]
        interaction_mat = sp.csr_matrix((entries, (row, col)), shape=(self.n_users_entities, self.n_users_entities),dtype=np.float32) 
        return interaction_mat
    
    def convert_coo2tensor(self, coo):
        values = coo.data
        indices = np.vstack((coo.row, coo.col))

        i = torch.LongTensor(indices)
        v = torch.FloatTensor(values)
        shape = coo.shape
        return torch.sparse.FloatTensor(i, v, torch.Size(shape))
    
    def create_adjacency_dict(self):
        self.adjacency_dict = {}
        for r, ht_list in self.train_relation_dict.items():
            rows = [e[0] for e in ht_list]
            cols = [e[1] for e in ht_list]
            vals = [1] * len(rows)
            adj = sp.coo_matrix((vals, (rows, cols)), shape=(self.n_users_entities, self.n_users_entities))
            self.adjacency_dict[r] = adj
    
    def create_laplacian_dict(self):
        def symmetric_norm_lap(adj):
            rowsum = np.array(adj.sum(axis=1))

            d_inv_sqrt = np.power(rowsum, -0.5).flatten()
            d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0
            d_mat_inv_sqrt = sp.diags(d_inv_sqrt)

            norm_adj = d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt)
            return norm_adj.tocoo()

        def random_walk_norm_lap(adj):
            rowsum = np.array(adj.sum(axis=1))

            d_inv = np.power(rowsum, -1.0).flatten()
            d_inv[np.isinf(d_inv)] = 0
            d_mat_inv = sp.diags(d_inv)

            norm_adj = d_mat_inv.dot(adj)
            return norm_adj.tocoo()

        if self.laplacian_type == 'symmetric':
            norm_lap_func = symmetric_norm_lap
        elif self.laplacian_type == 'random-walk':
            norm_lap_func = random_walk_norm_lap
        
        self.laplacian_dict = {}
        for r, adj in self.adjacency_dict.items():
            self.laplacian_dict[r] = norm_lap_func(adj)

        A_in = sum(self.laplacian_dict.values())
        self.A_in = self.convert_coo2tensor(A_in.tocoo())

# %% [markdown]
# ## Sampler

# %%
def next_batch_kg(data_kg, batch_size, n_negs=1):
    ptr = 0
    kg_data = data_kg.kg_train_data.to_numpy()
    kg_dict = data_kg.train_kg_dict

    exist_heads= kg_dict.keys()
    h_list = list(exist_heads)
    h_dict = {value: idx for idx, value in enumerate(h_list)}
    all_tails = list(set(kg_data[:,2]))
    data_size = len(kg_data)
    # Pre-compute positive tail sets and negative tails for each head
    pos_tail_sets = {head: set([it[0] for it in tails]) for head, tails in kg_dict.items()}
    # neg_tail_sets = {head: np.random.choice(list(all_tails - pos_tails), size=n_negs) for head, pos_tails in pos_tail_sets.items()}
    
    while ptr < data_size:
        if ptr + batch_size < data_size:
            batch_end = ptr + batch_size
        else:   
            batch_end = data_size
        
        heads, relations, tails = kg_data[ptr:batch_end, 0], kg_data[ptr:batch_end, 1], kg_data[ptr:batch_end, 2]
        
        ptr = batch_end
        h_idx, r_idx, pos_t_idx, neg_t_idx = [], [], [], []
        # time1 = datetime.datetime.now()
        h_idx = [h_dict[head] for head in heads]
        
        r_idx.extend([int(rel) for rel in relations])
        pos_t_idx.extend([int(tail) for tail in tails])
        for head in heads:
            neg_t = random.choice(all_tails)
            while neg_t in pos_tail_sets[head]:
                neg_t = random.choice(all_tails)
            neg_t_idx.append(h_dict[neg_t])

        h_idx  = torch.LongTensor(h_idx).to(device)
        r_idx  = torch.LongTensor(r_idx).to(device)
        pos_t_idx  = torch.LongTensor(pos_t_idx).to(device)
        neg_t_idx  = torch.LongTensor(neg_t_idx).to(device)
        yield h_idx, r_idx, pos_t_idx, neg_t_idx

# %% [markdown]
# ## Layers

# %%
class HGNNConv(nn.Module):
    def __init__(self, leaky, input_dim, hyper_dim, bias=False):
        super(HGNNConv, self).__init__()
        self.hyper_dim = hyper_dim
        self.act = nn.LeakyReLU(negative_slope=leaky).to(device)
        self.fc = nn.Linear(input_dim, hyper_dim ,bias=False).to(device) 
        
        self.ln1 = torch.nn.LayerNorm(hyper_dim).to(device)
        self.ln2 = torch.nn.LayerNorm(hyper_dim).to(device)
        
    def forward(self, adj, embeds):
        lat1 = self.ln1(self.fc(torch.spmm(adj.t(), embeds)))
        output = self.act((self.ln2(torch.spmm(adj, lat1))))
        return output

# %% [markdown]
# ## Model

# %%
class Model(nn.Module):
    def __init__(self, config, data, data_kg, args):
        super(Model, self).__init__()
        self.data = data
        adj = data.interaction_mat
        self.data_kg = data_kg 
        kg_adj = data_kg.kg_interaction_mat
        self.adj  = TorchGraphInterface.convert_sparse_mat_to_tensor(adj).to(device)
        self.kg_adj = TorchGraphInterface.convert_sparse_mat_to_tensor(kg_adj).to(device)

        self.user_indices =  torch.LongTensor(list(data.user.keys())).to(device)
        self.item_indices = torch.LongTensor(list(data.item.keys())).to(device)
        
        self._parse_args(args)
        self.embedding_dict = self._init_model()
        
        self.fc_u = nn.Linear(self.input_dim, self.hyper_dim)
        self.fc_i = nn.Linear(self.input_dim, self.hyper_dim)
        self.fc_e = nn.Linear(self.input_dim, self.hyper_dim)
        
        self.hgnn_u = [HGNNConv(leaky=self.p, input_dim=self.hyper_dim, hyper_dim=self.hyper_dim) for i in range(self.layers)]
        self.hgnn_i = [HGNNConv(leaky=self.p, input_dim=self.hyper_dim, hyper_dim=self.hyper_dim) for i in range(self.layers) ] 
        self.hgnn_e = [HGNNConv(leaky=self.p, input_dim=self.hyper_dim, hyper_dim=self.hyper_dim) for i in range(self.layers) ] 
        
        self.relation_emb =   nn.Parameter(init.xavier_uniform_(torch.empty(self.data_kg.n_relations, self.input_dim))).to(device)
        self.trans_M = nn.Parameter(init.xavier_uniform_(torch.empty(self.data_kg.n_relations, self.hyper_dim, self.relation_dim))).to(device)

        self.non_linear = nn.ReLU()
        self.act = nn.LeakyReLU(self.p)
        self.dropout = nn.Dropout(self.drop_rate)
        self.apply(self._init_weights)
        
    def _parse_args(self, args):
        self.input_dim = args['input_dim']
        self.hyper_dim = args['hyper_dim']
        self.p = args['p']
        self.drop_rate = args['drop_rate'] 
        self.layers = args['n_layers']
        self.temp = args['temp']
        self.aug_type = args['aug_type']
        self.relation_dim = args['relation_dim']

    def _init_model(self):
        initializer = init.xavier_uniform_
        embedding_dict = nn.ParameterDict({
            'user_entity_emb': nn.Parameter(initializer(torch.empty(self.data_kg.n_users_entities, self.input_dim)).to(device)),
            'entity_emb': nn.Parameter(initializer(torch.empty(self.data_kg.n_relations, self.input_dim)).to(device))
        })
        return embedding_dict
    
    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            init.normal_(m.weight, std=0.01)
            if m.bias is not None:
                init.zeros_(m.bias)

    def graph_reconstruction(self):
        if self.aug_type==0 or 1:
            dropped_adj = self.random_graph_augment()
        else:
            dropped_adj = [], []
            for k in range(self.n_layers):
                dropped_adj = self.random_graph_augment()
                dropped_adj.append(dropped_adj_)
        return dropped_adj

    def random_graph_augment(self):
        dropped_mat = None
        if self.aug_type == 0:
            dropped_mat = GraphAugmentor.node_dropout(self.data.interaction_mat, self.drop_rate)
        elif self.aug_type == 1 or self.aug_type == 2:
            dropped_mat = GraphAugmentor.edge_dropout(self.data.interaction_mat, self.drop_rate)
        return TorchGraphInterface.convert_sparse_mat_to_tensor(dropped_mat).to(device)

    def calculate_cf_embeddings(self, perturbed_adj=None):
        uEmbed = self.embedding_dict['user_entity_emb'][self.user_indices]
        iEmbed = self.embedding_dict['user_entity_emb'][self.item_indices]
        
        uEmbed = self.dropout(self.act(self.fc_u(uEmbed)))
        iEmbed = self.dropout(self.act(self.fc_i(iEmbed)))
        
        embeds = torch.cat([uEmbed, iEmbed], 0)
        all_embeddings = [embeds]
        
        for k in range(self.layers):     
            if perturbed_adj is not None:
                if isinstance(perturbed_adj, list):
                    hyperULat = self.hgnn_u[k](perturbed_adj[k], uEmbed)
                    hyperILat = self.hgnn_i[k](perturbed_adj[k].t(), iEmbed)
                else:
                    hyperULat = self.hgnn_u[k](perturbed_adj, uEmbed)
                    hyperILat = self.hgnn_i[k](perturbed_adj.t(), iEmbed)
            else:
                hyperULat = self.hgnn_u[k](self.adj, uEmbed)
                hyperILat = self.hgnn_i[k](self.adj.t(), iEmbed)
            
            uEmbed += hyperULat
            iEmbed += hyperILat
            ego_embeddings = torch.cat([hyperULat, hyperILat], dim=0)
            all_embeddings += [ego_embeddings]
            
        all_embeddings = torch.stack(all_embeddings, dim=1)
        all_embeddings = torch.mean(all_embeddings, dim=1)
        user_all_embeddings = all_embeddings[:self.data.n_users]
        item_all_embeddings = all_embeddings[self.data.n_users:]
        return user_all_embeddings, item_all_embeddings 

    def calculate_kg_embeddings(self, perturbed_adj=None):
        eEmbed = self.embedding_dict['user_entity_emb']
        
        eEmbed = self.dropout(self.act(self.fc_e(eEmbed)))
        
        embeds = torch.cat([eEmbed], 0)
        all_embeddings = [embeds]
        
        for k in range(self.layers):     
            if perturbed_adj is not None:
                if isinstance(perturbed_adj, list):
                    hyperELat = self.hgnn_e[k](perturbed_adj[k], eEmbed)
                else:
                    hyperELat = self.hgnn_e[k](perturbed_adj, eEmbed)
            else:
                hyperELat = self.hgnn_e[k](self.kg_adj, eEmbed)
            
            eEmbed += hyperELat
            all_embeddings += [eEmbed]
            
        all_embeddings = torch.stack(all_embeddings, dim=1)
        all_embeddings = torch.mean(all_embeddings, dim=1)
        return all_embeddings 

    def forward(self, perturbed_adj=None, mode='cf'):
        if mode == 'cf':
            user_embed, item_embed = self.calculate_cf_embeddings(perturbed_adj)
            return user_embed, item_embed
        elif mode == 'kg':
            entity_embed = self.calculate_kg_embeddings(perturbed_adj)
            return entity_embed 

    def calculate_cf_loss(self, anchor_emb, pos_emb, neg_emb, reg):
        calc_reg_loss = EmbLoss()
        rec_loss = bpr_loss(anchor_emb, pos_emb, neg_emb)
        reg_loss = reg * calc_reg_loss(anchor_emb, pos_emb, neg_emb)

        cf_loss  = rec_loss + reg_loss
        return cf_loss
    
    def calculate_kg_loss(self, h_embed, r, pos_t_embed, neg_t_embed, reg_kg):
        calc_reg_loss = EmbLoss()
        
        r_embed = self.relation_emb[r]                                                # (kg_batch_size, relation_dim)
        W_r = self.trans_M[r]                                                           # (kg_batch_size, embed_dim, relation_dim)

        # h_embed = self.user_entity_emb[h]                                          # (kg_batch_size, embed_dim)
        # pos_t_embed = self.user_entity_emb[pos_t]                                    # (kg_batch_size, embed_dim)
        # neg_t_embed = self.user_entity_emb[neg_t]                                     # (kg_batch_size, embed_dim)

        r_mul_h = torch.bmm(h_embed.unsqueeze(1), W_r).squeeze(1)                       # (kg_batch_size, relation_dim)
        r_mul_pos_t = torch.bmm(pos_t_embed.unsqueeze(1), W_r).squeeze(1)               # (kg_batch_size, relation_dim)
        r_mul_neg_t = torch.bmm(neg_t_embed.unsqueeze(1), W_r).squeeze(1)               # (kg_batch_size, relation_dim)

        # Equation (1)
        pos_score = torch.sum(torch.pow(r_mul_h + r_embed - r_mul_pos_t, 2), dim=1)     # (kg_batch_size)
        neg_score = torch.sum(torch.pow(r_mul_h + r_embed - r_mul_neg_t, 2), dim=1)     # (kg_batch_size)

        # Equation (2)
        # kg_loss = F.softplus(pos_score - neg_score)
        kg_loss = (-1.0) * F.logsigmoid(neg_score - pos_score)
        kg_loss = torch.mean(kg_loss)

        reg_loss =  reg_kg * calc_reg_loss(r_mul_h, r_embed, r_mul_pos_t, r_mul_neg_t)
        loss = kg_loss + reg_loss
        return loss
        
    def cal_cl_loss(self, idxs, perturbed_mat1, perturbed_mat2):
        if type(idxs[0]) is not list:
            u_idx = torch.unique(idxs[0])
        else:
            u_idx = torch.unique(torch.Tensor(idxs[0]).to(device).type(torch.long))
        if type(idxs[1]) is not list:
            i_idx = torch.unique(idxs[1])
        else:
            i_idx = torch.unique(torch.Tensor(idxs[1]).to(device).type(torch.long))
        user_view_1, item_view_1 = self.forward(perturbed_mat1)
        user_view_2, item_view_2 = self.forward(perturbed_mat2)
        view1 = torch.cat((user_view_1[u_idx],item_view_1[i_idx]),0)
        view2 = torch.cat((user_view_2[u_idx],item_view_2[i_idx]),0)
        return InfoNCE(view1,view2,self.temp)

# %% [markdown]
# ## Util

# %%
def predict(u, rec, user_emb, item_emb):
    user_id  = rec.data.get_user_id(u)
    score = torch.matmul(user_emb[user_id], item_emb.transpose(0, 1))
    return score.cpu().numpy()

# %% [markdown]
# ## Train

# %%
def train(train_model, data):
    lst_train_losses = []
    lst_cf_losses = []
    lst_kg_losses = []
    lst_performances = []
    
    for ep in range(maxEpoch):
        cf_losses = []
        kg_losses = []
        
        cf_total_loss = 0
        kg_total_loss = 0

        n_cf_batch = int(rec.data.n_cf_train // batchSize + 1)
        n_kg_batch = int(rec.data_kg.n_kg_train // batchSizeKG + 1)

        train_model.train()
        for n, batch in enumerate(next_batch_pairwise(rec.data, batchSize)):
            user_idx, pos_idx, neg_idx = batch
            user_emb, item_emb = train_model()
            anchor_emb = user_emb[user_idx]
            pos_emb = item_emb[pos_idx]
            neg_emb = item_emb[neg_idx]
            
            cf_batch_loss = train_model.calculate_cf_loss(anchor_emb, pos_emb, neg_emb, reg)
            cf_losses.append(cf_batch_loss.item())
            
            cf_optimizer.zero_grad()
            cf_batch_loss.backward()
            cf_optimizer.step()

            cf_total_loss += cf_batch_loss.item()
                        
            if (n % 20) == 0:
                print('CF Training: Epoch {:04d} Iter {:04d} / {:04d} | Iter Loss {:.4f} | Iter Mean Loss {:.4f}'.format(ep, n, n_cf_batch,  cf_batch_loss.item(), cf_total_loss / (n+1)))

        for n, batch in enumerate(next_batch_kg(rec.data_kg, batchSizeKG)):
            kg_batch_head, kg_batch_relation, kg_batch_pos_tail, kg_batch_neg_tail = batch
            
            ego_embed = train_model(mode='kg')
            kg_batch_head_emb = ego_embed[kg_batch_head]
            kg_batch_pos_tail_emb = ego_embed[kg_batch_pos_tail]
            kg_batch_neg_tail_emb = ego_embed[kg_batch_neg_tail]
            
            kg_batch_loss = train_model.calculate_kg_loss(kg_batch_head_emb, kg_batch_relation, kg_batch_pos_tail_emb, kg_batch_neg_tail_emb, reg_kg)
            kg_losses.append(kg_batch_loss.item())

            kg_optimizer.zero_grad()
            kg_batch_loss.backward()
            kg_optimizer.step()

            kg_total_loss += kg_batch_loss.item()
            if (n % 10) == 0:
                print('KG Training: Epoch {:04d} Iter {:04d} / {:04d} | Iter Loss {:.4f} | Iter Mean Loss {:.4f}'.format(ep, n, n_kg_batch, kg_batch_loss.item(), kg_total_loss / (n+1)))
        

        cf_loss = np.mean(cf_losses)
        scheduler_cf.step(cf_loss)

        kg_loss = np.mean(kg_losses)
        scheduler_kg.step(kg_loss)

        train_loss =  cf_loss + kg_loss
        
        lst_train_losses.append([ep, train_loss])
        lst_cf_losses.append([ep,cf_loss])
        lst_kg_losses.append([ep, kg_loss])

        # Evaluation
        train_model.eval()
        with torch.no_grad():
            user_emb, item_emb = train_model(mode='cf')
            data_ep = rec.fast_evaluation(train_model, ep, user_emb, item_emb)
        lst_performances.append(data_ep)

    rec.save_loss(lst_train_losses, lst_kg_losses, lst_cf_losses)
    rec.save_perfomance_training(lst_performances)
    user_emb, item_emb = rec.best_user_emb, rec.best_item_emb
    return user_emb, item_emb

# %% [markdown]
# ## Test

# %%
def test(rec, user_emb, item_emb):
    def process_bar(num, total):
        rate = float(num) / total
        ratenum = int(50 * rate)
        r = '\rProgress: [{}{}]{}%'.format('+' * ratenum, ' ' * (50 - ratenum), ratenum*2)
        sys.stdout.write(r)
        sys.stdout.flush()

    # predict
    rec_list = {}
    user_count = len(rec.data.test_set)
    for i, user in enumerate(rec.data.test_set):
        # s_find_candidates = time.time()
        candidates = predict(user, rec, user_emb, item_emb)
        rated_list, li = rec.data.user_rated(user)
        for item in rated_list:
            candidates[rec.data.item[item]] = -10e8

        # s_find_k_largest = time.time()
        ids, scores = find_k_largest(rec.max_N, candidates)
        # e_find_k_largest = time.time()
        # print("Find k largest candidates: %f s" % (e_find_k_largest - s_find_k_largest))
        item_names = [rec.data.id2item[iid] for iid in ids]
        rec_list[user] = list(zip(item_names, scores))
        if i % 1000 == 0:
            process_bar(i, user_count)
    process_bar(user_count, user_count)
    print('')
    rec.evaluate(rec_list)

# %% [markdown]
# ## Main

# %%
model = 'HGNN'
if model not in ['HGNN', 'LightGCN']:
    print("No model found.")
config = ModelConf('./conf/' + model + '.conf')

dataset = ['lastfm', 'ml-1m']
batchSize = 2048
batchSizeKG = 8192
maxEpoch = 500
lRates = [0.01]
lRateKgs = [0.001]
lrDecays = [0.9]
regs = [0.1]
reg_kgs = [1e-3]
hyperDims = [128]
inputDims = [32]
ps = [0.3]
dropRates = [0.5]
nLayers = [2]
nHeads = [1]
nSelfAtt = [1]
clRate = [0.1, 0.01]
augType = [1]
temp = [0.3]

hyperparameters = [dataset, lRates, lRateKgs, lrDecays, regs, reg_kgs, hyperDims, inputDims, ps, dropRates, nLayers, nHeads, nSelfAtt, clRate, augType, temp]

# %%
dataset = 'lastfm'
training_data = FileIO.load_data_set('./dataset/' + dataset + '/' +config['training.set'], config['model.type'])
test_data = FileIO.load_data_set('./dataset/' + dataset + '/'  +config['test.set'], config['model.type'])
knowledge_set = FileIO.load_kg_data('./dataset/' + dataset +'/'+ dataset +'.kg')
data = Interaction(config, training_data, test_data)
data_kg = Knowledge(config, training_data, test_data, knowledge_set)
# Out:
# /tmp/ipykernel_120525/2675761588.py:181: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -1.0).flatten()

# %%
for params in product(*hyperparameters):
    dataset, lr, lr_kg, lr_decay, reg, reg_kg, hyper_dim, input_dim, prob, drop_rate, n_layers, n_heads, n_self_att, cl_rate, aug_type, temp = params
    print(params)
    args = {
        'lr': lr,
        'lr_kg': lr_kg,
        'lr_decay': lr_decay,
        'reg': reg,
        'reg_kg': reg_kg,
        'hyper_dim': hyper_dim,
        'input_dim': input_dim,
        'p': prob,
        'drop_rate': drop_rate,
        'n_layers': n_layers,
        'input_dim': input_dim,
        'hyper_dim': hyper_dim,
        'relation_dim': 32,
        'n_heads': n_heads,
        'n_self_att': n_self_att,
        'dataset': dataset,
        'cl_rate': cl_rate,
        'aug_type': aug_type,
        'temp': temp
    }
    rec = GraphRecommender(config, data, data_kg, knowledge_set, **args)
    train_model = Model(rec.config, rec.data, rec.data_kg, args).to(device)
    cf_optimizer  = torch.optim.Adam(train_model.parameters(), lr=lr)
    kg_optimizer  = torch.optim.Adam(train_model.parameters(), lr=lr_kg)

    scheduler_cf = ReduceLROnPlateau(cf_optimizer, 'min', factor=lr_decay, patience=10)
    scheduler_kg = ReduceLROnPlateau(kg_optimizer, 'min', factor=lr_decay, patience=10)
    user_emb, item_emb = train(train_model, rec.data)
    test(rec, user_emb, item_emb)
# Out:
# ('lastfm', 0.01, 0.001, 0.9, 0.1, 0.001, 128, 32, 0.3, 0.5, 2, 1, 1, 0.1, 1, 0.3)
# CF Training: Epoch 0000 Iter 0000 / 0034 | Iter Loss 0.7104 | Iter Mean Loss 0.7104
# CF Training: Epoch 0000 Iter 0020 / 0034 | Iter Loss 0.5193 | Iter Mean Loss 0.5930
# KG Training: Epoch 0000 Iter 0000 / 0263 | Iter Loss 0.6760 | Iter Mean Loss 0.6760
# KG Training: Epoch 0000 Iter 0010 / 0263 | Iter Loss 0.6627 | Iter Mean Loss 0.6787
# KG Training: Epoch 0000 Iter 0020 / 0263 | Iter Loss 0.5844 | Iter Mean Loss 0.6487
# KG Training: Epoch 0000 Iter 0030 / 0263 | Iter Loss 0.5427 | Iter Mean Loss 0.6188
# KG Training: Epoch 0000 Iter 0040 / 0263 | Iter Loss 0.5118 | Iter Mean Loss 0.5959
# KG Training: Epoch 0000 Iter 0050 / 0263 | Iter Loss 0.5108 | Iter Mean Loss 0.5778
# KG Training: Epoch 0000 Iter 0060 / 0263 | Iter Loss 0.4714 | Iter Mean Loss 0.5626
# KG Training: Epoch 0000 Iter 0070 / 0263 | Iter Loss 0.6660 | Iter Mean Loss 0.5800
# KG Training: Epoch 0000 Iter 0080 / 0263 | Iter Loss 0.5549 | Iter Mean Loss 0.5818
# KG Training: Epoch 0000 Iter 0090 / 0263 | Iter Loss 0.6488 | Iter Mean Loss 0.5896
# KG Training: Epoch 0000 Iter 0100 / 0263 | Iter Loss 0.5991 | Iter Mean Loss 0.5931
# KG Training: Epoch 0000 Iter 0110 / 0263 | Iter Loss 0.5316 | Iter Mean Loss 0.5904
# KG Training: Epoch 0000 Iter 0120 / 0263 | Iter Loss 0.4883 | Iter Mean Loss 0.5831
# KG Training: Epoch 0000 Iter 0130 / 0263 | Iter Loss 0.4418 | Iter Mean Loss 0.5736
# KG Training: Epoch 0000 Iter 0140 / 0263 | Iter Loss 0.4251 | Iter Mean Loss 0.5638
# KG Training: Epoch 0000 Iter 0150 / 0263 | Iter Loss 0.6113 | Iter Mean Loss 0.5624
# KG Training: Epoch 0000 Iter 0160 / 0263 | Iter Loss 0.4870 | Iter Mean Loss 0.5602
# KG Training: Epoch 0000 Iter 0170 / 0263 | Iter Loss 0.4949 | Iter Mean Loss 0.5595
# KG Training: Epoch 0000 Iter 0180 / 0263 | Iter Loss 0.4411 | Iter Mean Loss 0.5542
# KG Training: Epoch 0000 Iter 0190 / 0263 | Iter Loss 0.3947 | Iter Mean Loss 0.5466
# KG Training: Epoch 0000 Iter 0200 / 0263 | Iter Loss 0.3643 | Iter Mean Loss 0.5384
# KG Training: Epoch 0000 Iter 0210 / 0263 | Iter Loss 0.3453 | Iter Mean Loss 0.5299
# KG Training: Epoch 0000 Iter 0220 / 0263 | Iter Loss 0.3560 | Iter Mean Loss 0.5216
# KG Training: Epoch 0000 Iter 0230 / 0263 | Iter Loss 0.5442 | Iter Mean Loss 0.5163
# KG Training: Epoch 0000 Iter 0240 / 0263 | Iter Loss 0.3884 | Iter Mean Loss 0.5135
# KG Training: Epoch 0000 Iter 0250 / 0263 | Iter Loss 0.4968 | Iter Mean Loss 0.5126
# KG Training: Epoch 0000 Iter 0260 / 0263 | Iter Loss 0.4089 | Iter Mean Loss 0.5133
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 3.020554 s
# Measure time: 0.014463 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 1, Hit Ratio:0.00987  |  Precision:0.00608  |  Recall:0.00985  |  NDCG:0.00699
# *Best Performance*
# Epoch:fast_evaluation 1, Hit Ratio:0.00987  |  Precision:0.00608  |  Recall:0.00985  |  NDCG:0.00699
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0001 Iter 0000 / 0034 | Iter Loss 0.4147 | Iter Mean Loss 0.4147
# CF Training: Epoch 0001 Iter 0020 / 0034 | Iter Loss 0.3024 | Iter Mean Loss 0.3424
# KG Training: Epoch 0001 Iter 0000 / 0263 | Iter Loss 0.4979 | Iter Mean Loss 0.4979
# KG Training: Epoch 0001 Iter 0010 / 0263 | Iter Loss 0.6425 | Iter Mean Loss 0.5955
# KG Training: Epoch 0001 Iter 0020 / 0263 | Iter Loss 0.5134 | Iter Mean Loss 0.5776
# KG Training: Epoch 0001 Iter 0030 / 0263 | Iter Loss 0.4604 | Iter Mean Loss 0.5488
# KG Training: Epoch 0001 Iter 0040 / 0263 | Iter Loss 0.4460 | Iter Mean Loss 0.5271
# KG Training: Epoch 0001 Iter 0050 / 0263 | Iter Loss 0.4381 | Iter Mean Loss 0.5091
# KG Training: Epoch 0001 Iter 0060 / 0263 | Iter Loss 0.4099 | Iter Mean Loss 0.4938
# KG Training: Epoch 0001 Iter 0070 / 0263 | Iter Loss 0.5001 | Iter Mean Loss 0.4952
# KG Training: Epoch 0001 Iter 0080 / 0263 | Iter Loss 0.3999 | Iter Mean Loss 0.4879
# KG Training: Epoch 0001 Iter 0090 / 0263 | Iter Loss 0.3982 | Iter Mean Loss 0.4860
# KG Training: Epoch 0001 Iter 0100 / 0263 | Iter Loss 0.3656 | Iter Mean Loss 0.4763
# KG Training: Epoch 0001 Iter 0110 / 0263 | Iter Loss 0.3382 | Iter Mean Loss 0.4648
# KG Training: Epoch 0001 Iter 0120 / 0263 | Iter Loss 0.3351 | Iter Mean Loss 0.4538
# KG Training: Epoch 0001 Iter 0130 / 0263 | Iter Loss 0.3021 | Iter Mean Loss 0.4428
# KG Training: Epoch 0001 Iter 0140 / 0263 | Iter Loss 0.2863 | Iter Mean Loss 0.4327
# KG Training: Epoch 0001 Iter 0150 / 0263 | Iter Loss 0.4831 | Iter Mean Loss 0.4304
# KG Training: Epoch 0001 Iter 0160 / 0263 | Iter Loss 0.3942 | Iter Mean Loss 0.4308
# KG Training: Epoch 0001 Iter 0170 / 0263 | Iter Loss 0.3303 | Iter Mean Loss 0.4311
# KG Training: Epoch 0001 Iter 0180 / 0263 | Iter Loss 0.3048 | Iter Mean Loss 0.4250
# KG Training: Epoch 0001 Iter 0190 / 0263 | Iter Loss 0.2892 | Iter Mean Loss 0.4184
# KG Training: Epoch 0001 Iter 0200 / 0263 | Iter Loss 0.2778 | Iter Mean Loss 0.4118
# KG Training: Epoch 0001 Iter 0210 / 0263 | Iter Loss 0.2634 | Iter Mean Loss 0.4055
# KG Training: Epoch 0001 Iter 0220 / 0263 | Iter Loss 0.2860 | Iter Mean Loss 0.3996
# KG Training: Epoch 0001 Iter 0230 / 0263 | Iter Loss 0.3922 | Iter Mean Loss 0.3955
# KG Training: Epoch 0001 Iter 0240 / 0263 | Iter Loss 0.3305 | Iter Mean Loss 0.3940
# KG Training: Epoch 0001 Iter 0250 / 0263 | Iter Loss 0.3984 | Iter Mean Loss 0.3931
# KG Training: Epoch 0001 Iter 0260 / 0263 | Iter Loss 0.2639 | Iter Mean Loss 0.3901
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.196310 s
# Measure time: 0.015435 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 2, Hit Ratio:0.04624  |  Precision:0.02848  |  Recall:0.04677  |  NDCG:0.03749
# *Best Performance*
# Epoch:fast_evaluation 2, Hit Ratio:0.04624  |  Precision:0.02848  |  Recall:0.04677  |  NDCG:0.03749
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0002 Iter 0000 / 0034 | Iter Loss 0.2640 | Iter Mean Loss 0.2640
# CF Training: Epoch 0002 Iter 0020 / 0034 | Iter Loss 0.2263 | Iter Mean Loss 0.2489
# KG Training: Epoch 0002 Iter 0000 / 0263 | Iter Loss 0.4035 | Iter Mean Loss 0.4035
# KG Training: Epoch 0002 Iter 0010 / 0263 | Iter Loss 0.4991 | Iter Mean Loss 0.4510
# KG Training: Epoch 0002 Iter 0020 / 0263 | Iter Loss 0.4233 | Iter Mean Loss 0.4487
# KG Training: Epoch 0002 Iter 0030 / 0263 | Iter Loss 0.3749 | Iter Mean Loss 0.4310
# KG Training: Epoch 0002 Iter 0040 / 0263 | Iter Loss 0.3592 | Iter Mean Loss 0.4171
# KG Training: Epoch 0002 Iter 0050 / 0263 | Iter Loss 0.3576 | Iter Mean Loss 0.4051
# KG Training: Epoch 0002 Iter 0060 / 0263 | Iter Loss 0.3290 | Iter Mean Loss 0.3948
# KG Training: Epoch 0002 Iter 0070 / 0263 | Iter Loss 0.4102 | Iter Mean Loss 0.3971
# KG Training: Epoch 0002 Iter 0080 / 0263 | Iter Loss 0.3341 | Iter Mean Loss 0.3933
# KG Training: Epoch 0002 Iter 0090 / 0263 | Iter Loss 0.3126 | Iter Mean Loss 0.3918
# KG Training: Epoch 0002 Iter 0100 / 0263 | Iter Loss 0.2850 | Iter Mean Loss 0.3830
# KG Training: Epoch 0002 Iter 0110 / 0263 | Iter Loss 0.2644 | Iter Mean Loss 0.3731
# KG Training: Epoch 0002 Iter 0120 / 0263 | Iter Loss 0.2720 | Iter Mean Loss 0.3640
# KG Training: Epoch 0002 Iter 0130 / 0263 | Iter Loss 0.2412 | Iter Mean Loss 0.3553
# KG Training: Epoch 0002 Iter 0140 / 0263 | Iter Loss 0.2364 | Iter Mean Loss 0.3480
# KG Training: Epoch 0002 Iter 0150 / 0263 | Iter Loss 0.4184 | Iter Mean Loss 0.3473
# KG Training: Epoch 0002 Iter 0160 / 0263 | Iter Loss 0.3384 | Iter Mean Loss 0.3489
# KG Training: Epoch 0002 Iter 0170 / 0263 | Iter Loss 0.2804 | Iter Mean Loss 0.3498
# KG Training: Epoch 0002 Iter 0180 / 0263 | Iter Loss 0.2569 | Iter Mean Loss 0.3455
# KG Training: Epoch 0002 Iter 0190 / 0263 | Iter Loss 0.2438 | Iter Mean Loss 0.3405
# KG Training: Epoch 0002 Iter 0200 / 0263 | Iter Loss 0.2314 | Iter Mean Loss 0.3358
# KG Training: Epoch 0002 Iter 0210 / 0263 | Iter Loss 0.2273 | Iter Mean Loss 0.3311
# KG Training: Epoch 0002 Iter 0220 / 0263 | Iter Loss 0.2484 | Iter Mean Loss 0.3269
# KG Training: Epoch 0002 Iter 0230 / 0263 | Iter Loss 0.3466 | Iter Mean Loss 0.3242
# KG Training: Epoch 0002 Iter 0240 / 0263 | Iter Loss 0.2977 | Iter Mean Loss 0.3241
# KG Training: Epoch 0002 Iter 0250 / 0263 | Iter Loss 0.3280 | Iter Mean Loss 0.3237
# KG Training: Epoch 0002 Iter 0260 / 0263 | Iter Loss 0.2045 | Iter Mean Loss 0.3211
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.192754 s
# Measure time: 0.015218 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 3, Hit Ratio:0.06223  |  Precision:0.03832  |  Recall:0.06323  |  NDCG:0.05513
# *Best Performance*
# Epoch:fast_evaluation 3, Hit Ratio:0.06223  |  Precision:0.03832  |  Recall:0.06323  |  NDCG:0.05513
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0003 Iter 0000 / 0034 | Iter Loss 0.1970 | Iter Mean Loss 0.1970
# CF Training: Epoch 0003 Iter 0020 / 0034 | Iter Loss 0.1782 | Iter Mean Loss 0.1937
# KG Training: Epoch 0003 Iter 0000 / 0263 | Iter Loss 0.3539 | Iter Mean Loss 0.3539
# KG Training: Epoch 0003 Iter 0010 / 0263 | Iter Loss 0.4233 | Iter Mean Loss 0.3863
# KG Training: Epoch 0003 Iter 0020 / 0263 | Iter Loss 0.3547 | Iter Mean Loss 0.3868
# KG Training: Epoch 0003 Iter 0030 / 0263 | Iter Loss 0.3312 | Iter Mean Loss 0.3741
# KG Training: Epoch 0003 Iter 0040 / 0263 | Iter Loss 0.3190 | Iter Mean Loss 0.3632
# KG Training: Epoch 0003 Iter 0050 / 0263 | Iter Loss 0.3143 | Iter Mean Loss 0.3541
# KG Training: Epoch 0003 Iter 0060 / 0263 | Iter Loss 0.2975 | Iter Mean Loss 0.3461
# KG Training: Epoch 0003 Iter 0070 / 0263 | Iter Loss 0.3721 | Iter Mean Loss 0.3492
# KG Training: Epoch 0003 Iter 0080 / 0263 | Iter Loss 0.3020 | Iter Mean Loss 0.3468
# KG Training: Epoch 0003 Iter 0090 / 0263 | Iter Loss 0.2585 | Iter Mean Loss 0.3461
# KG Training: Epoch 0003 Iter 0100 / 0263 | Iter Loss 0.2510 | Iter Mean Loss 0.3372
# KG Training: Epoch 0003 Iter 0110 / 0263 | Iter Loss 0.2375 | Iter Mean Loss 0.3283
# KG Training: Epoch 0003 Iter 0120 / 0263 | Iter Loss 0.2422 | Iter Mean Loss 0.3203
# KG Training: Epoch 0003 Iter 0130 / 0263 | Iter Loss 0.2164 | Iter Mean Loss 0.3128
# KG Training: Epoch 0003 Iter 0140 / 0263 | Iter Loss 0.2147 | Iter Mean Loss 0.3065
# KG Training: Epoch 0003 Iter 0150 / 0263 | Iter Loss 0.3745 | Iter Mean Loss 0.3063
# KG Training: Epoch 0003 Iter 0160 / 0263 | Iter Loss 0.3101 | Iter Mean Loss 0.3082
# KG Training: Epoch 0003 Iter 0170 / 0263 | Iter Loss 0.2490 | Iter Mean Loss 0.3095
# KG Training: Epoch 0003 Iter 0180 / 0263 | Iter Loss 0.2269 | Iter Mean Loss 0.3059
# KG Training: Epoch 0003 Iter 0190 / 0263 | Iter Loss 0.2141 | Iter Mean Loss 0.3016
# KG Training: Epoch 0003 Iter 0200 / 0263 | Iter Loss 0.2041 | Iter Mean Loss 0.2975
# KG Training: Epoch 0003 Iter 0210 / 0263 | Iter Loss 0.2006 | Iter Mean Loss 0.2934
# KG Training: Epoch 0003 Iter 0220 / 0263 | Iter Loss 0.2242 | Iter Mean Loss 0.2899
# KG Training: Epoch 0003 Iter 0230 / 0263 | Iter Loss 0.3231 | Iter Mean Loss 0.2879
# KG Training: Epoch 0003 Iter 0240 / 0263 | Iter Loss 0.2779 | Iter Mean Loss 0.2884
# KG Training: Epoch 0003 Iter 0250 / 0263 | Iter Loss 0.2986 | Iter Mean Loss 0.2885
# KG Training: Epoch 0003 Iter 0260 / 0263 | Iter Loss 0.1967 | Iter Mean Loss 0.2863
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.191623 s
# Measure time: 0.015502 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 4, Hit Ratio:0.08477  |  Precision:0.0522  |  Recall:0.08492  |  NDCG:0.07463
# *Best Performance*
# Epoch:fast_evaluation 4, Hit Ratio:0.08477  |  Precision:0.0522  |  Recall:0.08492  |  NDCG:0.07463
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0004 Iter 0000 / 0034 | Iter Loss 0.1647 | Iter Mean Loss 0.1647
# CF Training: Epoch 0004 Iter 0020 / 0034 | Iter Loss 0.1554 | Iter Mean Loss 0.1580
# KG Training: Epoch 0004 Iter 0000 / 0263 | Iter Loss 0.3122 | Iter Mean Loss 0.3122
# KG Training: Epoch 0004 Iter 0010 / 0263 | Iter Loss 0.3944 | Iter Mean Loss 0.3535
# KG Training: Epoch 0004 Iter 0020 / 0263 | Iter Loss 0.3285 | Iter Mean Loss 0.3528
# KG Training: Epoch 0004 Iter 0030 / 0263 | Iter Loss 0.2989 | Iter Mean Loss 0.3409
# KG Training: Epoch 0004 Iter 0040 / 0263 | Iter Loss 0.2961 | Iter Mean Loss 0.3319
# KG Training: Epoch 0004 Iter 0050 / 0263 | Iter Loss 0.2913 | Iter Mean Loss 0.3242
# KG Training: Epoch 0004 Iter 0060 / 0263 | Iter Loss 0.2778 | Iter Mean Loss 0.3175
# KG Training: Epoch 0004 Iter 0070 / 0263 | Iter Loss 0.3477 | Iter Mean Loss 0.3211
# KG Training: Epoch 0004 Iter 0080 / 0263 | Iter Loss 0.2861 | Iter Mean Loss 0.3196
# KG Training: Epoch 0004 Iter 0090 / 0263 | Iter Loss 0.2316 | Iter Mean Loss 0.3193
# KG Training: Epoch 0004 Iter 0100 / 0263 | Iter Loss 0.2239 | Iter Mean Loss 0.3106
# KG Training: Epoch 0004 Iter 0110 / 0263 | Iter Loss 0.2095 | Iter Mean Loss 0.3019
# KG Training: Epoch 0004 Iter 0120 / 0263 | Iter Loss 0.2253 | Iter Mean Loss 0.2944
# KG Training: Epoch 0004 Iter 0130 / 0263 | Iter Loss 0.2029 | Iter Mean Loss 0.2874
# KG Training: Epoch 0004 Iter 0140 / 0263 | Iter Loss 0.1998 | Iter Mean Loss 0.2817
# KG Training: Epoch 0004 Iter 0150 / 0263 | Iter Loss 0.3546 | Iter Mean Loss 0.2819
# KG Training: Epoch 0004 Iter 0160 / 0263 | Iter Loss 0.2978 | Iter Mean Loss 0.2842
# KG Training: Epoch 0004 Iter 0170 / 0263 | Iter Loss 0.2282 | Iter Mean Loss 0.2857
# KG Training: Epoch 0004 Iter 0180 / 0263 | Iter Loss 0.2115 | Iter Mean Loss 0.2823
# KG Training: Epoch 0004 Iter 0190 / 0263 | Iter Loss 0.2030 | Iter Mean Loss 0.2784
# KG Training: Epoch 0004 Iter 0200 / 0263 | Iter Loss 0.1882 | Iter Mean Loss 0.2746
# KG Training: Epoch 0004 Iter 0210 / 0263 | Iter Loss 0.1865 | Iter Mean Loss 0.2709
# KG Training: Epoch 0004 Iter 0220 / 0263 | Iter Loss 0.2157 | Iter Mean Loss 0.2677
# KG Training: Epoch 0004 Iter 0230 / 0263 | Iter Loss 0.3038 | Iter Mean Loss 0.2659
# KG Training: Epoch 0004 Iter 0240 / 0263 | Iter Loss 0.2534 | Iter Mean Loss 0.2665
# KG Training: Epoch 0004 Iter 0250 / 0263 | Iter Loss 0.2773 | Iter Mean Loss 0.2668
# KG Training: Epoch 0004 Iter 0260 / 0263 | Iter Loss 0.1797 | Iter Mean Loss 0.2648
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.196108 s
# Measure time: 0.015975 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 5, Hit Ratio:0.11041  |  Precision:0.06799  |  Recall:0.11126  |  NDCG:0.10634
# *Best Performance*
# Epoch:fast_evaluation 5, Hit Ratio:0.11041  |  Precision:0.06799  |  Recall:0.11126  |  NDCG:0.10634
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0005 Iter 0000 / 0034 | Iter Loss 0.1400 | Iter Mean Loss 0.1400
# CF Training: Epoch 0005 Iter 0020 / 0034 | Iter Loss 0.1377 | Iter Mean Loss 0.1348
# KG Training: Epoch 0005 Iter 0000 / 0263 | Iter Loss 0.2837 | Iter Mean Loss 0.2837
# KG Training: Epoch 0005 Iter 0010 / 0263 | Iter Loss 0.3654 | Iter Mean Loss 0.3264
# KG Training: Epoch 0005 Iter 0020 / 0263 | Iter Loss 0.3055 | Iter Mean Loss 0.3284
# KG Training: Epoch 0005 Iter 0030 / 0263 | Iter Loss 0.2880 | Iter Mean Loss 0.3184
# KG Training: Epoch 0005 Iter 0040 / 0263 | Iter Loss 0.2835 | Iter Mean Loss 0.3103
# KG Training: Epoch 0005 Iter 0050 / 0263 | Iter Loss 0.2731 | Iter Mean Loss 0.3035
# KG Training: Epoch 0005 Iter 0060 / 0263 | Iter Loss 0.2617 | Iter Mean Loss 0.2977
# KG Training: Epoch 0005 Iter 0070 / 0263 | Iter Loss 0.3301 | Iter Mean Loss 0.3019
# KG Training: Epoch 0005 Iter 0080 / 0263 | Iter Loss 0.2732 | Iter Mean Loss 0.3009
# KG Training: Epoch 0005 Iter 0090 / 0263 | Iter Loss 0.2165 | Iter Mean Loss 0.3004
# KG Training: Epoch 0005 Iter 0100 / 0263 | Iter Loss 0.2075 | Iter Mean Loss 0.2916
# KG Training: Epoch 0005 Iter 0110 / 0263 | Iter Loss 0.1977 | Iter Mean Loss 0.2833
# KG Training: Epoch 0005 Iter 0120 / 0263 | Iter Loss 0.2112 | Iter Mean Loss 0.2761
# KG Training: Epoch 0005 Iter 0130 / 0263 | Iter Loss 0.1837 | Iter Mean Loss 0.2695
# KG Training: Epoch 0005 Iter 0140 / 0263 | Iter Loss 0.1859 | Iter Mean Loss 0.2640
# KG Training: Epoch 0005 Iter 0150 / 0263 | Iter Loss 0.3307 | Iter Mean Loss 0.2642
# KG Training: Epoch 0005 Iter 0160 / 0263 | Iter Loss 0.2752 | Iter Mean Loss 0.2665
# KG Training: Epoch 0005 Iter 0170 / 0263 | Iter Loss 0.2138 | Iter Mean Loss 0.2681
# KG Training: Epoch 0005 Iter 0180 / 0263 | Iter Loss 0.1916 | Iter Mean Loss 0.2648
# KG Training: Epoch 0005 Iter 0190 / 0263 | Iter Loss 0.1857 | Iter Mean Loss 0.2610
# KG Training: Epoch 0005 Iter 0200 / 0263 | Iter Loss 0.1805 | Iter Mean Loss 0.2574
# KG Training: Epoch 0005 Iter 0210 / 0263 | Iter Loss 0.1853 | Iter Mean Loss 0.2541
# KG Training: Epoch 0005 Iter 0220 / 0263 | Iter Loss 0.2007 | Iter Mean Loss 0.2511
# KG Training: Epoch 0005 Iter 0230 / 0263 | Iter Loss 0.2886 | Iter Mean Loss 0.2496
# KG Training: Epoch 0005 Iter 0240 / 0263 | Iter Loss 0.2481 | Iter Mean Loss 0.2503
# KG Training: Epoch 0005 Iter 0250 / 0263 | Iter Loss 0.2673 | Iter Mean Loss 0.2507
# KG Training: Epoch 0005 Iter 0260 / 0263 | Iter Loss 0.1718 | Iter Mean Loss 0.2489
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.190994 s
# Measure time: 0.015896 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 6, Hit Ratio:0.12769  |  Precision:0.07864  |  Recall:0.12857  |  NDCG:0.12461
# *Best Performance*
# Epoch:fast_evaluation 6, Hit Ratio:0.12769  |  Precision:0.07864  |  Recall:0.12857  |  NDCG:0.12461
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0006 Iter 0000 / 0034 | Iter Loss 0.1355 | Iter Mean Loss 0.1355
# CF Training: Epoch 0006 Iter 0020 / 0034 | Iter Loss 0.1197 | Iter Mean Loss 0.1255
# KG Training: Epoch 0006 Iter 0000 / 0263 | Iter Loss 0.2622 | Iter Mean Loss 0.2622
# KG Training: Epoch 0006 Iter 0010 / 0263 | Iter Loss 0.3526 | Iter Mean Loss 0.3060
# KG Training: Epoch 0006 Iter 0020 / 0263 | Iter Loss 0.2996 | Iter Mean Loss 0.3096
# KG Training: Epoch 0006 Iter 0030 / 0263 | Iter Loss 0.2717 | Iter Mean Loss 0.3012
# KG Training: Epoch 0006 Iter 0040 / 0263 | Iter Loss 0.2643 | Iter Mean Loss 0.2943
# KG Training: Epoch 0006 Iter 0050 / 0263 | Iter Loss 0.2652 | Iter Mean Loss 0.2887
# KG Training: Epoch 0006 Iter 0060 / 0263 | Iter Loss 0.2485 | Iter Mean Loss 0.2836
# KG Training: Epoch 0006 Iter 0070 / 0263 | Iter Loss 0.3208 | Iter Mean Loss 0.2874
# KG Training: Epoch 0006 Iter 0080 / 0263 | Iter Loss 0.2616 | Iter Mean Loss 0.2868
# KG Training: Epoch 0006 Iter 0090 / 0263 | Iter Loss 0.1974 | Iter Mean Loss 0.2859
# KG Training: Epoch 0006 Iter 0100 / 0263 | Iter Loss 0.1922 | Iter Mean Loss 0.2771
# KG Training: Epoch 0006 Iter 0110 / 0263 | Iter Loss 0.1869 | Iter Mean Loss 0.2688
# KG Training: Epoch 0006 Iter 0120 / 0263 | Iter Loss 0.1922 | Iter Mean Loss 0.2618
# KG Training: Epoch 0006 Iter 0130 / 0263 | Iter Loss 0.1731 | Iter Mean Loss 0.2552
# KG Training: Epoch 0006 Iter 0140 / 0263 | Iter Loss 0.1713 | Iter Mean Loss 0.2499
# KG Training: Epoch 0006 Iter 0150 / 0263 | Iter Loss 0.3143 | Iter Mean Loss 0.2501
# KG Training: Epoch 0006 Iter 0160 / 0263 | Iter Loss 0.2685 | Iter Mean Loss 0.2522
# KG Training: Epoch 0006 Iter 0170 / 0263 | Iter Loss 0.1950 | Iter Mean Loss 0.2536
# KG Training: Epoch 0006 Iter 0180 / 0263 | Iter Loss 0.1839 | Iter Mean Loss 0.2503
# KG Training: Epoch 0006 Iter 0190 / 0263 | Iter Loss 0.1754 | Iter Mean Loss 0.2467
# KG Training: Epoch 0006 Iter 0200 / 0263 | Iter Loss 0.1691 | Iter Mean Loss 0.2432
# KG Training: Epoch 0006 Iter 0210 / 0263 | Iter Loss 0.1681 | Iter Mean Loss 0.2399
# KG Training: Epoch 0006 Iter 0220 / 0263 | Iter Loss 0.1870 | Iter Mean Loss 0.2370
# KG Training: Epoch 0006 Iter 0230 / 0263 | Iter Loss 0.2770 | Iter Mean Loss 0.2356
# KG Training: Epoch 0006 Iter 0240 / 0263 | Iter Loss 0.2357 | Iter Mean Loss 0.2365
# KG Training: Epoch 0006 Iter 0250 / 0263 | Iter Loss 0.2516 | Iter Mean Loss 0.2369
# KG Training: Epoch 0006 Iter 0260 / 0263 | Iter Loss 0.1622 | Iter Mean Loss 0.2352
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.188345 s
# Measure time: 0.015589 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 7, Hit Ratio:0.13937  |  Precision:0.08583  |  Recall:0.14083  |  NDCG:0.13565
# *Best Performance*
# Epoch:fast_evaluation 7, Hit Ratio:0.13937  |  Precision:0.08583  |  Recall:0.14083  |  NDCG:0.13565
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0007 Iter 0000 / 0034 | Iter Loss 0.1287 | Iter Mean Loss 0.1287
# CF Training: Epoch 0007 Iter 0020 / 0034 | Iter Loss 0.1177 | Iter Mean Loss 0.1195
# KG Training: Epoch 0007 Iter 0000 / 0263 | Iter Loss 0.2498 | Iter Mean Loss 0.2498
# KG Training: Epoch 0007 Iter 0010 / 0263 | Iter Loss 0.3316 | Iter Mean Loss 0.2904
# KG Training: Epoch 0007 Iter 0020 / 0263 | Iter Loss 0.2877 | Iter Mean Loss 0.2962
# KG Training: Epoch 0007 Iter 0030 / 0263 | Iter Loss 0.2563 | Iter Mean Loss 0.2893
# KG Training: Epoch 0007 Iter 0040 / 0263 | Iter Loss 0.2626 | Iter Mean Loss 0.2834
# KG Training: Epoch 0007 Iter 0050 / 0263 | Iter Loss 0.2555 | Iter Mean Loss 0.2782
# KG Training: Epoch 0007 Iter 0060 / 0263 | Iter Loss 0.2391 | Iter Mean Loss 0.2734
# KG Training: Epoch 0007 Iter 0070 / 0263 | Iter Loss 0.2993 | Iter Mean Loss 0.2767
# KG Training: Epoch 0007 Iter 0080 / 0263 | Iter Loss 0.2448 | Iter Mean Loss 0.2757
# KG Training: Epoch 0007 Iter 0090 / 0263 | Iter Loss 0.1906 | Iter Mean Loss 0.2745
# KG Training: Epoch 0007 Iter 0100 / 0263 | Iter Loss 0.1785 | Iter Mean Loss 0.2657
# KG Training: Epoch 0007 Iter 0110 / 0263 | Iter Loss 0.1738 | Iter Mean Loss 0.2574
# KG Training: Epoch 0007 Iter 0120 / 0263 | Iter Loss 0.1841 | Iter Mean Loss 0.2503
# KG Training: Epoch 0007 Iter 0130 / 0263 | Iter Loss 0.1662 | Iter Mean Loss 0.2438
# KG Training: Epoch 0007 Iter 0140 / 0263 | Iter Loss 0.1614 | Iter Mean Loss 0.2387
# KG Training: Epoch 0007 Iter 0150 / 0263 | Iter Loss 0.2963 | Iter Mean Loss 0.2388
# KG Training: Epoch 0007 Iter 0160 / 0263 | Iter Loss 0.2483 | Iter Mean Loss 0.2409
# KG Training: Epoch 0007 Iter 0170 / 0263 | Iter Loss 0.1834 | Iter Mean Loss 0.2421
# KG Training: Epoch 0007 Iter 0180 / 0263 | Iter Loss 0.1695 | Iter Mean Loss 0.2387
# KG Training: Epoch 0007 Iter 0190 / 0263 | Iter Loss 0.1651 | Iter Mean Loss 0.2350
# KG Training: Epoch 0007 Iter 0200 / 0263 | Iter Loss 0.1596 | Iter Mean Loss 0.2317
# KG Training: Epoch 0007 Iter 0210 / 0263 | Iter Loss 0.1560 | Iter Mean Loss 0.2284
# KG Training: Epoch 0007 Iter 0220 / 0263 | Iter Loss 0.1751 | Iter Mean Loss 0.2257
# KG Training: Epoch 0007 Iter 0230 / 0263 | Iter Loss 0.2596 | Iter Mean Loss 0.2244
# KG Training: Epoch 0007 Iter 0240 / 0263 | Iter Loss 0.2328 | Iter Mean Loss 0.2254
# KG Training: Epoch 0007 Iter 0250 / 0263 | Iter Loss 0.2417 | Iter Mean Loss 0.2259
# KG Training: Epoch 0007 Iter 0260 / 0263 | Iter Loss 0.1523 | Iter Mean Loss 0.2244
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.188951 s
# Measure time: 0.015749 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 8, Hit Ratio:0.13898  |  Precision:0.08559  |  Recall:0.14072  |  NDCG:0.13484
# *Best Performance*
# Epoch:fast_evaluation 7, Hit Ratio:0.13937  |  Precision:0.08583  |  Recall:0.14083  |  NDCG:0.13565
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0008 Iter 0000 / 0034 | Iter Loss 0.1245 | Iter Mean Loss 0.1245
# CF Training: Epoch 0008 Iter 0020 / 0034 | Iter Loss 0.1046 | Iter Mean Loss 0.1089
# KG Training: Epoch 0008 Iter 0000 / 0263 | Iter Loss 0.2402 | Iter Mean Loss 0.2402
# KG Training: Epoch 0008 Iter 0010 / 0263 | Iter Loss 0.3220 | Iter Mean Loss 0.2828
# KG Training: Epoch 0008 Iter 0020 / 0263 | Iter Loss 0.2808 | Iter Mean Loss 0.2879
# KG Training: Epoch 0008 Iter 0030 / 0263 | Iter Loss 0.2528 | Iter Mean Loss 0.2811
# KG Training: Epoch 0008 Iter 0040 / 0263 | Iter Loss 0.2496 | Iter Mean Loss 0.2752
# KG Training: Epoch 0008 Iter 0050 / 0263 | Iter Loss 0.2468 | Iter Mean Loss 0.2701
# KG Training: Epoch 0008 Iter 0060 / 0263 | Iter Loss 0.2365 | Iter Mean Loss 0.2655
# KG Training: Epoch 0008 Iter 0070 / 0263 | Iter Loss 0.2901 | Iter Mean Loss 0.2684
# KG Training: Epoch 0008 Iter 0080 / 0263 | Iter Loss 0.2463 | Iter Mean Loss 0.2677
# KG Training: Epoch 0008 Iter 0090 / 0263 | Iter Loss 0.1789 | Iter Mean Loss 0.2660
# KG Training: Epoch 0008 Iter 0100 / 0263 | Iter Loss 0.1695 | Iter Mean Loss 0.2568
# KG Training: Epoch 0008 Iter 0110 / 0263 | Iter Loss 0.1610 | Iter Mean Loss 0.2482
# KG Training: Epoch 0008 Iter 0120 / 0263 | Iter Loss 0.1738 | Iter Mean Loss 0.2412
# KG Training: Epoch 0008 Iter 0130 / 0263 | Iter Loss 0.1545 | Iter Mean Loss 0.2348
# KG Training: Epoch 0008 Iter 0140 / 0263 | Iter Loss 0.1522 | Iter Mean Loss 0.2296
# KG Training: Epoch 0008 Iter 0150 / 0263 | Iter Loss 0.2883 | Iter Mean Loss 0.2296
# KG Training: Epoch 0008 Iter 0160 / 0263 | Iter Loss 0.2415 | Iter Mean Loss 0.2315
# KG Training: Epoch 0008 Iter 0170 / 0263 | Iter Loss 0.1714 | Iter Mean Loss 0.2324
# KG Training: Epoch 0008 Iter 0180 / 0263 | Iter Loss 0.1600 | Iter Mean Loss 0.2289
# KG Training: Epoch 0008 Iter 0190 / 0263 | Iter Loss 0.1622 | Iter Mean Loss 0.2252
# KG Training: Epoch 0008 Iter 0200 / 0263 | Iter Loss 0.1462 | Iter Mean Loss 0.2218
# KG Training: Epoch 0008 Iter 0210 / 0263 | Iter Loss 0.1448 | Iter Mean Loss 0.2187
# KG Training: Epoch 0008 Iter 0220 / 0263 | Iter Loss 0.1626 | Iter Mean Loss 0.2160
# KG Training: Epoch 0008 Iter 0230 / 0263 | Iter Loss 0.2580 | Iter Mean Loss 0.2148
# KG Training: Epoch 0008 Iter 0240 / 0263 | Iter Loss 0.2165 | Iter Mean Loss 0.2157
# KG Training: Epoch 0008 Iter 0250 / 0263 | Iter Loss 0.2356 | Iter Mean Loss 0.2162
# KG Training: Epoch 0008 Iter 0260 / 0263 | Iter Loss 0.1448 | Iter Mean Loss 0.2147
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.190512 s
# Measure time: 0.016795 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 9, Hit Ratio:0.13053  |  Precision:0.08039  |  Recall:0.13066  |  NDCG:0.12564
# *Best Performance*
# Epoch:fast_evaluation 7, Hit Ratio:0.13937  |  Precision:0.08583  |  Recall:0.14083  |  NDCG:0.13565
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0009 Iter 0000 / 0034 | Iter Loss 0.1177 | Iter Mean Loss 0.1177
# CF Training: Epoch 0009 Iter 0020 / 0034 | Iter Loss 0.1076 | Iter Mean Loss 0.1036
# KG Training: Epoch 0009 Iter 0000 / 0263 | Iter Loss 0.2324 | Iter Mean Loss 0.2324
# KG Training: Epoch 0009 Iter 0010 / 0263 | Iter Loss 0.3036 | Iter Mean Loss 0.2716
# KG Training: Epoch 0009 Iter 0020 / 0263 | Iter Loss 0.2869 | Iter Mean Loss 0.2791
# KG Training: Epoch 0009 Iter 0030 / 0263 | Iter Loss 0.2528 | Iter Mean Loss 0.2733
# KG Training: Epoch 0009 Iter 0040 / 0263 | Iter Loss 0.2437 | Iter Mean Loss 0.2675
# KG Training: Epoch 0009 Iter 0050 / 0263 | Iter Loss 0.2397 | Iter Mean Loss 0.2629
# KG Training: Epoch 0009 Iter 0060 / 0263 | Iter Loss 0.2361 | Iter Mean Loss 0.2586
# KG Training: Epoch 0009 Iter 0070 / 0263 | Iter Loss 0.2816 | Iter Mean Loss 0.2616
# KG Training: Epoch 0009 Iter 0080 / 0263 | Iter Loss 0.2359 | Iter Mean Loss 0.2606
# KG Training: Epoch 0009 Iter 0090 / 0263 | Iter Loss 0.1667 | Iter Mean Loss 0.2582
# KG Training: Epoch 0009 Iter 0100 / 0263 | Iter Loss 0.1577 | Iter Mean Loss 0.2487
# KG Training: Epoch 0009 Iter 0110 / 0263 | Iter Loss 0.1508 | Iter Mean Loss 0.2401
# KG Training: Epoch 0009 Iter 0120 / 0263 | Iter Loss 0.1675 | Iter Mean Loss 0.2330
# KG Training: Epoch 0009 Iter 0130 / 0263 | Iter Loss 0.1416 | Iter Mean Loss 0.2265
# KG Training: Epoch 0009 Iter 0140 / 0263 | Iter Loss 0.1379 | Iter Mean Loss 0.2211
# KG Training: Epoch 0009 Iter 0150 / 0263 | Iter Loss 0.2660 | Iter Mean Loss 0.2210
# KG Training: Epoch 0009 Iter 0160 / 0263 | Iter Loss 0.2314 | Iter Mean Loss 0.2227
# KG Training: Epoch 0009 Iter 0170 / 0263 | Iter Loss 0.1637 | Iter Mean Loss 0.2235
# KG Training: Epoch 0009 Iter 0180 / 0263 | Iter Loss 0.1476 | Iter Mean Loss 0.2200
# KG Training: Epoch 0009 Iter 0190 / 0263 | Iter Loss 0.1509 | Iter Mean Loss 0.2164
# KG Training: Epoch 0009 Iter 0200 / 0263 | Iter Loss 0.1385 | Iter Mean Loss 0.2131
# KG Training: Epoch 0009 Iter 0210 / 0263 | Iter Loss 0.1386 | Iter Mean Loss 0.2100
# KG Training: Epoch 0009 Iter 0220 / 0263 | Iter Loss 0.1613 | Iter Mean Loss 0.2074
# KG Training: Epoch 0009 Iter 0230 / 0263 | Iter Loss 0.2464 | Iter Mean Loss 0.2061
# KG Training: Epoch 0009 Iter 0240 / 0263 | Iter Loss 0.2156 | Iter Mean Loss 0.2070
# KG Training: Epoch 0009 Iter 0250 / 0263 | Iter Loss 0.2254 | Iter Mean Loss 0.2076
# KG Training: Epoch 0009 Iter 0260 / 0263 | Iter Loss 0.1395 | Iter Mean Loss 0.2062
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.188954 s
# Measure time: 0.021230 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 10, Hit Ratio:0.14557  |  Precision:0.08965  |  Recall:0.14625  |  NDCG:0.1438
# *Best Performance*
# Epoch:fast_evaluation 10, Hit Ratio:0.14557  |  Precision:0.08965  |  Recall:0.14625  |  NDCG:0.1438
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0010 Iter 0000 / 0034 | Iter Loss 0.1033 | Iter Mean Loss 0.1033
# CF Training: Epoch 0010 Iter 0020 / 0034 | Iter Loss 0.0948 | Iter Mean Loss 0.0976
# KG Training: Epoch 0010 Iter 0000 / 0263 | Iter Loss 0.2194 | Iter Mean Loss 0.2194
# KG Training: Epoch 0010 Iter 0010 / 0263 | Iter Loss 0.3013 | Iter Mean Loss 0.2640
# KG Training: Epoch 0010 Iter 0020 / 0263 | Iter Loss 0.2672 | Iter Mean Loss 0.2707
# KG Training: Epoch 0010 Iter 0030 / 0263 | Iter Loss 0.2464 | Iter Mean Loss 0.2669
# KG Training: Epoch 0010 Iter 0040 / 0263 | Iter Loss 0.2359 | Iter Mean Loss 0.2620
# KG Training: Epoch 0010 Iter 0050 / 0263 | Iter Loss 0.2381 | Iter Mean Loss 0.2574
# KG Training: Epoch 0010 Iter 0060 / 0263 | Iter Loss 0.2357 | Iter Mean Loss 0.2533
# KG Training: Epoch 0010 Iter 0070 / 0263 | Iter Loss 0.2725 | Iter Mean Loss 0.2561
# KG Training: Epoch 0010 Iter 0080 / 0263 | Iter Loss 0.2279 | Iter Mean Loss 0.2551
# KG Training: Epoch 0010 Iter 0090 / 0263 | Iter Loss 0.1500 | Iter Mean Loss 0.2515
# KG Training: Epoch 0010 Iter 0100 / 0263 | Iter Loss 0.1479 | Iter Mean Loss 0.2417
# KG Training: Epoch 0010 Iter 0110 / 0263 | Iter Loss 0.1445 | Iter Mean Loss 0.2328
# KG Training: Epoch 0010 Iter 0120 / 0263 | Iter Loss 0.1497 | Iter Mean Loss 0.2254
# KG Training: Epoch 0010 Iter 0130 / 0263 | Iter Loss 0.1350 | Iter Mean Loss 0.2187
# KG Training: Epoch 0010 Iter 0140 / 0263 | Iter Loss 0.1354 | Iter Mean Loss 0.2134
# KG Training: Epoch 0010 Iter 0150 / 0263 | Iter Loss 0.2577 | Iter Mean Loss 0.2131
# KG Training: Epoch 0010 Iter 0160 / 0263 | Iter Loss 0.2218 | Iter Mean Loss 0.2147
# KG Training: Epoch 0010 Iter 0170 / 0263 | Iter Loss 0.1532 | Iter Mean Loss 0.2153
# KG Training: Epoch 0010 Iter 0180 / 0263 | Iter Loss 0.1396 | Iter Mean Loss 0.2118
# KG Training: Epoch 0010 Iter 0190 / 0263 | Iter Loss 0.1395 | Iter Mean Loss 0.2080
# KG Training: Epoch 0010 Iter 0200 / 0263 | Iter Loss 0.1327 | Iter Mean Loss 0.2047
# KG Training: Epoch 0010 Iter 0210 / 0263 | Iter Loss 0.1365 | Iter Mean Loss 0.2016
# KG Training: Epoch 0010 Iter 0220 / 0263 | Iter Loss 0.1474 | Iter Mean Loss 0.1988
# KG Training: Epoch 0010 Iter 0230 / 0263 | Iter Loss 0.2415 | Iter Mean Loss 0.1977
# KG Training: Epoch 0010 Iter 0240 / 0263 | Iter Loss 0.2070 | Iter Mean Loss 0.1986
# KG Training: Epoch 0010 Iter 0250 / 0263 | Iter Loss 0.2212 | Iter Mean Loss 0.1993
# KG Training: Epoch 0010 Iter 0260 / 0263 | Iter Loss 0.1373 | Iter Mean Loss 0.1980
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.192772 s
# Measure time: 0.016823 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 11, Hit Ratio:0.15695  |  Precision:0.09666  |  Recall:0.15727  |  NDCG:0.16147
# *Best Performance*
# Epoch:fast_evaluation 11, Hit Ratio:0.15695  |  Precision:0.09666  |  Recall:0.15727  |  NDCG:0.16147
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0011 Iter 0000 / 0034 | Iter Loss 0.0998 | Iter Mean Loss 0.0998
# CF Training: Epoch 0011 Iter 0020 / 0034 | Iter Loss 0.0949 | Iter Mean Loss 0.0940
# KG Training: Epoch 0011 Iter 0000 / 0263 | Iter Loss 0.2116 | Iter Mean Loss 0.2116
# KG Training: Epoch 0011 Iter 0010 / 0263 | Iter Loss 0.2869 | Iter Mean Loss 0.2555
# KG Training: Epoch 0011 Iter 0020 / 0263 | Iter Loss 0.2626 | Iter Mean Loss 0.2636
# KG Training: Epoch 0011 Iter 0030 / 0263 | Iter Loss 0.2365 | Iter Mean Loss 0.2594
# KG Training: Epoch 0011 Iter 0040 / 0263 | Iter Loss 0.2369 | Iter Mean Loss 0.2551
# KG Training: Epoch 0011 Iter 0050 / 0263 | Iter Loss 0.2294 | Iter Mean Loss 0.2508
# KG Training: Epoch 0011 Iter 0060 / 0263 | Iter Loss 0.2272 | Iter Mean Loss 0.2474
# KG Training: Epoch 0011 Iter 0070 / 0263 | Iter Loss 0.2652 | Iter Mean Loss 0.2496
# KG Training: Epoch 0011 Iter 0080 / 0263 | Iter Loss 0.2282 | Iter Mean Loss 0.2485
# KG Training: Epoch 0011 Iter 0090 / 0263 | Iter Loss 0.1426 | Iter Mean Loss 0.2445
# KG Training: Epoch 0011 Iter 0100 / 0263 | Iter Loss 0.1393 | Iter Mean Loss 0.2346
# KG Training: Epoch 0011 Iter 0110 / 0263 | Iter Loss 0.1369 | Iter Mean Loss 0.2255
# KG Training: Epoch 0011 Iter 0120 / 0263 | Iter Loss 0.1457 | Iter Mean Loss 0.2180
# KG Training: Epoch 0011 Iter 0130 / 0263 | Iter Loss 0.1262 | Iter Mean Loss 0.2114
# KG Training: Epoch 0011 Iter 0140 / 0263 | Iter Loss 0.1283 | Iter Mean Loss 0.2060
# KG Training: Epoch 0011 Iter 0150 / 0263 | Iter Loss 0.2590 | Iter Mean Loss 0.2057
# KG Training: Epoch 0011 Iter 0160 / 0263 | Iter Loss 0.2155 | Iter Mean Loss 0.2073
# KG Training: Epoch 0011 Iter 0170 / 0263 | Iter Loss 0.1482 | Iter Mean Loss 0.2075
# KG Training: Epoch 0011 Iter 0180 / 0263 | Iter Loss 0.1328 | Iter Mean Loss 0.2039
# KG Training: Epoch 0011 Iter 0190 / 0263 | Iter Loss 0.1309 | Iter Mean Loss 0.2002
# KG Training: Epoch 0011 Iter 0200 / 0263 | Iter Loss 0.1306 | Iter Mean Loss 0.1969
# KG Training: Epoch 0011 Iter 0210 / 0263 | Iter Loss 0.1269 | Iter Mean Loss 0.1939
# KG Training: Epoch 0011 Iter 0220 / 0263 | Iter Loss 0.1497 | Iter Mean Loss 0.1913
# KG Training: Epoch 0011 Iter 0230 / 0263 | Iter Loss 0.2358 | Iter Mean Loss 0.1901
# KG Training: Epoch 0011 Iter 0240 / 0263 | Iter Loss 0.1984 | Iter Mean Loss 0.1911
# KG Training: Epoch 0011 Iter 0250 / 0263 | Iter Loss 0.2127 | Iter Mean Loss 0.1918
# KG Training: Epoch 0011 Iter 0260 / 0263 | Iter Loss 0.1291 | Iter Mean Loss 0.1906
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.190881 s
# Measure time: 0.015759 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 12, Hit Ratio:0.17065  |  Precision:0.1051  |  Recall:0.17077  |  NDCG:0.17678
# *Best Performance*
# Epoch:fast_evaluation 12, Hit Ratio:0.17065  |  Precision:0.1051  |  Recall:0.17077  |  NDCG:0.17678
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0012 Iter 0000 / 0034 | Iter Loss 0.0974 | Iter Mean Loss 0.0974
# CF Training: Epoch 0012 Iter 0020 / 0034 | Iter Loss 0.0917 | Iter Mean Loss 0.0890
# KG Training: Epoch 0012 Iter 0000 / 0263 | Iter Loss 0.2071 | Iter Mean Loss 0.2071
# KG Training: Epoch 0012 Iter 0010 / 0263 | Iter Loss 0.2930 | Iter Mean Loss 0.2499
# KG Training: Epoch 0012 Iter 0020 / 0263 | Iter Loss 0.2596 | Iter Mean Loss 0.2580
# KG Training: Epoch 0012 Iter 0030 / 0263 | Iter Loss 0.2334 | Iter Mean Loss 0.2542
# KG Training: Epoch 0012 Iter 0040 / 0263 | Iter Loss 0.2278 | Iter Mean Loss 0.2496
# KG Training: Epoch 0012 Iter 0050 / 0263 | Iter Loss 0.2209 | Iter Mean Loss 0.2454
# KG Training: Epoch 0012 Iter 0060 / 0263 | Iter Loss 0.2193 | Iter Mean Loss 0.2417
# KG Training: Epoch 0012 Iter 0070 / 0263 | Iter Loss 0.2605 | Iter Mean Loss 0.2436
# KG Training: Epoch 0012 Iter 0080 / 0263 | Iter Loss 0.2157 | Iter Mean Loss 0.2424
# KG Training: Epoch 0012 Iter 0090 / 0263 | Iter Loss 0.1317 | Iter Mean Loss 0.2375
# KG Training: Epoch 0012 Iter 0100 / 0263 | Iter Loss 0.1291 | Iter Mean Loss 0.2273
# KG Training: Epoch 0012 Iter 0110 / 0263 | Iter Loss 0.1311 | Iter Mean Loss 0.2183
# KG Training: Epoch 0012 Iter 0120 / 0263 | Iter Loss 0.1432 | Iter Mean Loss 0.2109
# KG Training: Epoch 0012 Iter 0130 / 0263 | Iter Loss 0.1278 | Iter Mean Loss 0.2043
# KG Training: Epoch 0012 Iter 0140 / 0263 | Iter Loss 0.1225 | Iter Mean Loss 0.1990
# KG Training: Epoch 0012 Iter 0150 / 0263 | Iter Loss 0.2434 | Iter Mean Loss 0.1986
# KG Training: Epoch 0012 Iter 0160 / 0263 | Iter Loss 0.2077 | Iter Mean Loss 0.2002
# KG Training: Epoch 0012 Iter 0170 / 0263 | Iter Loss 0.1405 | Iter Mean Loss 0.2001
# KG Training: Epoch 0012 Iter 0180 / 0263 | Iter Loss 0.1277 | Iter Mean Loss 0.1965
# KG Training: Epoch 0012 Iter 0190 / 0263 | Iter Loss 0.1236 | Iter Mean Loss 0.1928
# KG Training: Epoch 0012 Iter 0200 / 0263 | Iter Loss 0.1111 | Iter Mean Loss 0.1894
# KG Training: Epoch 0012 Iter 0210 / 0263 | Iter Loss 0.1199 | Iter Mean Loss 0.1863
# KG Training: Epoch 0012 Iter 0220 / 0263 | Iter Loss 0.1354 | Iter Mean Loss 0.1837
# KG Training: Epoch 0012 Iter 0230 / 0263 | Iter Loss 0.2181 | Iter Mean Loss 0.1825
# KG Training: Epoch 0012 Iter 0240 / 0263 | Iter Loss 0.1922 | Iter Mean Loss 0.1835
# KG Training: Epoch 0012 Iter 0250 / 0263 | Iter Loss 0.2090 | Iter Mean Loss 0.1843
# KG Training: Epoch 0012 Iter 0260 / 0263 | Iter Loss 0.1258 | Iter Mean Loss 0.1832
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.194153 s
# Measure time: 0.017306 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 13, Hit Ratio:0.17022  |  Precision:0.10483  |  Recall:0.17096  |  NDCG:0.17222
# *Best Performance*
# Epoch:fast_evaluation 12, Hit Ratio:0.17065  |  Precision:0.1051  |  Recall:0.17077  |  NDCG:0.17678
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0013 Iter 0000 / 0034 | Iter Loss 0.0953 | Iter Mean Loss 0.0953
# CF Training: Epoch 0013 Iter 0020 / 0034 | Iter Loss 0.0866 | Iter Mean Loss 0.0874
# KG Training: Epoch 0013 Iter 0000 / 0263 | Iter Loss 0.2061 | Iter Mean Loss 0.2061
# KG Training: Epoch 0013 Iter 0010 / 0263 | Iter Loss 0.2764 | Iter Mean Loss 0.2435
# KG Training: Epoch 0013 Iter 0020 / 0263 | Iter Loss 0.2500 | Iter Mean Loss 0.2524
# KG Training: Epoch 0013 Iter 0030 / 0263 | Iter Loss 0.2208 | Iter Mean Loss 0.2486
# KG Training: Epoch 0013 Iter 0040 / 0263 | Iter Loss 0.2264 | Iter Mean Loss 0.2443
# KG Training: Epoch 0013 Iter 0050 / 0263 | Iter Loss 0.2245 | Iter Mean Loss 0.2406
# KG Training: Epoch 0013 Iter 0060 / 0263 | Iter Loss 0.2085 | Iter Mean Loss 0.2369
# KG Training: Epoch 0013 Iter 0070 / 0263 | Iter Loss 0.2564 | Iter Mean Loss 0.2392
# KG Training: Epoch 0013 Iter 0080 / 0263 | Iter Loss 0.2145 | Iter Mean Loss 0.2377
# KG Training: Epoch 0013 Iter 0090 / 0263 | Iter Loss 0.1264 | Iter Mean Loss 0.2317
# KG Training: Epoch 0013 Iter 0100 / 0263 | Iter Loss 0.1213 | Iter Mean Loss 0.2213
# KG Training: Epoch 0013 Iter 0110 / 0263 | Iter Loss 0.1175 | Iter Mean Loss 0.2119
# KG Training: Epoch 0013 Iter 0120 / 0263 | Iter Loss 0.1295 | Iter Mean Loss 0.2042
# KG Training: Epoch 0013 Iter 0130 / 0263 | Iter Loss 0.1123 | Iter Mean Loss 0.1976
# KG Training: Epoch 0013 Iter 0140 / 0263 | Iter Loss 0.1130 | Iter Mean Loss 0.1922
# KG Training: Epoch 0013 Iter 0150 / 0263 | Iter Loss 0.2448 | Iter Mean Loss 0.1917
# KG Training: Epoch 0013 Iter 0160 / 0263 | Iter Loss 0.2057 | Iter Mean Loss 0.1933
# KG Training: Epoch 0013 Iter 0170 / 0263 | Iter Loss 0.1330 | Iter Mean Loss 0.1930
# KG Training: Epoch 0013 Iter 0180 / 0263 | Iter Loss 0.1185 | Iter Mean Loss 0.1893
# KG Training: Epoch 0013 Iter 0190 / 0263 | Iter Loss 0.1171 | Iter Mean Loss 0.1856
# KG Training: Epoch 0013 Iter 0200 / 0263 | Iter Loss 0.1100 | Iter Mean Loss 0.1823
# KG Training: Epoch 0013 Iter 0210 / 0263 | Iter Loss 0.1143 | Iter Mean Loss 0.1793
# KG Training: Epoch 0013 Iter 0220 / 0263 | Iter Loss 0.1269 | Iter Mean Loss 0.1767
# KG Training: Epoch 0013 Iter 0230 / 0263 | Iter Loss 0.2097 | Iter Mean Loss 0.1756
# KG Training: Epoch 0013 Iter 0240 / 0263 | Iter Loss 0.1885 | Iter Mean Loss 0.1765
# KG Training: Epoch 0013 Iter 0250 / 0263 | Iter Loss 0.2005 | Iter Mean Loss 0.1773
# KG Training: Epoch 0013 Iter 0260 / 0263 | Iter Loss 0.1223 | Iter Mean Loss 0.1763
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.192138 s
# Measure time: 0.016487 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 14, Hit Ratio:0.15919  |  Precision:0.09804  |  Recall:0.16014  |  NDCG:0.15708
# *Best Performance*
# Epoch:fast_evaluation 12, Hit Ratio:0.17065  |  Precision:0.1051  |  Recall:0.17077  |  NDCG:0.17678
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0014 Iter 0000 / 0034 | Iter Loss 0.0876 | Iter Mean Loss 0.0876
# CF Training: Epoch 0014 Iter 0020 / 0034 | Iter Loss 0.0815 | Iter Mean Loss 0.0861
# KG Training: Epoch 0014 Iter 0000 / 0263 | Iter Loss 0.1925 | Iter Mean Loss 0.1925
# KG Training: Epoch 0014 Iter 0010 / 0263 | Iter Loss 0.2713 | Iter Mean Loss 0.2374
# KG Training: Epoch 0014 Iter 0020 / 0263 | Iter Loss 0.2399 | Iter Mean Loss 0.2466
# KG Training: Epoch 0014 Iter 0030 / 0263 | Iter Loss 0.2243 | Iter Mean Loss 0.2433
# KG Training: Epoch 0014 Iter 0040 / 0263 | Iter Loss 0.2232 | Iter Mean Loss 0.2389
# KG Training: Epoch 0014 Iter 0050 / 0263 | Iter Loss 0.2095 | Iter Mean Loss 0.2353
# KG Training: Epoch 0014 Iter 0060 / 0263 | Iter Loss 0.2175 | Iter Mean Loss 0.2316
# KG Training: Epoch 0014 Iter 0070 / 0263 | Iter Loss 0.2456 | Iter Mean Loss 0.2331
# KG Training: Epoch 0014 Iter 0080 / 0263 | Iter Loss 0.2056 | Iter Mean Loss 0.2316
# KG Training: Epoch 0014 Iter 0090 / 0263 | Iter Loss 0.1165 | Iter Mean Loss 0.2249
# KG Training: Epoch 0014 Iter 0100 / 0263 | Iter Loss 0.1185 | Iter Mean Loss 0.2145
# KG Training: Epoch 0014 Iter 0110 / 0263 | Iter Loss 0.1138 | Iter Mean Loss 0.2054
# KG Training: Epoch 0014 Iter 0120 / 0263 | Iter Loss 0.1226 | Iter Mean Loss 0.1979
# KG Training: Epoch 0014 Iter 0130 / 0263 | Iter Loss 0.1097 | Iter Mean Loss 0.1913
# KG Training: Epoch 0014 Iter 0140 / 0263 | Iter Loss 0.1031 | Iter Mean Loss 0.1858
# KG Training: Epoch 0014 Iter 0150 / 0263 | Iter Loss 0.2273 | Iter Mean Loss 0.1853
# KG Training: Epoch 0014 Iter 0160 / 0263 | Iter Loss 0.1874 | Iter Mean Loss 0.1867
# KG Training: Epoch 0014 Iter 0170 / 0263 | Iter Loss 0.1190 | Iter Mean Loss 0.1861
# KG Training: Epoch 0014 Iter 0180 / 0263 | Iter Loss 0.1144 | Iter Mean Loss 0.1825
# KG Training: Epoch 0014 Iter 0190 / 0263 | Iter Loss 0.1088 | Iter Mean Loss 0.1788
# KG Training: Epoch 0014 Iter 0200 / 0263 | Iter Loss 0.1069 | Iter Mean Loss 0.1756
# KG Training: Epoch 0014 Iter 0210 / 0263 | Iter Loss 0.1067 | Iter Mean Loss 0.1727
# KG Training: Epoch 0014 Iter 0220 / 0263 | Iter Loss 0.1227 | Iter Mean Loss 0.1701
# KG Training: Epoch 0014 Iter 0230 / 0263 | Iter Loss 0.2086 | Iter Mean Loss 0.1689
# KG Training: Epoch 0014 Iter 0240 / 0263 | Iter Loss 0.1815 | Iter Mean Loss 0.1699
# KG Training: Epoch 0014 Iter 0250 / 0263 | Iter Loss 0.1956 | Iter Mean Loss 0.1706
# KG Training: Epoch 0014 Iter 0260 / 0263 | Iter Loss 0.1154 | Iter Mean Loss 0.1697
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.193107 s
# Measure time: 0.016295 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 15, Hit Ratio:0.18358  |  Precision:0.11306  |  Recall:0.18445  |  NDCG:0.18123
# *Best Performance*
# Epoch:fast_evaluation 15, Hit Ratio:0.18358  |  Precision:0.11306  |  Recall:0.18445  |  NDCG:0.18123
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0015 Iter 0000 / 0034 | Iter Loss 0.0835 | Iter Mean Loss 0.0835
# CF Training: Epoch 0015 Iter 0020 / 0034 | Iter Loss 0.0813 | Iter Mean Loss 0.0804
# KG Training: Epoch 0015 Iter 0000 / 0263 | Iter Loss 0.1891 | Iter Mean Loss 0.1891
# KG Training: Epoch 0015 Iter 0010 / 0263 | Iter Loss 0.2743 | Iter Mean Loss 0.2309
# KG Training: Epoch 0015 Iter 0020 / 0263 | Iter Loss 0.2406 | Iter Mean Loss 0.2400
# KG Training: Epoch 0015 Iter 0030 / 0263 | Iter Loss 0.2238 | Iter Mean Loss 0.2374
# KG Training: Epoch 0015 Iter 0040 / 0263 | Iter Loss 0.2141 | Iter Mean Loss 0.2331
# KG Training: Epoch 0015 Iter 0050 / 0263 | Iter Loss 0.2057 | Iter Mean Loss 0.2290
# KG Training: Epoch 0015 Iter 0060 / 0263 | Iter Loss 0.1996 | Iter Mean Loss 0.2257
# KG Training: Epoch 0015 Iter 0070 / 0263 | Iter Loss 0.2368 | Iter Mean Loss 0.2272
# KG Training: Epoch 0015 Iter 0080 / 0263 | Iter Loss 0.2024 | Iter Mean Loss 0.2260
# KG Training: Epoch 0015 Iter 0090 / 0263 | Iter Loss 0.1135 | Iter Mean Loss 0.2187
# KG Training: Epoch 0015 Iter 0100 / 0263 | Iter Loss 0.1073 | Iter Mean Loss 0.2080
# KG Training: Epoch 0015 Iter 0110 / 0263 | Iter Loss 0.1021 | Iter Mean Loss 0.1989
# KG Training: Epoch 0015 Iter 0120 / 0263 | Iter Loss 0.1121 | Iter Mean Loss 0.1914
# ...
# KG Training: Epoch 0328 Iter 0000 / 0263 | Iter Loss 0.0198 | Iter Mean Loss 0.0198
# KG Training: Epoch 0328 Iter 0010 / 0263 | Iter Loss 0.0255 | Iter Mean Loss 0.0249
# KG Training: Epoch 0328 Iter 0020 / 0263 | Iter Loss 0.0283 | Iter Mean Loss 0.0262
# KG Training: Epoch 0328 Iter 0030 / 0263 | Iter Loss 0.0263 | Iter Mean Loss 0.0262
# KG Training: Epoch 0328 Iter 0040 / 0263 | Iter Loss 0.0255 | Iter Mean Loss 0.0259
# KG Training: Epoch 0328 Iter 0050 / 0263 | Iter Loss 0.0244 | Iter Mean Loss 0.0260
# KG Training: Epoch 0328 Iter 0060 / 0263 | Iter Loss 0.0279 | Iter Mean Loss 0.0259
# KG Training: Epoch 0328 Iter 0070 / 0263 | Iter Loss 0.0200 | Iter Mean Loss 0.0256
# KG Training: Epoch 0328 Iter 0080 / 0263 | Iter Loss 0.0174 | Iter Mean Loss 0.0246
# KG Training: Epoch 0328 Iter 0090 / 0263 | Iter Loss 0.0344 | Iter Mean Loss 0.0251
# KG Training: Epoch 0328 Iter 0100 / 0263 | Iter Loss 0.0287 | Iter Mean Loss 0.0253
# KG Training: Epoch 0328 Iter 0110 / 0263 | Iter Loss 0.0274 | Iter Mean Loss 0.0256
# KG Training: Epoch 0328 Iter 0120 / 0263 | Iter Loss 0.0267 | Iter Mean Loss 0.0258
# KG Training: Epoch 0328 Iter 0130 / 0263 | Iter Loss 0.0316 | Iter Mean Loss 0.0260
# KG Training: Epoch 0328 Iter 0140 / 0263 | Iter Loss 0.0314 | Iter Mean Loss 0.0263
# KG Training: Epoch 0328 Iter 0150 / 0263 | Iter Loss 0.0267 | Iter Mean Loss 0.0267
# KG Training: Epoch 0328 Iter 0160 / 0263 | Iter Loss 0.0161 | Iter Mean Loss 0.0261
# KG Training: Epoch 0328 Iter 0170 / 0263 | Iter Loss 0.0261 | Iter Mean Loss 0.0259
# KG Training: Epoch 0328 Iter 0180 / 0263 | Iter Loss 0.0257 | Iter Mean Loss 0.0260
# KG Training: Epoch 0328 Iter 0190 / 0263 | Iter Loss 0.0277 | Iter Mean Loss 0.0261
# KG Training: Epoch 0328 Iter 0200 / 0263 | Iter Loss 0.0249 | Iter Mean Loss 0.0262
# KG Training: Epoch 0328 Iter 0210 / 0263 | Iter Loss 0.0272 | Iter Mean Loss 0.0263
# KG Training: Epoch 0328 Iter 0220 / 0263 | Iter Loss 0.0305 | Iter Mean Loss 0.0264
# KG Training: Epoch 0328 Iter 0230 / 0263 | Iter Loss 0.0253 | Iter Mean Loss 0.0265
# KG Training: Epoch 0328 Iter 0240 / 0263 | Iter Loss 0.0145 | Iter Mean Loss 0.0262
# KG Training: Epoch 0328 Iter 0250 / 0263 | Iter Loss 0.0212 | Iter Mean Loss 0.0259
# KG Training: Epoch 0328 Iter 0260 / 0263 | Iter Loss 0.0058 | Iter Mean Loss 0.0253
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.188385 s
# Measure time: 0.016312 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 329, Hit Ratio:0.23697  |  Precision:0.14594  |  Recall:0.23854  |  NDCG:0.25334
# *Best Performance*
# Epoch:fast_evaluation 313, Hit Ratio:0.23995  |  Precision:0.14777  |  Recall:0.24189  |  NDCG:0.2586
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0329 Iter 0000 / 0034 | Iter Loss 0.0463 | Iter Mean Loss 0.0463
# CF Training: Epoch 0329 Iter 0020 / 0034 | Iter Loss 0.0487 | Iter Mean Loss 0.0432
# KG Training: Epoch 0329 Iter 0000 / 0263 | Iter Loss 0.0182 | Iter Mean Loss 0.0182
# KG Training: Epoch 0329 Iter 0010 / 0263 | Iter Loss 0.0270 | Iter Mean Loss 0.0246
# KG Training: Epoch 0329 Iter 0020 / 0263 | Iter Loss 0.0274 | Iter Mean Loss 0.0256
# KG Training: Epoch 0329 Iter 0030 / 0263 | Iter Loss 0.0248 | Iter Mean Loss 0.0259
# KG Training: Epoch 0329 Iter 0040 / 0263 | Iter Loss 0.0257 | Iter Mean Loss 0.0258
# KG Training: Epoch 0329 Iter 0050 / 0263 | Iter Loss 0.0272 | Iter Mean Loss 0.0258
# KG Training: Epoch 0329 Iter 0060 / 0263 | Iter Loss 0.0250 | Iter Mean Loss 0.0255
# KG Training: Epoch 0329 Iter 0070 / 0263 | Iter Loss 0.0163 | Iter Mean Loss 0.0252
# KG Training: Epoch 0329 Iter 0080 / 0263 | Iter Loss 0.0176 | Iter Mean Loss 0.0241
# KG Training: Epoch 0329 Iter 0090 / 0263 | Iter Loss 0.0255 | Iter Mean Loss 0.0243
# KG Training: Epoch 0329 Iter 0100 / 0263 | Iter Loss 0.0271 | Iter Mean Loss 0.0247
# KG Training: Epoch 0329 Iter 0110 / 0263 | Iter Loss 0.0259 | Iter Mean Loss 0.0250
# KG Training: Epoch 0329 Iter 0120 / 0263 | Iter Loss 0.0257 | Iter Mean Loss 0.0252
# KG Training: Epoch 0329 Iter 0130 / 0263 | Iter Loss 0.0340 | Iter Mean Loss 0.0255
# KG Training: Epoch 0329 Iter 0140 / 0263 | Iter Loss 0.0304 | Iter Mean Loss 0.0258
# KG Training: Epoch 0329 Iter 0150 / 0263 | Iter Loss 0.0222 | Iter Mean Loss 0.0260
# KG Training: Epoch 0329 Iter 0160 / 0263 | Iter Loss 0.0165 | Iter Mean Loss 0.0255
# KG Training: Epoch 0329 Iter 0170 / 0263 | Iter Loss 0.0215 | Iter Mean Loss 0.0254
# KG Training: Epoch 0329 Iter 0180 / 0263 | Iter Loss 0.0334 | Iter Mean Loss 0.0255
# KG Training: Epoch 0329 Iter 0190 / 0263 | Iter Loss 0.0240 | Iter Mean Loss 0.0256
# KG Training: Epoch 0329 Iter 0200 / 0263 | Iter Loss 0.0252 | Iter Mean Loss 0.0257
# KG Training: Epoch 0329 Iter 0210 / 0263 | Iter Loss 0.0295 | Iter Mean Loss 0.0258
# KG Training: Epoch 0329 Iter 0220 / 0263 | Iter Loss 0.0321 | Iter Mean Loss 0.0259
# KG Training: Epoch 0329 Iter 0230 / 0263 | Iter Loss 0.0256 | Iter Mean Loss 0.0261
# KG Training: Epoch 0329 Iter 0240 / 0263 | Iter Loss 0.0136 | Iter Mean Loss 0.0257
# KG Training: Epoch 0329 Iter 0250 / 0263 | Iter Loss 0.0168 | Iter Mean Loss 0.0255
# KG Training: Epoch 0329 Iter 0260 / 0263 | Iter Loss 0.0058 | Iter Mean Loss 0.0249
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.518532 s
# Measure time: 0.016223 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 330, Hit Ratio:0.24193  |  Precision:0.14899  |  Recall:0.24382  |  NDCG:0.26065
# *Best Performance*
# Epoch:fast_evaluation 330, Hit Ratio:0.24193  |  Precision:0.14899  |  Recall:0.24382  |  NDCG:0.26065
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0330 Iter 0000 / 0034 | Iter Loss 0.0440 | Iter Mean Loss 0.0440
# CF Training: Epoch 0330 Iter 0020 / 0034 | Iter Loss 0.0470 | Iter Mean Loss 0.0456
# KG Training: Epoch 0330 Iter 0000 / 0263 | Iter Loss 0.0184 | Iter Mean Loss 0.0184
# KG Training: Epoch 0330 Iter 0010 / 0263 | Iter Loss 0.0305 | Iter Mean Loss 0.0256
# KG Training: Epoch 0330 Iter 0020 / 0263 | Iter Loss 0.0270 | Iter Mean Loss 0.0264
# KG Training: Epoch 0330 Iter 0030 / 0263 | Iter Loss 0.0235 | Iter Mean Loss 0.0264
# KG Training: Epoch 0330 Iter 0040 / 0263 | Iter Loss 0.0249 | Iter Mean Loss 0.0263
# KG Training: Epoch 0330 Iter 0050 / 0263 | Iter Loss 0.0246 | Iter Mean Loss 0.0262
# KG Training: Epoch 0330 Iter 0060 / 0263 | Iter Loss 0.0246 | Iter Mean Loss 0.0259
# KG Training: Epoch 0330 Iter 0070 / 0263 | Iter Loss 0.0182 | Iter Mean Loss 0.0256
# KG Training: Epoch 0330 Iter 0080 / 0263 | Iter Loss 0.0170 | Iter Mean Loss 0.0245
# KG Training: Epoch 0330 Iter 0090 / 0263 | Iter Loss 0.0273 | Iter Mean Loss 0.0246
# KG Training: Epoch 0330 Iter 0100 / 0263 | Iter Loss 0.0291 | Iter Mean Loss 0.0248
# KG Training: Epoch 0330 Iter 0110 / 0263 | Iter Loss 0.0264 | Iter Mean Loss 0.0251
# KG Training: Epoch 0330 Iter 0120 / 0263 | Iter Loss 0.0304 | Iter Mean Loss 0.0253
# KG Training: Epoch 0330 Iter 0130 / 0263 | Iter Loss 0.0291 | Iter Mean Loss 0.0256
# KG Training: Epoch 0330 Iter 0140 / 0263 | Iter Loss 0.0399 | Iter Mean Loss 0.0261
# KG Training: Epoch 0330 Iter 0150 / 0263 | Iter Loss 0.0253 | Iter Mean Loss 0.0265
# KG Training: Epoch 0330 Iter 0160 / 0263 | Iter Loss 0.0162 | Iter Mean Loss 0.0259
# KG Training: Epoch 0330 Iter 0170 / 0263 | Iter Loss 0.0301 | Iter Mean Loss 0.0258
# KG Training: Epoch 0330 Iter 0180 / 0263 | Iter Loss 0.0297 | Iter Mean Loss 0.0259
# KG Training: Epoch 0330 Iter 0190 / 0263 | Iter Loss 0.0265 | Iter Mean Loss 0.0259
# KG Training: Epoch 0330 Iter 0200 / 0263 | Iter Loss 0.0256 | Iter Mean Loss 0.0259
# KG Training: Epoch 0330 Iter 0210 / 0263 | Iter Loss 0.0293 | Iter Mean Loss 0.0261
# KG Training: Epoch 0330 Iter 0220 / 0263 | Iter Loss 0.0375 | Iter Mean Loss 0.0262
# KG Training: Epoch 0330 Iter 0230 / 0263 | Iter Loss 0.0243 | Iter Mean Loss 0.0264
# KG Training: Epoch 0330 Iter 0240 / 0263 | Iter Loss 0.0182 | Iter Mean Loss 0.0261
# KG Training: Epoch 0330 Iter 0250 / 0263 | Iter Loss 0.0186 | Iter Mean Loss 0.0257
# KG Training: Epoch 0330 Iter 0260 / 0263 | Iter Loss 0.0057 | Iter Mean Loss 0.0252
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.188844 s
# Measure time: 0.016376 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 331, Hit Ratio:0.23732  |  Precision:0.14615  |  Recall:0.23981  |  NDCG:0.25523
# *Best Performance*
# Epoch:fast_evaluation 330, Hit Ratio:0.24193  |  Precision:0.14899  |  Recall:0.24382  |  NDCG:0.26065
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0331 Iter 0000 / 0034 | Iter Loss 0.0458 | Iter Mean Loss 0.0458
# CF Training: Epoch 0331 Iter 0020 / 0034 | Iter Loss 0.0430 | Iter Mean Loss 0.0428
# KG Training: Epoch 0331 Iter 0000 / 0263 | Iter Loss 0.0201 | Iter Mean Loss 0.0201
# KG Training: Epoch 0331 Iter 0010 / 0263 | Iter Loss 0.0275 | Iter Mean Loss 0.0258
# KG Training: Epoch 0331 Iter 0020 / 0263 | Iter Loss 0.0272 | Iter Mean Loss 0.0263
# KG Training: Epoch 0331 Iter 0030 / 0263 | Iter Loss 0.0244 | Iter Mean Loss 0.0265
# KG Training: Epoch 0331 Iter 0040 / 0263 | Iter Loss 0.0245 | Iter Mean Loss 0.0263
# KG Training: Epoch 0331 Iter 0050 / 0263 | Iter Loss 0.0237 | Iter Mean Loss 0.0261
# KG Training: Epoch 0331 Iter 0060 / 0263 | Iter Loss 0.0251 | Iter Mean Loss 0.0259
# KG Training: Epoch 0331 Iter 0070 / 0263 | Iter Loss 0.0184 | Iter Mean Loss 0.0255
# KG Training: Epoch 0331 Iter 0080 / 0263 | Iter Loss 0.0167 | Iter Mean Loss 0.0244
# KG Training: Epoch 0331 Iter 0090 / 0263 | Iter Loss 0.0309 | Iter Mean Loss 0.0245
# KG Training: Epoch 0331 Iter 0100 / 0263 | Iter Loss 0.0249 | Iter Mean Loss 0.0249
# KG Training: Epoch 0331 Iter 0110 / 0263 | Iter Loss 0.0278 | Iter Mean Loss 0.0251
# KG Training: Epoch 0331 Iter 0120 / 0263 | Iter Loss 0.0287 | Iter Mean Loss 0.0255
# KG Training: Epoch 0331 Iter 0130 / 0263 | Iter Loss 0.0307 | Iter Mean Loss 0.0257
# KG Training: Epoch 0331 Iter 0140 / 0263 | Iter Loss 0.0334 | Iter Mean Loss 0.0261
# KG Training: Epoch 0331 Iter 0150 / 0263 | Iter Loss 0.0239 | Iter Mean Loss 0.0264
# KG Training: Epoch 0331 Iter 0160 / 0263 | Iter Loss 0.0169 | Iter Mean Loss 0.0258
# KG Training: Epoch 0331 Iter 0170 / 0263 | Iter Loss 0.0276 | Iter Mean Loss 0.0257
# KG Training: Epoch 0331 Iter 0180 / 0263 | Iter Loss 0.0262 | Iter Mean Loss 0.0258
# KG Training: Epoch 0331 Iter 0190 / 0263 | Iter Loss 0.0301 | Iter Mean Loss 0.0259
# KG Training: Epoch 0331 Iter 0200 / 0263 | Iter Loss 0.0250 | Iter Mean Loss 0.0260
# KG Training: Epoch 0331 Iter 0210 / 0263 | Iter Loss 0.0298 | Iter Mean Loss 0.0261
# KG Training: Epoch 0331 Iter 0220 / 0263 | Iter Loss 0.0308 | Iter Mean Loss 0.0262
# KG Training: Epoch 0331 Iter 0230 / 0263 | Iter Loss 0.0227 | Iter Mean Loss 0.0264
# KG Training: Epoch 0331 Iter 0240 / 0263 | Iter Loss 0.0171 | Iter Mean Loss 0.0261
# KG Training: Epoch 0331 Iter 0250 / 0263 | Iter Loss 0.0192 | Iter Mean Loss 0.0258
# KG Training: Epoch 0331 Iter 0260 / 0263 | Iter Loss 0.0053 | Iter Mean Loss 0.0252
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.187366 s
# Measure time: 0.016337 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 332, Hit Ratio:0.23689  |  Precision:0.14589  |  Recall:0.23832  |  NDCG:0.25668
# *Best Performance*
# Epoch:fast_evaluation 330, Hit Ratio:0.24193  |  Precision:0.14899  |  Recall:0.24382  |  NDCG:0.26065
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0332 Iter 0000 / 0034 | Iter Loss 0.0417 | Iter Mean Loss 0.0417
# CF Training: Epoch 0332 Iter 0020 / 0034 | Iter Loss 0.0440 | Iter Mean Loss 0.0438
# KG Training: Epoch 0332 Iter 0000 / 0263 | Iter Loss 0.0196 | Iter Mean Loss 0.0196
# KG Training: Epoch 0332 Iter 0010 / 0263 | Iter Loss 0.0256 | Iter Mean Loss 0.0242
# KG Training: Epoch 0332 Iter 0020 / 0263 | Iter Loss 0.0258 | Iter Mean Loss 0.0257
# KG Training: Epoch 0332 Iter 0030 / 0263 | Iter Loss 0.0254 | Iter Mean Loss 0.0256
# KG Training: Epoch 0332 Iter 0040 / 0263 | Iter Loss 0.0254 | Iter Mean Loss 0.0257
# KG Training: Epoch 0332 Iter 0050 / 0263 | Iter Loss 0.0269 | Iter Mean Loss 0.0257
# KG Training: Epoch 0332 Iter 0060 / 0263 | Iter Loss 0.0247 | Iter Mean Loss 0.0255
# KG Training: Epoch 0332 Iter 0070 / 0263 | Iter Loss 0.0191 | Iter Mean Loss 0.0253
# KG Training: Epoch 0332 Iter 0080 / 0263 | Iter Loss 0.0174 | Iter Mean Loss 0.0242
# KG Training: Epoch 0332 Iter 0090 / 0263 | Iter Loss 0.0264 | Iter Mean Loss 0.0245
# KG Training: Epoch 0332 Iter 0100 / 0263 | Iter Loss 0.0274 | Iter Mean Loss 0.0249
# KG Training: Epoch 0332 Iter 0110 / 0263 | Iter Loss 0.0268 | Iter Mean Loss 0.0252
# KG Training: Epoch 0332 Iter 0120 / 0263 | Iter Loss 0.0334 | Iter Mean Loss 0.0256
# KG Training: Epoch 0332 Iter 0130 / 0263 | Iter Loss 0.0274 | Iter Mean Loss 0.0258
# KG Training: Epoch 0332 Iter 0140 / 0263 | Iter Loss 0.0369 | Iter Mean Loss 0.0261
# KG Training: Epoch 0332 Iter 0150 / 0263 | Iter Loss 0.0261 | Iter Mean Loss 0.0264
# KG Training: Epoch 0332 Iter 0160 / 0263 | Iter Loss 0.0148 | Iter Mean Loss 0.0258
# KG Training: Epoch 0332 Iter 0170 / 0263 | Iter Loss 0.0258 | Iter Mean Loss 0.0257
# KG Training: Epoch 0332 Iter 0180 / 0263 | Iter Loss 0.0305 | Iter Mean Loss 0.0258
# KG Training: Epoch 0332 Iter 0190 / 0263 | Iter Loss 0.0280 | Iter Mean Loss 0.0259
# KG Training: Epoch 0332 Iter 0200 / 0263 | Iter Loss 0.0287 | Iter Mean Loss 0.0261
# KG Training: Epoch 0332 Iter 0210 / 0263 | Iter Loss 0.0319 | Iter Mean Loss 0.0261
# KG Training: Epoch 0332 Iter 0220 / 0263 | Iter Loss 0.0309 | Iter Mean Loss 0.0263
# KG Training: Epoch 0332 Iter 0230 / 0263 | Iter Loss 0.0247 | Iter Mean Loss 0.0265
# KG Training: Epoch 0332 Iter 0240 / 0263 | Iter Loss 0.0158 | Iter Mean Loss 0.0262
# KG Training: Epoch 0332 Iter 0250 / 0263 | Iter Loss 0.0158 | Iter Mean Loss 0.0258
# KG Training: Epoch 0332 Iter 0260 / 0263 | Iter Loss 0.0053 | Iter Mean Loss 0.0252
# Evaluating the model...
# Progress: [++++++++++++++++++++++++++++++++++++++++++++++++++]100%
# Test time: 0.190542 s
# Measure time: 0.016672 s
# ------------------------------------------------------------------------------------------------------------------------
# Real-Time Ranking Performance  (Top-20 Item Recommendation)
# *Current Performance*
# Epoch: 333, Hit Ratio:0.23473  |  Precision:0.14456  |  Recall:0.23639  |  NDCG:0.25034
# *Best Performance*
# Epoch:fast_evaluation 330, Hit Ratio:0.24193  |  Precision:0.14899  |  Recall:0.24382  |  NDCG:0.26065
# ------------------------------------------------------------------------------------------------------------------------
# CF Training: Epoch 0333 Iter 0000 / 0034 | Iter Loss 0.0451 | Iter Mean Loss 0.0451
# CF Training: Epoch 0333 Iter 0020 / 0034 | Iter Loss 0.0440 | Iter Mean Loss 0.0431
# KG Training: Epoch 0333 Iter 0000 / 0263 | Iter Loss 0.0203 | Iter Mean Loss 0.0203
# KG Training: Epoch 0333 Iter 0010 / 0263 | Iter Loss 0.0270 | Iter Mean Loss 0.0251
# KG Training: Epoch 0333 Iter 0020 / 0263 | Iter Loss 0.0239 | Iter Mean Loss 0.0255
# KG Training: Epoch 0333 Iter 0030 / 0263 | Iter Loss 0.0266 | Iter Mean Loss 0.0259
# KG Training: Epoch 0333 Iter 0040 / 0263 | Iter Loss 0.0280 | Iter Mean Loss 0.0261
